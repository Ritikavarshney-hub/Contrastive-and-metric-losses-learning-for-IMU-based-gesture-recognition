# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.optim import Adam
from pytorch_metric_learning.losses import SupConLoss

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

NUM_CLASSES = 47   
class EMGDataset(Dataset):
    def __init__(self, x_path, y_path):
        self.X = np.load(x_path)
        self.y = np.argmax(np.load(y_path), axis=1)  

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return (
            torch.tensor(self.X[idx], dtype=torch.float32),
            torch.tensor(self.y[idx], dtype=torch.long)
        )

class CNNEncoder(nn.Module):
    def __init__(self, emb_dim=256):
        super().__init__()

        self.features = nn.Sequential(
            nn.Conv1d(6, 64, kernel_size=10),
            nn.ReLU(),
            nn.Conv1d(64, 64, kernel_size=10),
            nn.ReLU(),
            nn.MaxPool1d(3),

            nn.Conv1d(64, 256, kernel_size=10),
            nn.ReLU(),
            nn.Conv1d(256, 256, kernel_size=10),
            nn.ReLU(),

            nn.AdaptiveAvgPool1d(1)
        )

        self.fc = nn.Linear(256, emb_dim)

    def forward(self, x):
        x = x.permute(0, 2, 1)  
        x = self.features(x).squeeze(-1)
        z = self.fc(x)
        return z
    
class Classifier(nn.Module):
    def __init__(self, emb_dim=256, num_classes=NUM_CLASSES):
        super().__init__()
        self.fc = nn.Linear(emb_dim, num_classes)

    def forward(self, z):
        return self.fc(z)

class FullModel(nn.Module):
    def __init__(self, emb_dim=256, num_classes=NUM_CLASSES):
        super().__init__()
        self.encoder = CNNEncoder(emb_dim)
        self.classifier = Classifier(emb_dim, num_classes)

    def forward(self, x):
        z = self.encoder(x)
        logits = self.classifier(z)
        return z, logits

class EarlyStopping:
    def __init__(self, patience=10):
        self.patience = patience
        self.best_acc = -1
        self.counter = 0
        self.best_state = None

    def step(self, acc, model):
        if acc > self.best_acc:
            self.best_acc = acc
            self.best_state = {k: v.cpu() for k, v in model.state_dict().items()}
            self.counter = 0
            return False
        else:
            self.counter += 1
            return self.counter >= self.patience

    def restore(self, model):
        model.load_state_dict(self.best_state)

def train_and_eval(
    model,
    train_loader,
    test_loader,
    supcon_loss,
    alpha=0.5,
    epochs=500,
    patience=10
):
    ce_loss = nn.CrossEntropyLoss()
    optimizer = Adam(model.parameters(), lr=5e-4)
    stopper = EarlyStopping(patience)

    for epoch in range(epochs):
        model.train()
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)

            z, logits = model(x)

            z_norm = F.normalize(z, dim=1)  
            loss = ce_loss(logits, y) + alpha * supcon_loss(z_norm, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        model.eval()
        correct, total = 0, 0
        with torch.no_grad():
            for x, y in test_loader:
                x, y = x.to(device), y.to(device)
                _, logits = model(x)
                pred = logits.argmax(dim=1)
                correct += (pred == y).sum().item()
                total += y.size(0)

        acc = correct / total
        print(f"Epoch {epoch+1:02d} | Val Acc: {acc:.4f}")

        if stopper.step(acc, model):
            print("Early stopping triggered")
            break

    stopper.restore(model)
    return stopper.best_acc

BASE = "models/Data/Data/47_classes/UserDependenet"  
supcon_loss = SupConLoss(temperature=0.07)

all_accs = []

for split in range(1, 11):
    print(f"\n===== SPLIT {split} =====")

    train_ds = EMGDataset(
        f"{BASE}/Train/X_train_{split}.npy",
        f"{BASE}/Train/y_train_{split}.npy"
    )
    test_ds = EMGDataset(
        f"{BASE}/Test/X_test_{split}.npy",
        f"{BASE}/Test/y_test_{split}.npy"
    )

    train_loader = DataLoader(train_ds, batch_size=128, shuffle=True)
    test_loader = DataLoader(test_ds, batch_size=128, shuffle=False)

    model = FullModel(
        emb_dim=256,
        num_classes=NUM_CLASSES
    ).to(device)

    acc = train_and_eval(
        model,
        train_loader,
        test_loader,
        supcon_loss,
        alpha=0.5,
        epochs=500,
        patience=10
    )

    print(f"Split {split} Accuracy: {acc:.4f}")
    all_accs.append(acc)

print("\nFINAL AVERAGE ACCURACY:", np.mean(all_accs))
# Out:
# Device: cuda
#
# ===== SPLIT 1 =====
# Epoch 01 | Val Acc: 0.0213
# Epoch 02 | Val Acc: 0.1298
# Epoch 03 | Val Acc: 0.4213
# Epoch 04 | Val Acc: 0.5128
# Epoch 05 | Val Acc: 0.5936
# Epoch 06 | Val Acc: 0.6489
# Epoch 07 | Val Acc: 0.6819
# Epoch 08 | Val Acc: 0.7606
# Epoch 09 | Val Acc: 0.7340
# Epoch 10 | Val Acc: 0.7266
# Epoch 11 | Val Acc: 0.7989
# Epoch 12 | Val Acc: 0.8160
# Epoch 13 | Val Acc: 0.8053
# Epoch 14 | Val Acc: 0.8074
# Epoch 15 | Val Acc: 0.8362
# Epoch 16 | Val Acc: 0.7979
# Epoch 17 | Val Acc: 0.8372
# Epoch 18 | Val Acc: 0.8181
# Epoch 19 | Val Acc: 0.8287
# Epoch 20 | Val Acc: 0.8128
# Epoch 21 | Val Acc: 0.8202
# Epoch 22 | Val Acc: 0.8330
# Epoch 23 | Val Acc: 0.8426
# Epoch 24 | Val Acc: 0.8372
# Epoch 25 | Val Acc: 0.8404
# Epoch 26 | Val Acc: 0.8394
# Epoch 27 | Val Acc: 0.8372
# Epoch 28 | Val Acc: 0.8638
# Epoch 29 | Val Acc: 0.8426
# Epoch 30 | Val Acc: 0.8436
# Epoch 31 | Val Acc: 0.8340
# Epoch 32 | Val Acc: 0.8426
# Epoch 33 | Val Acc: 0.8564
# Epoch 34 | Val Acc: 0.8564
# Epoch 35 | Val Acc: 0.8436
# Epoch 36 | Val Acc: 0.8202
# Epoch 37 | Val Acc: 0.8489
# Epoch 38 | Val Acc: 0.8532
# Early stopping triggered
# Split 1 Accuracy: 0.8638
#
# ===== SPLIT 2 =====
# Epoch 01 | Val Acc: 0.0798
# Epoch 02 | Val Acc: 0.2287
# Epoch 03 | Val Acc: 0.4011
# Epoch 04 | Val Acc: 0.5830
# Epoch 05 | Val Acc: 0.6500
# Epoch 06 | Val Acc: 0.6309
# Epoch 07 | Val Acc: 0.7670
# Epoch 08 | Val Acc: 0.7457
# Epoch 09 | Val Acc: 0.8245
# Epoch 10 | Val Acc: 0.8500
# Epoch 11 | Val Acc: 0.8436
# Epoch 12 | Val Acc: 0.8574
# Epoch 13 | Val Acc: 0.8606
# Epoch 14 | Val Acc: 0.8617
# Epoch 15 | Val Acc: 0.8532
# Epoch 16 | Val Acc: 0.8745
# Epoch 17 | Val Acc: 0.8606
# Epoch 18 | Val Acc: 0.8809
# Epoch 19 | Val Acc: 0.8851
# Epoch 20 | Val Acc: 0.8936
# Epoch 21 | Val Acc: 0.9074
# Epoch 22 | Val Acc: 0.9043
# Epoch 23 | Val Acc: 0.8862
# Epoch 24 | Val Acc: 0.9106
# Epoch 25 | Val Acc: 0.9096
# Epoch 26 | Val Acc: 0.9138
# Epoch 27 | Val Acc: 0.9096
# Epoch 28 | Val Acc: 0.9191
# Epoch 29 | Val Acc: 0.9128
# Epoch 30 | Val Acc: 0.9117
# Epoch 31 | Val Acc: 0.9138
# Epoch 32 | Val Acc: 0.9106
# Epoch 33 | Val Acc: 0.9234
# Epoch 34 | Val Acc: 0.9149
# Epoch 35 | Val Acc: 0.9053
# Epoch 36 | Val Acc: 0.9202
# Epoch 37 | Val Acc: 0.9138
# Epoch 38 | Val Acc: 0.9213
# Epoch 39 | Val Acc: 0.9085
# Epoch 40 | Val Acc: 0.9149
# Epoch 41 | Val Acc: 0.9064
# Epoch 42 | Val Acc: 0.8947
# Epoch 43 | Val Acc: 0.8926
# Early stopping triggered
# Split 2 Accuracy: 0.9234
#
# ===== SPLIT 3 =====
# Epoch 01 | Val Acc: 0.0383
# Epoch 02 | Val Acc: 0.1160
# Epoch 03 | Val Acc: 0.2872
# Epoch 04 | Val Acc: 0.5383
# Epoch 05 | Val Acc: 0.6160
# Epoch 06 | Val Acc: 0.7011
# Epoch 07 | Val Acc: 0.7638
# Epoch 08 | Val Acc: 0.7585
# Epoch 09 | Val Acc: 0.7883
# Epoch 10 | Val Acc: 0.8340
# Epoch 11 | Val Acc: 0.8468
# Epoch 12 | Val Acc: 0.8191
# Epoch 13 | Val Acc: 0.8543
# Epoch 14 | Val Acc: 0.8660
# Epoch 15 | Val Acc: 0.8723
# Epoch 16 | Val Acc: 0.8862
# Epoch 17 | Val Acc: 0.8894
# Epoch 18 | Val Acc: 0.8862
# Epoch 19 | Val Acc: 0.9000
# Epoch 20 | Val Acc: 0.8936
# Epoch 21 | Val Acc: 0.8968
# Epoch 22 | Val Acc: 0.8936
# Epoch 23 | Val Acc: 0.9011
# Epoch 24 | Val Acc: 0.9043
# Epoch 25 | Val Acc: 0.9021
# Epoch 26 | Val Acc: 0.9064
# Epoch 27 | Val Acc: 0.9096
# Epoch 28 | Val Acc: 0.9096
# Epoch 29 | Val Acc: 0.9000
# Epoch 30 | Val Acc: 0.9064
# Epoch 31 | Val Acc: 0.9117
# Epoch 32 | Val Acc: 0.9223
# Epoch 33 | Val Acc: 0.9032
# Epoch 34 | Val Acc: 0.9096
# Epoch 35 | Val Acc: 0.9170
# Epoch 36 | Val Acc: 0.9149
# Epoch 37 | Val Acc: 0.9181
# Epoch 38 | Val Acc: 0.9053
# Epoch 39 | Val Acc: 0.8989
# Epoch 40 | Val Acc: 0.9106
# Epoch 41 | Val Acc: 0.9149
# Epoch 42 | Val Acc: 0.9106
# Early stopping triggered
# Split 3 Accuracy: 0.9223
#
# ===== SPLIT 4 =====
# Epoch 01 | Val Acc: 0.0404
# Epoch 02 | Val Acc: 0.2468
# Epoch 03 | Val Acc: 0.4117
# Epoch 04 | Val Acc: 0.5894
# Epoch 05 | Val Acc: 0.6191
# Epoch 06 | Val Acc: 0.6649
# Epoch 07 | Val Acc: 0.7681
# Epoch 08 | Val Acc: 0.7702
# Epoch 09 | Val Acc: 0.8223
# Epoch 10 | Val Acc: 0.8128
# Epoch 11 | Val Acc: 0.8096
# Epoch 12 | Val Acc: 0.8468
# Epoch 13 | Val Acc: 0.8511
# Epoch 14 | Val Acc: 0.8723
# Epoch 15 | Val Acc: 0.8755
# Epoch 16 | Val Acc: 0.8745
# Epoch 17 | Val Acc: 0.8681
# Epoch 18 | Val Acc: 0.8989
# Epoch 19 | Val Acc: 0.9074
# Epoch 20 | Val Acc: 0.9043
# Epoch 21 | Val Acc: 0.9043
# Epoch 22 | Val Acc: 0.9138
# Epoch 23 | Val Acc: 0.9096
# Epoch 24 | Val Acc: 0.9085
# Epoch 25 | Val Acc: 0.9160
# Epoch 26 | Val Acc: 0.9106
# Epoch 27 | Val Acc: 0.9128
# Epoch 28 | Val Acc: 0.9149
# Epoch 29 | Val Acc: 0.9096
# Epoch 30 | Val Acc: 0.8968
# Epoch 31 | Val Acc: 0.9170
# Epoch 32 | Val Acc: 0.9191
# Epoch 33 | Val Acc: 0.9170
# Epoch 34 | Val Acc: 0.9021
# Epoch 35 | Val Acc: 0.9128
# Epoch 36 | Val Acc: 0.9053
# Epoch 37 | Val Acc: 0.9191
# Epoch 38 | Val Acc: 0.9277
# Epoch 39 | Val Acc: 0.9234
# Epoch 40 | Val Acc: 0.9202
# Epoch 41 | Val Acc: 0.9170
# Epoch 42 | Val Acc: 0.9266
# Epoch 43 | Val Acc: 0.9202
# Epoch 44 | Val Acc: 0.9245
# Epoch 45 | Val Acc: 0.9255
# Epoch 46 | Val Acc: 0.9255
# Epoch 47 | Val Acc: 0.9255
# Epoch 48 | Val Acc: 0.9106
# Early stopping triggered
# Split 4 Accuracy: 0.9277
#
# ===== SPLIT 5 =====
# Epoch 01 | Val Acc: 0.0245
# Epoch 02 | Val Acc: 0.2404
# Epoch 03 | Val Acc: 0.3447
# Epoch 04 | Val Acc: 0.5766
# Epoch 05 | Val Acc: 0.6574
# Epoch 06 | Val Acc: 0.7043
# Epoch 07 | Val Acc: 0.7819
# Epoch 08 | Val Acc: 0.7936
# Epoch 09 | Val Acc: 0.8149
# Epoch 10 | Val Acc: 0.8298
# Epoch 11 | Val Acc: 0.8564
# Epoch 12 | Val Acc: 0.8851
# Epoch 13 | Val Acc: 0.8691
# Epoch 14 | Val Acc: 0.8894
# Epoch 15 | Val Acc: 0.8915
# Epoch 16 | Val Acc: 0.8840
# Epoch 17 | Val Acc: 0.8989
# Epoch 18 | Val Acc: 0.8830
# Epoch 19 | Val Acc: 0.9128
# Epoch 20 | Val Acc: 0.8915
# Epoch 21 | Val Acc: 0.9000
# Epoch 22 | Val Acc: 0.9096
# Epoch 23 | Val Acc: 0.9096
# Epoch 24 | Val Acc: 0.8936
# Epoch 25 | Val Acc: 0.8904
# Epoch 26 | Val Acc: 0.9032
# Epoch 27 | Val Acc: 0.9011
# Epoch 28 | Val Acc: 0.8915
# Epoch 29 | Val Acc: 0.8968
# Early stopping triggered
# Split 5 Accuracy: 0.9128
#
# ===== SPLIT 6 =====
# Epoch 01 | Val Acc: 0.0213
# Epoch 02 | Val Acc: 0.0851
# Epoch 03 | Val Acc: 0.2319
# Epoch 04 | Val Acc: 0.4511
# Epoch 05 | Val Acc: 0.5117
# Epoch 06 | Val Acc: 0.5862
# Epoch 07 | Val Acc: 0.6936
# Epoch 08 | Val Acc: 0.7181
# Epoch 09 | Val Acc: 0.7383
# Epoch 10 | Val Acc: 0.7734
# Epoch 11 | Val Acc: 0.7957
# Epoch 12 | Val Acc: 0.8074
# Epoch 13 | Val Acc: 0.8404
# Epoch 14 | Val Acc: 0.8394
# Epoch 15 | Val Acc: 0.8362
# Epoch 16 | Val Acc: 0.8479
# Epoch 17 | Val Acc: 0.8574
# Epoch 18 | Val Acc: 0.8628
# Epoch 19 | Val Acc: 0.8723
# Epoch 20 | Val Acc: 0.8543
# Epoch 21 | Val Acc: 0.8660
# Epoch 22 | Val Acc: 0.8734
# Epoch 23 | Val Acc: 0.8809
# Epoch 24 | Val Acc: 0.8830
# Epoch 25 | Val Acc: 0.8787
# Epoch 26 | Val Acc: 0.8798
# Epoch 27 | Val Acc: 0.8862
# Epoch 28 | Val Acc: 0.8862
# Epoch 29 | Val Acc: 0.9000
# Epoch 30 | Val Acc: 0.8521
# Epoch 31 | Val Acc: 0.8926
# Epoch 32 | Val Acc: 0.8915
# Epoch 33 | Val Acc: 0.8883
# Epoch 34 | Val Acc: 0.8830
# Epoch 35 | Val Acc: 0.8957
# Epoch 36 | Val Acc: 0.8936
# Epoch 37 | Val Acc: 0.8957
# Epoch 38 | Val Acc: 0.8798
# Epoch 39 | Val Acc: 0.8936
# Early stopping triggered
# Split 6 Accuracy: 0.9000
#
# ===== SPLIT 7 =====
# Epoch 01 | Val Acc: 0.0223
# Epoch 02 | Val Acc: 0.1383
# Epoch 03 | Val Acc: 0.3149
# Epoch 04 | Val Acc: 0.4872
# Epoch 05 | Val Acc: 0.5553
# Epoch 06 | Val Acc: 0.6404
# Epoch 07 | Val Acc: 0.6904
# Epoch 08 | Val Acc: 0.7266
# Epoch 09 | Val Acc: 0.7394
# Epoch 10 | Val Acc: 0.7713
# Epoch 11 | Val Acc: 0.8106
# Epoch 12 | Val Acc: 0.7830
# Epoch 13 | Val Acc: 0.8415
# Epoch 14 | Val Acc: 0.8351
# Epoch 15 | Val Acc: 0.8553
# Epoch 16 | Val Acc: 0.8638
# Epoch 17 | Val Acc: 0.8713
# Epoch 18 | Val Acc: 0.8745
# Epoch 19 | Val Acc: 0.8777
# Epoch 20 | Val Acc: 0.8766
# Epoch 21 | Val Acc: 0.8755
# Epoch 22 | Val Acc: 0.8830
# Epoch 23 | Val Acc: 0.8947
# Epoch 24 | Val Acc: 0.8872
# Epoch 25 | Val Acc: 0.9032
# Epoch 26 | Val Acc: 0.8840
# Epoch 27 | Val Acc: 0.8936
# Epoch 28 | Val Acc: 0.8936
# Epoch 29 | Val Acc: 0.9085
# Epoch 30 | Val Acc: 0.8883
# Epoch 31 | Val Acc: 0.9085
# Epoch 32 | Val Acc: 0.8968
# Epoch 33 | Val Acc: 0.8957
# Epoch 34 | Val Acc: 0.9043
# Epoch 35 | Val Acc: 0.9043
# Epoch 36 | Val Acc: 0.8691
# Epoch 37 | Val Acc: 0.8809
# Epoch 38 | Val Acc: 0.9021
# Epoch 39 | Val Acc: 0.9043
# Early stopping triggered
# Split 7 Accuracy: 0.9085
#
# ===== SPLIT 8 =====
# Epoch 01 | Val Acc: 0.0202
# Epoch 02 | Val Acc: 0.1170
# Epoch 03 | Val Acc: 0.3064
# Epoch 04 | Val Acc: 0.4543
# Epoch 05 | Val Acc: 0.5628
# Epoch 06 | Val Acc: 0.6543
# Epoch 07 | Val Acc: 0.6915
# Epoch 08 | Val Acc: 0.7213
# Epoch 09 | Val Acc: 0.6298
# Epoch 10 | Val Acc: 0.7862
# Epoch 11 | Val Acc: 0.8117
# Epoch 12 | Val Acc: 0.7926
# Epoch 13 | Val Acc: 0.7936
# Epoch 14 | Val Acc: 0.8128
# Epoch 15 | Val Acc: 0.8191
# Epoch 16 | Val Acc: 0.8415
# Epoch 17 | Val Acc: 0.8351
# Epoch 18 | Val Acc: 0.8415
# Epoch 19 | Val Acc: 0.8521
# Epoch 20 | Val Acc: 0.8596
# Epoch 21 | Val Acc: 0.8596
# Epoch 22 | Val Acc: 0.8798
# Epoch 23 | Val Acc: 0.8713
# Epoch 24 | Val Acc: 0.8691
# Epoch 25 | Val Acc: 0.8553
# Epoch 26 | Val Acc: 0.8649
# Epoch 27 | Val Acc: 0.8713
# Epoch 28 | Val Acc: 0.8734
# Epoch 29 | Val Acc: 0.8660
# Epoch 30 | Val Acc: 0.8819
# Epoch 31 | Val Acc: 0.8713
# Epoch 32 | Val Acc: 0.8649
# Epoch 33 | Val Acc: 0.8745
# Epoch 34 | Val Acc: 0.8702
# Epoch 35 | Val Acc: 0.8840
# Epoch 36 | Val Acc: 0.8830
# Epoch 37 | Val Acc: 0.8872
# Epoch 38 | Val Acc: 0.8649
# Epoch 39 | Val Acc: 0.8681
# Epoch 40 | Val Acc: 0.8745
# Epoch 41 | Val Acc: 0.8723
# Epoch 42 | Val Acc: 0.8883
# Epoch 43 | Val Acc: 0.8809
# Epoch 44 | Val Acc: 0.8830
# Epoch 45 | Val Acc: 0.8691
# Epoch 46 | Val Acc: 0.8872
# Epoch 47 | Val Acc: 0.8979
# Epoch 48 | Val Acc: 0.8830
# Epoch 49 | Val Acc: 0.8936
# Epoch 50 | Val Acc: 0.8840
# Epoch 51 | Val Acc: 0.8851
# Epoch 52 | Val Acc: 0.8851
# Epoch 53 | Val Acc: 0.8894
# Epoch 54 | Val Acc: 0.8915
# Epoch 55 | Val Acc: 0.8872
# Epoch 56 | Val Acc: 0.8915
# Epoch 57 | Val Acc: 0.8830
# Early stopping triggered
# Split 8 Accuracy: 0.8979
#
# ===== SPLIT 9 =====
# Epoch 01 | Val Acc: 0.0213
# Epoch 02 | Val Acc: 0.1809
# Epoch 03 | Val Acc: 0.3266
# Epoch 04 | Val Acc: 0.4521
# Epoch 05 | Val Acc: 0.4617
# Epoch 06 | Val Acc: 0.6245
# Epoch 07 | Val Acc: 0.6713
# Epoch 08 | Val Acc: 0.7479
# Epoch 09 | Val Acc: 0.7117
# Epoch 10 | Val Acc: 0.7638
# Epoch 11 | Val Acc: 0.7894
# Epoch 12 | Val Acc: 0.8021
# Epoch 13 | Val Acc: 0.8426
# Epoch 14 | Val Acc: 0.8106
# Epoch 15 | Val Acc: 0.8436
# Epoch 16 | Val Acc: 0.8681
# Epoch 17 | Val Acc: 0.8553
# Epoch 18 | Val Acc: 0.8649
# Epoch 19 | Val Acc: 0.8713
# Epoch 20 | Val Acc: 0.8755
# Epoch 21 | Val Acc: 0.8755
# Epoch 22 | Val Acc: 0.8702
# Epoch 23 | Val Acc: 0.8819
# Epoch 24 | Val Acc: 0.8883
# Epoch 25 | Val Acc: 0.8926
# Epoch 26 | Val Acc: 0.8809
# Epoch 27 | Val Acc: 0.9117
# Epoch 28 | Val Acc: 0.8957
# Epoch 29 | Val Acc: 0.8936
# Epoch 30 | Val Acc: 0.8872
# Epoch 31 | Val Acc: 0.8894
# Epoch 32 | Val Acc: 0.8989
# Epoch 33 | Val Acc: 0.9021
# Epoch 34 | Val Acc: 0.8979
# Epoch 35 | Val Acc: 0.9085
# Epoch 36 | Val Acc: 0.8989
# Epoch 37 | Val Acc: 0.9074
# Early stopping triggered
# Split 9 Accuracy: 0.9117
#
# ===== SPLIT 10 =====
# Epoch 01 | Val Acc: 0.0223
# Epoch 02 | Val Acc: 0.0457
# Epoch 03 | Val Acc: 0.2245
# Epoch 04 | Val Acc: 0.3713
# Epoch 05 | Val Acc: 0.4394
# Epoch 06 | Val Acc: 0.5617
# Epoch 07 | Val Acc: 0.5713
# Epoch 08 | Val Acc: 0.6234
# Epoch 09 | Val Acc: 0.6872
# Epoch 10 | Val Acc: 0.7096
# Epoch 11 | Val Acc: 0.7202
# Epoch 12 | Val Acc: 0.7255
# Epoch 13 | Val Acc: 0.7543
# Epoch 14 | Val Acc: 0.7840
# Epoch 15 | Val Acc: 0.7745
# Epoch 16 | Val Acc: 0.8085
# Epoch 17 | Val Acc: 0.8043
# Epoch 18 | Val Acc: 0.8138
# Epoch 19 | Val Acc: 0.8053
# Epoch 20 | Val Acc: 0.8138
# Epoch 21 | Val Acc: 0.8351
# Epoch 22 | Val Acc: 0.8245
# Epoch 23 | Val Acc: 0.8404
# Epoch 24 | Val Acc: 0.8415
# Epoch 25 | Val Acc: 0.8266
# Epoch 26 | Val Acc: 0.8426
# Epoch 27 | Val Acc: 0.8436
# Epoch 28 | Val Acc: 0.8457
# Epoch 29 | Val Acc: 0.8447
# Epoch 30 | Val Acc: 0.8543
# Epoch 31 | Val Acc: 0.8628
# Epoch 32 | Val Acc: 0.8681
# Epoch 33 | Val Acc: 0.8734
# Epoch 34 | Val Acc: 0.8713
# Epoch 35 | Val Acc: 0.8606
# Epoch 36 | Val Acc: 0.8702
# Epoch 37 | Val Acc: 0.8404
# Epoch 38 | Val Acc: 0.8638
# Epoch 39 | Val Acc: 0.8447
# Epoch 40 | Val Acc: 0.8713
# Epoch 41 | Val Acc: 0.8617
# Epoch 42 | Val Acc: 0.8638
# Epoch 43 | Val Acc: 0.8660
# Early stopping triggered
# Split 10 Accuracy: 0.8734
#
# FINAL AVERAGE ACCURACY: 0.9041489361702129
