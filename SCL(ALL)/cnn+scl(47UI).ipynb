# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.optim import Adam
from pytorch_metric_learning.losses import SupConLoss

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

NUM_CLASSES = 47   
class EMGDataset(Dataset):
    def __init__(self, x_path, y_path):
        self.X = np.load(x_path)
        self.y = np.argmax(np.load(y_path), axis=1)  

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return (
            torch.tensor(self.X[idx], dtype=torch.float32),
            torch.tensor(self.y[idx], dtype=torch.long)
        )

class CNNEncoder(nn.Module):
    def __init__(self, emb_dim=256):
        super().__init__()

        self.features = nn.Sequential(
            nn.Conv1d(6, 64, kernel_size=10),
            nn.ReLU(),
            nn.Conv1d(64, 64, kernel_size=10),
            nn.ReLU(),
            nn.MaxPool1d(3),

            nn.Conv1d(64, 256, kernel_size=10),
            nn.ReLU(),
            nn.Conv1d(256, 256, kernel_size=10),
            nn.ReLU(),

            nn.AdaptiveAvgPool1d(1)
        )

        self.fc = nn.Linear(256, emb_dim)

    def forward(self, x):
        x = x.permute(0, 2, 1)  
        x = self.features(x).squeeze(-1)
        z = self.fc(x)
        return z
    
class Classifier(nn.Module):
    def __init__(self, emb_dim=256, num_classes=NUM_CLASSES):
        super().__init__()
        self.fc = nn.Linear(emb_dim, num_classes)

    def forward(self, z):
        return self.fc(z)

class FullModel(nn.Module):
    def __init__(self, emb_dim=256, num_classes=NUM_CLASSES):
        super().__init__()
        self.encoder = CNNEncoder(emb_dim)
        self.classifier = Classifier(emb_dim, num_classes)

    def forward(self, x):
        z = self.encoder(x)
        logits = self.classifier(z)
        return z, logits

class EarlyStopping:
    def __init__(self, patience=10):
        self.patience = patience
        self.best_acc = -1
        self.counter = 0
        self.best_state = None

    def step(self, acc, model):
        if acc > self.best_acc:
            self.best_acc = acc
            self.best_state = {k: v.cpu() for k, v in model.state_dict().items()}
            self.counter = 0
            return False
        else:
            self.counter += 1
            return self.counter >= self.patience

    def restore(self, model):
        model.load_state_dict(self.best_state)

def train_and_eval(
    model,
    train_loader,
    test_loader,
    supcon_loss,
    alpha=0.5,
    epochs=500,
    patience=10
):
    ce_loss = nn.CrossEntropyLoss()
    optimizer = Adam(model.parameters(), lr=5e-4)
    stopper = EarlyStopping(patience)

    for epoch in range(epochs):
        model.train()
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)

            z, logits = model(x)

            z_norm = F.normalize(z, dim=1)  
            loss = ce_loss(logits, y) + alpha * supcon_loss(z_norm, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        model.eval()
        correct, total = 0, 0
        with torch.no_grad():
            for x, y in test_loader:
                x, y = x.to(device), y.to(device)
                _, logits = model(x)
                pred = logits.argmax(dim=1)
                correct += (pred == y).sum().item()
                total += y.size(0)

        acc = correct / total
        print(f"Epoch {epoch+1:02d} | Val Acc: {acc:.4f}")

        if stopper.step(acc, model):
            print("Early stopping triggered")
            break

    stopper.restore(model)
    return stopper.best_acc

BASE = "models/Data/Data/47_classes/UserInDependenet"  
supcon_loss = SupConLoss(temperature=0.1)

all_accs = []

for split in range(1, 20):
    print(f"\n===== SPLIT {split} =====")

    train_ds = EMGDataset(
        f"{BASE}/Train/X_train_{split}.npy",
        f"{BASE}/Train/y_train_{split}.npy"
    )
    test_ds = EMGDataset(
        f"{BASE}/Test/X_test_{split}.npy",
        f"{BASE}/Test/y_test_{split}.npy"
    )

    train_loader = DataLoader(train_ds, batch_size=128, shuffle=True)
    test_loader = DataLoader(test_ds, batch_size=128, shuffle=False)

    model = FullModel(
        emb_dim=256,
        num_classes=NUM_CLASSES
    ).to(device)

    acc = train_and_eval(
        model,
        train_loader,
        test_loader,
        supcon_loss,
        alpha=1.0,
        epochs=500,
        patience=10
    )

    print(f"Split {split} Accuracy: {acc:.4f}")
    all_accs.append(acc)

print("\nFINAL AVERAGE ACCURACY:", np.mean(all_accs))
# Out:
# Device: cuda
#
# ===== SPLIT 1 =====
# Epoch 01 | Val Acc: 0.0489
# Epoch 02 | Val Acc: 0.2957
# Epoch 03 | Val Acc: 0.4574
# Epoch 04 | Val Acc: 0.5574
# Epoch 05 | Val Acc: 0.5766
# Epoch 06 | Val Acc: 0.5936
# Epoch 07 | Val Acc: 0.6511
# Epoch 08 | Val Acc: 0.7043
# Epoch 09 | Val Acc: 0.7085
# Epoch 10 | Val Acc: 0.7234
# Epoch 11 | Val Acc: 0.7298
# Epoch 12 | Val Acc: 0.7234
# Epoch 13 | Val Acc: 0.7426
# Epoch 14 | Val Acc: 0.7468
# Epoch 15 | Val Acc: 0.7277
# Epoch 16 | Val Acc: 0.7362
# Epoch 17 | Val Acc: 0.7532
# Epoch 18 | Val Acc: 0.7468
# Epoch 19 | Val Acc: 0.7426
# Epoch 20 | Val Acc: 0.7511
# Epoch 21 | Val Acc: 0.7447
# Epoch 22 | Val Acc: 0.7511
# Epoch 23 | Val Acc: 0.7362
# Epoch 24 | Val Acc: 0.7660
# Epoch 25 | Val Acc: 0.7617
# Epoch 26 | Val Acc: 0.7553
# Epoch 27 | Val Acc: 0.7489
# Epoch 28 | Val Acc: 0.7532
# Epoch 29 | Val Acc: 0.7596
# Epoch 30 | Val Acc: 0.7489
# Epoch 31 | Val Acc: 0.7766
# Epoch 32 | Val Acc: 0.7617
# Epoch 33 | Val Acc: 0.7638
# Epoch 34 | Val Acc: 0.7617
# Epoch 35 | Val Acc: 0.7617
# Epoch 36 | Val Acc: 0.7617
# Epoch 37 | Val Acc: 0.7638
# Epoch 38 | Val Acc: 0.7489
# Epoch 39 | Val Acc: 0.7787
# Epoch 40 | Val Acc: 0.7489
# Epoch 41 | Val Acc: 0.7574
# Epoch 42 | Val Acc: 0.7319
# Epoch 43 | Val Acc: 0.7681
# Epoch 44 | Val Acc: 0.7532
# Epoch 45 | Val Acc: 0.7766
# Epoch 46 | Val Acc: 0.7702
# Epoch 47 | Val Acc: 0.7511
# Epoch 48 | Val Acc: 0.7489
# Epoch 49 | Val Acc: 0.6681
# Early stopping triggered
# Split 1 Accuracy: 0.7787
#
# ===== SPLIT 2 =====
# Epoch 01 | Val Acc: 0.0404
# Epoch 02 | Val Acc: 0.1021
# Epoch 03 | Val Acc: 0.2000
# Epoch 04 | Val Acc: 0.3511
# Epoch 05 | Val Acc: 0.3745
# Epoch 06 | Val Acc: 0.4191
# Epoch 07 | Val Acc: 0.4617
# Epoch 08 | Val Acc: 0.4532
# Epoch 09 | Val Acc: 0.5021
# Epoch 10 | Val Acc: 0.5000
# Epoch 11 | Val Acc: 0.5191
# Epoch 12 | Val Acc: 0.5319
# Epoch 13 | Val Acc: 0.5404
# Epoch 14 | Val Acc: 0.5936
# Epoch 15 | Val Acc: 0.5340
# Epoch 16 | Val Acc: 0.5957
# Epoch 17 | Val Acc: 0.5681
# Epoch 18 | Val Acc: 0.5702
# Epoch 19 | Val Acc: 0.5745
# Epoch 20 | Val Acc: 0.5894
# Epoch 21 | Val Acc: 0.5681
# Epoch 22 | Val Acc: 0.5404
# Epoch 23 | Val Acc: 0.5468
# Epoch 24 | Val Acc: 0.5638
# Epoch 25 | Val Acc: 0.5596
# Epoch 26 | Val Acc: 0.5766
# Early stopping triggered
# Split 2 Accuracy: 0.5957
#
# ===== SPLIT 3 =====
# Epoch 01 | Val Acc: 0.0298
# Epoch 02 | Val Acc: 0.2319
# Epoch 03 | Val Acc: 0.3596
# Epoch 04 | Val Acc: 0.4468
# Epoch 05 | Val Acc: 0.5085
# Epoch 06 | Val Acc: 0.5681
# Epoch 07 | Val Acc: 0.5596
# Epoch 08 | Val Acc: 0.6404
# Epoch 09 | Val Acc: 0.5957
# Epoch 10 | Val Acc: 0.6234
# Epoch 11 | Val Acc: 0.5723
# Epoch 12 | Val Acc: 0.6298
# Epoch 13 | Val Acc: 0.6255
# Epoch 14 | Val Acc: 0.6617
# Epoch 15 | Val Acc: 0.6064
# Epoch 16 | Val Acc: 0.6319
# Epoch 17 | Val Acc: 0.6298
# Epoch 18 | Val Acc: 0.6660
# Epoch 19 | Val Acc: 0.6298
# Epoch 20 | Val Acc: 0.6426
# Epoch 21 | Val Acc: 0.6809
# Epoch 22 | Val Acc: 0.6298
# Epoch 23 | Val Acc: 0.6574
# Epoch 24 | Val Acc: 0.6574
# Epoch 25 | Val Acc: 0.6426
# Epoch 26 | Val Acc: 0.6532
# Epoch 27 | Val Acc: 0.6766
# Epoch 28 | Val Acc: 0.6319
# Epoch 29 | Val Acc: 0.6532
# Epoch 30 | Val Acc: 0.6404
# Epoch 31 | Val Acc: 0.6489
# Early stopping triggered
# Split 3 Accuracy: 0.6809
#
# ===== SPLIT 4 =====
# Epoch 01 | Val Acc: 0.0255
# Epoch 02 | Val Acc: 0.1511
# Epoch 03 | Val Acc: 0.3191
# Epoch 04 | Val Acc: 0.4000
# Epoch 05 | Val Acc: 0.5319
# Epoch 06 | Val Acc: 0.5702
# Epoch 07 | Val Acc: 0.6170
# Epoch 08 | Val Acc: 0.6638
# Epoch 09 | Val Acc: 0.6851
# Epoch 10 | Val Acc: 0.6894
# Epoch 11 | Val Acc: 0.6957
# Epoch 12 | Val Acc: 0.6915
# Epoch 13 | Val Acc: 0.7128
# Epoch 14 | Val Acc: 0.7191
# Epoch 15 | Val Acc: 0.6426
# Epoch 16 | Val Acc: 0.7170
# Epoch 17 | Val Acc: 0.7362
# Epoch 18 | Val Acc: 0.7340
# Epoch 19 | Val Acc: 0.7489
# Epoch 20 | Val Acc: 0.7362
# Epoch 21 | Val Acc: 0.7447
# Epoch 22 | Val Acc: 0.7362
# Epoch 23 | Val Acc: 0.7404
# Epoch 24 | Val Acc: 0.7191
# Epoch 25 | Val Acc: 0.7043
# Epoch 26 | Val Acc: 0.7085
# Epoch 27 | Val Acc: 0.7298
# Epoch 28 | Val Acc: 0.7170
# Epoch 29 | Val Acc: 0.6915
# Early stopping triggered
# Split 4 Accuracy: 0.7489
#
# ===== SPLIT 5 =====
# Epoch 01 | Val Acc: 0.0468
# Epoch 02 | Val Acc: 0.1532
# Epoch 03 | Val Acc: 0.1894
# Epoch 04 | Val Acc: 0.3277
# Epoch 05 | Val Acc: 0.4340
# Epoch 06 | Val Acc: 0.3851
# Epoch 07 | Val Acc: 0.4277
# Epoch 08 | Val Acc: 0.4894
# Epoch 09 | Val Acc: 0.4872
# Epoch 10 | Val Acc: 0.4894
# Epoch 11 | Val Acc: 0.5234
# Epoch 12 | Val Acc: 0.5000
# Epoch 13 | Val Acc: 0.5191
# Epoch 14 | Val Acc: 0.5511
# Epoch 15 | Val Acc: 0.5404
# Epoch 16 | Val Acc: 0.5319
# Epoch 17 | Val Acc: 0.5426
# Epoch 18 | Val Acc: 0.5468
# Epoch 19 | Val Acc: 0.5638
# Epoch 20 | Val Acc: 0.5596
# Epoch 21 | Val Acc: 0.5617
# Epoch 22 | Val Acc: 0.5553
# Epoch 23 | Val Acc: 0.5532
# Epoch 24 | Val Acc: 0.5489
# Epoch 25 | Val Acc: 0.6000
# Epoch 26 | Val Acc: 0.5553
# Epoch 27 | Val Acc: 0.5532
# Epoch 28 | Val Acc: 0.5638
# Epoch 29 | Val Acc: 0.5936
# Epoch 30 | Val Acc: 0.5809
# Epoch 31 | Val Acc: 0.5723
# Epoch 32 | Val Acc: 0.5638
# Epoch 33 | Val Acc: 0.5617
# Epoch 34 | Val Acc: 0.5617
# Epoch 35 | Val Acc: 0.5553
# Early stopping triggered
# Split 5 Accuracy: 0.6000
#
# ===== SPLIT 6 =====
# Epoch 01 | Val Acc: 0.0426
# Epoch 02 | Val Acc: 0.2021
# Epoch 03 | Val Acc: 0.3085
# Epoch 04 | Val Acc: 0.5383
# Epoch 05 | Val Acc: 0.4723
# Epoch 06 | Val Acc: 0.6234
# Epoch 07 | Val Acc: 0.6638
# Epoch 08 | Val Acc: 0.6957
# Epoch 09 | Val Acc: 0.7404
# Epoch 10 | Val Acc: 0.7319
# Epoch 11 | Val Acc: 0.7234
# Epoch 12 | Val Acc: 0.7064
# Epoch 13 | Val Acc: 0.7255
# Epoch 14 | Val Acc: 0.7319
# Epoch 15 | Val Acc: 0.7064
# Epoch 16 | Val Acc: 0.7277
# Epoch 17 | Val Acc: 0.7149
# Epoch 18 | Val Acc: 0.7213
# Epoch 19 | Val Acc: 0.7255
# Early stopping triggered
# Split 6 Accuracy: 0.7404
#
# ===== SPLIT 7 =====
# Epoch 01 | Val Acc: 0.0404
# Epoch 02 | Val Acc: 0.1702
# Epoch 03 | Val Acc: 0.3234
# Epoch 04 | Val Acc: 0.4574
# Epoch 05 | Val Acc: 0.4936
# Epoch 06 | Val Acc: 0.4170
# Epoch 07 | Val Acc: 0.4553
# Epoch 08 | Val Acc: 0.3702
# Epoch 09 | Val Acc: 0.5064
# Epoch 10 | Val Acc: 0.4872
# Epoch 11 | Val Acc: 0.4702
# Epoch 12 | Val Acc: 0.5362
# Epoch 13 | Val Acc: 0.5106
# Epoch 14 | Val Acc: 0.5191
# Epoch 15 | Val Acc: 0.5340
# Epoch 16 | Val Acc: 0.5660
# Epoch 17 | Val Acc: 0.5255
# Epoch 18 | Val Acc: 0.5021
# Epoch 19 | Val Acc: 0.5532
# Epoch 20 | Val Acc: 0.5362
# Epoch 21 | Val Acc: 0.5319
# Epoch 22 | Val Acc: 0.5128
# Epoch 23 | Val Acc: 0.5043
# Epoch 24 | Val Acc: 0.5319
# Epoch 25 | Val Acc: 0.5191
# Epoch 26 | Val Acc: 0.5340
# Early stopping triggered
# Split 7 Accuracy: 0.5660
#
# ===== SPLIT 8 =====
# Epoch 01 | Val Acc: 0.0404
# Epoch 02 | Val Acc: 0.0702
# Epoch 03 | Val Acc: 0.2362
# Epoch 04 | Val Acc: 0.3170
# Epoch 05 | Val Acc: 0.4085
# Epoch 06 | Val Acc: 0.4043
# Epoch 07 | Val Acc: 0.4383
# Epoch 08 | Val Acc: 0.4213
# Epoch 09 | Val Acc: 0.4851
# Epoch 10 | Val Acc: 0.4830
# Epoch 11 | Val Acc: 0.4106
# Epoch 12 | Val Acc: 0.5702
# Epoch 13 | Val Acc: 0.5383
# Epoch 14 | Val Acc: 0.5191
# Epoch 15 | Val Acc: 0.4362
# Epoch 16 | Val Acc: 0.4681
# Epoch 17 | Val Acc: 0.4340
# Epoch 18 | Val Acc: 0.4234
# Epoch 19 | Val Acc: 0.4255
# Epoch 20 | Val Acc: 0.4723
# Epoch 21 | Val Acc: 0.4702
# Epoch 22 | Val Acc: 0.4553
# Early stopping triggered
# Split 8 Accuracy: 0.5702
#
# ===== SPLIT 9 =====
# Epoch 01 | Val Acc: 0.0404
# Epoch 02 | Val Acc: 0.1255
# Epoch 03 | Val Acc: 0.2362
# Epoch 04 | Val Acc: 0.2532
# Epoch 05 | Val Acc: 0.4170
# Epoch 06 | Val Acc: 0.4574
# Epoch 07 | Val Acc: 0.4532
# Epoch 08 | Val Acc: 0.5596
# Epoch 09 | Val Acc: 0.5043
# Epoch 10 | Val Acc: 0.5447
# Epoch 11 | Val Acc: 0.5404
# Epoch 12 | Val Acc: 0.5447
# Epoch 13 | Val Acc: 0.6170
# Epoch 14 | Val Acc: 0.5702
# Epoch 15 | Val Acc: 0.5915
# Epoch 16 | Val Acc: 0.5809
# Epoch 17 | Val Acc: 0.5872
# Epoch 18 | Val Acc: 0.5766
# Epoch 19 | Val Acc: 0.5851
# Epoch 20 | Val Acc: 0.6021
# Epoch 21 | Val Acc: 0.5809
# Epoch 22 | Val Acc: 0.5702
# Epoch 23 | Val Acc: 0.6149
# Early stopping triggered
# Split 9 Accuracy: 0.6170
#
# ===== SPLIT 10 =====
# Epoch 01 | Val Acc: 0.0340
# Epoch 02 | Val Acc: 0.1000
# Epoch 03 | Val Acc: 0.2574
# Epoch 04 | Val Acc: 0.3681
# Epoch 05 | Val Acc: 0.4830
# Epoch 06 | Val Acc: 0.5574
# Epoch 07 | Val Acc: 0.5809
# Epoch 08 | Val Acc: 0.5851
# Epoch 09 | Val Acc: 0.6234
# Epoch 10 | Val Acc: 0.6128
# Epoch 11 | Val Acc: 0.6681
# Epoch 12 | Val Acc: 0.6383
# Epoch 13 | Val Acc: 0.7021
# Epoch 14 | Val Acc: 0.6404
# Epoch 15 | Val Acc: 0.7106
# Epoch 16 | Val Acc: 0.7213
# Epoch 17 | Val Acc: 0.6617
# Epoch 18 | Val Acc: 0.6489
# Epoch 19 | Val Acc: 0.6787
# Epoch 20 | Val Acc: 0.6745
# Epoch 21 | Val Acc: 0.6936
# Epoch 22 | Val Acc: 0.6957
# Epoch 23 | Val Acc: 0.7106
# Epoch 24 | Val Acc: 0.6894
# Epoch 25 | Val Acc: 0.7064
# Epoch 26 | Val Acc: 0.7085
# Early stopping triggered
# Split 10 Accuracy: 0.7213
#
# ===== SPLIT 11 =====
# Epoch 01 | Val Acc: 0.0213
# Epoch 02 | Val Acc: 0.0660
# Epoch 03 | Val Acc: 0.1043
# Epoch 04 | Val Acc: 0.2298
# Epoch 05 | Val Acc: 0.3745
# Epoch 06 | Val Acc: 0.4787
# Epoch 07 | Val Acc: 0.5213
# Epoch 08 | Val Acc: 0.5298
# Epoch 09 | Val Acc: 0.6191
# Epoch 10 | Val Acc: 0.6277
# Epoch 11 | Val Acc: 0.6213
# Epoch 12 | Val Acc: 0.6894
# Epoch 13 | Val Acc: 0.6851
# Epoch 14 | Val Acc: 0.7128
# Epoch 15 | Val Acc: 0.7064
# Epoch 16 | Val Acc: 0.7170
# Epoch 17 | Val Acc: 0.7234
# Epoch 18 | Val Acc: 0.6787
# Epoch 19 | Val Acc: 0.7149
# Epoch 20 | Val Acc: 0.7255
# Epoch 21 | Val Acc: 0.7319
# Epoch 22 | Val Acc: 0.7426
# Epoch 23 | Val Acc: 0.7106
# Epoch 24 | Val Acc: 0.7043
# Epoch 25 | Val Acc: 0.7170
# Epoch 26 | Val Acc: 0.6936
# Epoch 27 | Val Acc: 0.7340
# Epoch 28 | Val Acc: 0.6936
# Epoch 29 | Val Acc: 0.7043
# Epoch 30 | Val Acc: 0.6915
# Epoch 31 | Val Acc: 0.7149
# Epoch 32 | Val Acc: 0.7170
# Early stopping triggered
# Split 11 Accuracy: 0.7426
#
# ===== SPLIT 12 =====
# Epoch 01 | Val Acc: 0.0234
# Epoch 02 | Val Acc: 0.0915
# Epoch 03 | Val Acc: 0.2638
# Epoch 04 | Val Acc: 0.4596
# Epoch 05 | Val Acc: 0.5340
# Epoch 06 | Val Acc: 0.6128
# Epoch 07 | Val Acc: 0.6553
# Epoch 08 | Val Acc: 0.6936
# Epoch 09 | Val Acc: 0.7149
# Epoch 10 | Val Acc: 0.7000
# Epoch 11 | Val Acc: 0.7191
# Epoch 12 | Val Acc: 0.7617
# Epoch 13 | Val Acc: 0.7532
# Epoch 14 | Val Acc: 0.7723
# Epoch 15 | Val Acc: 0.7553
# Epoch 16 | Val Acc: 0.7872
# Epoch 17 | Val Acc: 0.7660
# Epoch 18 | Val Acc: 0.8043
# Epoch 19 | Val Acc: 0.7915
# Epoch 20 | Val Acc: 0.8064
# Epoch 21 | Val Acc: 0.8213
# Epoch 22 | Val Acc: 0.7915
# Epoch 23 | Val Acc: 0.8170
# Epoch 24 | Val Acc: 0.7894
# Epoch 25 | Val Acc: 0.8234
# Epoch 26 | Val Acc: 0.7809
# Epoch 27 | Val Acc: 0.8362
# Epoch 28 | Val Acc: 0.7830
# Epoch 29 | Val Acc: 0.8255
# Epoch 30 | Val Acc: 0.8106
# Epoch 31 | Val Acc: 0.8255
# Epoch 32 | Val Acc: 0.8383
# Epoch 33 | Val Acc: 0.7894
# Epoch 34 | Val Acc: 0.8234
# Epoch 35 | Val Acc: 0.8447
# Epoch 36 | Val Acc: 0.8064
# Epoch 37 | Val Acc: 0.8043
# Epoch 38 | Val Acc: 0.8277
# Epoch 39 | Val Acc: 0.8298
# Epoch 40 | Val Acc: 0.8149
# Epoch 41 | Val Acc: 0.8277
# Epoch 42 | Val Acc: 0.8213
# Epoch 43 | Val Acc: 0.8340
# Epoch 44 | Val Acc: 0.8468
# Epoch 45 | Val Acc: 0.8234
# Epoch 46 | Val Acc: 0.8234
# Epoch 47 | Val Acc: 0.8298
# Epoch 48 | Val Acc: 0.8213
# Epoch 49 | Val Acc: 0.8340
# Epoch 50 | Val Acc: 0.8383
# Epoch 51 | Val Acc: 0.8191
# Epoch 52 | Val Acc: 0.8319
# Epoch 53 | Val Acc: 0.8404
# Epoch 54 | Val Acc: 0.8383
# Early stopping triggered
# Split 12 Accuracy: 0.8468
#
# ===== SPLIT 13 =====
# Epoch 01 | Val Acc: 0.0298
# Epoch 02 | Val Acc: 0.1319
# Epoch 03 | Val Acc: 0.2702
# Epoch 04 | Val Acc: 0.5234
# Epoch 05 | Val Acc: 0.5617
# Epoch 06 | Val Acc: 0.5957
# Epoch 07 | Val Acc: 0.6106
# Epoch 08 | Val Acc: 0.6277
# Epoch 09 | Val Acc: 0.6766
# Epoch 10 | Val Acc: 0.7021
# Epoch 11 | Val Acc: 0.7021
# Epoch 12 | Val Acc: 0.7064
# Epoch 13 | Val Acc: 0.7277
# Epoch 14 | Val Acc: 0.7191
# Epoch 15 | Val Acc: 0.7319
# Epoch 16 | Val Acc: 0.7021
# Epoch 17 | Val Acc: 0.7426
# Epoch 18 | Val Acc: 0.7809
# Epoch 19 | Val Acc: 0.7213
# Epoch 20 | Val Acc: 0.7213
# Epoch 21 | Val Acc: 0.7340
# Epoch 22 | Val Acc: 0.7468
# Epoch 23 | Val Acc: 0.7702
# Epoch 24 | Val Acc: 0.7596
# Epoch 25 | Val Acc: 0.7638
# Epoch 26 | Val Acc: 0.7745
# Epoch 27 | Val Acc: 0.7532
# Epoch 28 | Val Acc: 0.7574
# Early stopping triggered
# Split 13 Accuracy: 0.7809
#
# ===== SPLIT 14 =====
# Epoch 01 | Val Acc: 0.0319
# Epoch 02 | Val Acc: 0.0957
# Epoch 03 | Val Acc: 0.1383
# Epoch 04 | Val Acc: 0.2468
# Epoch 05 | Val Acc: 0.2404
# Epoch 06 | Val Acc: 0.2936
# Epoch 07 | Val Acc: 0.3574
# Epoch 08 | Val Acc: 0.3149
# Epoch 09 | Val Acc: 0.3255
# Epoch 10 | Val Acc: 0.3234
# Epoch 11 | Val Acc: 0.3766
# Epoch 12 | Val Acc: 0.3489
# Epoch 13 | Val Acc: 0.3638
# Epoch 14 | Val Acc: 0.3298
# Epoch 15 | Val Acc: 0.3404
# Epoch 16 | Val Acc: 0.3574
# Epoch 17 | Val Acc: 0.4000
# Epoch 18 | Val Acc: 0.3489
# Epoch 19 | Val Acc: 0.3468
# Epoch 20 | Val Acc: 0.3170
# Epoch 21 | Val Acc: 0.3362
# Epoch 22 | Val Acc: 0.3085
# Epoch 23 | Val Acc: 0.3106
# Epoch 24 | Val Acc: 0.3000
# Epoch 25 | Val Acc: 0.3511
# Epoch 26 | Val Acc: 0.3043
# Epoch 27 | Val Acc: 0.3319
# Early stopping triggered
# Split 14 Accuracy: 0.4000
#
# ===== SPLIT 15 =====
# Epoch 01 | Val Acc: 0.0213
# Epoch 02 | Val Acc: 0.1043
# Epoch 03 | Val Acc: 0.3170
# Epoch 04 | Val Acc: 0.3936
# Epoch 05 | Val Acc: 0.4553
# Epoch 06 | Val Acc: 0.5128
# Epoch 07 | Val Acc: 0.5894
# Epoch 08 | Val Acc: 0.5809
# Epoch 09 | Val Acc: 0.5936
# Epoch 10 | Val Acc: 0.6043
# Epoch 11 | Val Acc: 0.6170
# Epoch 12 | Val Acc: 0.6553
# Epoch 13 | Val Acc: 0.7085
# Epoch 14 | Val Acc: 0.6745
# Epoch 15 | Val Acc: 0.6574
# Epoch 16 | Val Acc: 0.6894
# Epoch 17 | Val Acc: 0.6745
# Epoch 18 | Val Acc: 0.7149
# Epoch 19 | Val Acc: 0.6894
# Epoch 20 | Val Acc: 0.6872
# Epoch 21 | Val Acc: 0.7234
# Epoch 22 | Val Acc: 0.7191
# Epoch 23 | Val Acc: 0.7319
# Epoch 24 | Val Acc: 0.7043
# Epoch 25 | Val Acc: 0.7000
# Epoch 26 | Val Acc: 0.7298
# Epoch 27 | Val Acc: 0.7043
# Epoch 28 | Val Acc: 0.7064
# Epoch 29 | Val Acc: 0.7340
# Epoch 30 | Val Acc: 0.7319
# Epoch 31 | Val Acc: 0.7128
# Epoch 32 | Val Acc: 0.7298
# Epoch 33 | Val Acc: 0.7255
# Epoch 34 | Val Acc: 0.7340
# Epoch 35 | Val Acc: 0.7447
# Epoch 36 | Val Acc: 0.7447
# Epoch 37 | Val Acc: 0.7489
# Epoch 38 | Val Acc: 0.7362
# Epoch 39 | Val Acc: 0.7298
# Epoch 40 | Val Acc: 0.7426
# Epoch 41 | Val Acc: 0.7468
# Epoch 42 | Val Acc: 0.7511
# Epoch 43 | Val Acc: 0.7702
# Epoch 44 | Val Acc: 0.7340
# Epoch 45 | Val Acc: 0.7298
# Epoch 46 | Val Acc: 0.7255
# Epoch 47 | Val Acc: 0.7277
# Epoch 48 | Val Acc: 0.7383
# Epoch 49 | Val Acc: 0.7298
# Epoch 50 | Val Acc: 0.7362
# Epoch 51 | Val Acc: 0.7191
# Epoch 52 | Val Acc: 0.7511
# Epoch 53 | Val Acc: 0.7468
# Early stopping triggered
# Split 15 Accuracy: 0.7702
#
# ===== SPLIT 16 =====
# Epoch 01 | Val Acc: 0.0149
# Epoch 02 | Val Acc: 0.1085
# Epoch 03 | Val Acc: 0.3234
# Epoch 04 | Val Acc: 0.4787
# Epoch 05 | Val Acc: 0.5745
# Epoch 06 | Val Acc: 0.6957
# Epoch 07 | Val Acc: 0.7340
# Epoch 08 | Val Acc: 0.7617
# Epoch 09 | Val Acc: 0.7553
# Epoch 10 | Val Acc: 0.7851
# Epoch 11 | Val Acc: 0.7894
# Epoch 12 | Val Acc: 0.7809
# Epoch 13 | Val Acc: 0.8128
# Epoch 14 | Val Acc: 0.8213
# Epoch 15 | Val Acc: 0.8043
# Epoch 16 | Val Acc: 0.8021
# Epoch 17 | Val Acc: 0.7979
# Epoch 18 | Val Acc: 0.8340
# Epoch 19 | Val Acc: 0.8000
# Epoch 20 | Val Acc: 0.8319
# Epoch 21 | Val Acc: 0.8191
# Epoch 22 | Val Acc: 0.8021
# Epoch 23 | Val Acc: 0.8234
# Epoch 24 | Val Acc: 0.8234
# Epoch 25 | Val Acc: 0.8489
# Epoch 26 | Val Acc: 0.8277
# Epoch 27 | Val Acc: 0.8213
# Epoch 28 | Val Acc: 0.8340
# Epoch 29 | Val Acc: 0.8532
# Epoch 30 | Val Acc: 0.8319
# Epoch 31 | Val Acc: 0.8426
# Epoch 32 | Val Acc: 0.8574
# Epoch 33 | Val Acc: 0.8234
# Epoch 34 | Val Acc: 0.8404
# Epoch 35 | Val Acc: 0.8468
# Epoch 36 | Val Acc: 0.8489
# Epoch 37 | Val Acc: 0.8447
# Epoch 38 | Val Acc: 0.8319
# Epoch 39 | Val Acc: 0.8362
# Epoch 40 | Val Acc: 0.8404
# Epoch 41 | Val Acc: 0.8362
# Epoch 42 | Val Acc: 0.8277
# Early stopping triggered
# Split 16 Accuracy: 0.8574
#
# ===== SPLIT 17 =====
# Epoch 01 | Val Acc: 0.0702
# Epoch 02 | Val Acc: 0.2255
# Epoch 03 | Val Acc: 0.3319
# Epoch 04 | Val Acc: 0.5000
# Epoch 05 | Val Acc: 0.5128
# Epoch 06 | Val Acc: 0.6319
# Epoch 07 | Val Acc: 0.6128
# Epoch 08 | Val Acc: 0.6574
# Epoch 09 | Val Acc: 0.7468
# Epoch 10 | Val Acc: 0.7489
# Epoch 11 | Val Acc: 0.7638
# Epoch 12 | Val Acc: 0.7234
# Epoch 13 | Val Acc: 0.7723
# Epoch 14 | Val Acc: 0.7298
# Epoch 15 | Val Acc: 0.7340
# Epoch 16 | Val Acc: 0.8128
# Epoch 17 | Val Acc: 0.7660
# Epoch 18 | Val Acc: 0.7787
# Epoch 19 | Val Acc: 0.7851
# Epoch 20 | Val Acc: 0.7851
# Epoch 21 | Val Acc: 0.8128
# Epoch 22 | Val Acc: 0.7617
# Epoch 23 | Val Acc: 0.7553
# Epoch 24 | Val Acc: 0.7872
# Epoch 25 | Val Acc: 0.7830
# Epoch 26 | Val Acc: 0.8106
# Early stopping triggered
# Split 17 Accuracy: 0.8128
#
# ===== SPLIT 18 =====
# Epoch 01 | Val Acc: 0.0426
# Epoch 02 | Val Acc: 0.1830
# Epoch 03 | Val Acc: 0.4255
# Epoch 04 | Val Acc: 0.4809
# Epoch 05 | Val Acc: 0.5468
# Epoch 06 | Val Acc: 0.6447
# Epoch 07 | Val Acc: 0.6043
# Epoch 08 | Val Acc: 0.6596
# Epoch 09 | Val Acc: 0.6957
# Epoch 10 | Val Acc: 0.7447
# Epoch 11 | Val Acc: 0.7213
# Epoch 12 | Val Acc: 0.6979
# Epoch 13 | Val Acc: 0.7170
# Epoch 14 | Val Acc: 0.7021
# Epoch 15 | Val Acc: 0.7213
# Epoch 16 | Val Acc: 0.7085
# Epoch 17 | Val Acc: 0.7426
# Epoch 18 | Val Acc: 0.7766
# Epoch 19 | Val Acc: 0.7106
# Epoch 20 | Val Acc: 0.7468
# Epoch 21 | Val Acc: 0.7255
# Epoch 22 | Val Acc: 0.7340
# Epoch 23 | Val Acc: 0.7191
# Epoch 24 | Val Acc: 0.7277
# Epoch 25 | Val Acc: 0.7723
# Epoch 26 | Val Acc: 0.7745
# Epoch 27 | Val Acc: 0.7426
# Epoch 28 | Val Acc: 0.7170
# Early stopping triggered
# Split 18 Accuracy: 0.7766
#
# ===== SPLIT 19 =====
# Epoch 01 | Val Acc: 0.0191
# Epoch 02 | Val Acc: 0.1617
# Epoch 03 | Val Acc: 0.3064
# Epoch 04 | Val Acc: 0.3574
# Epoch 05 | Val Acc: 0.4383
# Epoch 06 | Val Acc: 0.3979
# Epoch 07 | Val Acc: 0.4255
# Epoch 08 | Val Acc: 0.5532
# Epoch 09 | Val Acc: 0.5468
# Epoch 10 | Val Acc: 0.5596
# Epoch 11 | Val Acc: 0.5106
# Epoch 12 | Val Acc: 0.5660
# Epoch 13 | Val Acc: 0.5468
# Epoch 14 | Val Acc: 0.5638
# Epoch 15 | Val Acc: 0.5745
# Epoch 16 | Val Acc: 0.5362
# Epoch 17 | Val Acc: 0.4702
# Epoch 18 | Val Acc: 0.5277
# Epoch 19 | Val Acc: 0.5894
# Epoch 20 | Val Acc: 0.5234
# Epoch 21 | Val Acc: 0.5191
# Epoch 22 | Val Acc: 0.5830
# Epoch 23 | Val Acc: 0.4489
# Epoch 24 | Val Acc: 0.5383
# Epoch 25 | Val Acc: 0.5426
# Epoch 26 | Val Acc: 0.5234
# Epoch 27 | Val Acc: 0.5191
# Epoch 28 | Val Acc: 0.6021
# Epoch 29 | Val Acc: 0.5936
# Epoch 30 | Val Acc: 0.5468
# Epoch 31 | Val Acc: 0.5426
# Epoch 32 | Val Acc: 0.5340
# Epoch 33 | Val Acc: 0.5596
# Epoch 34 | Val Acc: 0.5702
# Epoch 35 | Val Acc: 0.5404
# Epoch 36 | Val Acc: 0.5447
# Epoch 37 | Val Acc: 0.5234
# Epoch 38 | Val Acc: 0.5574
# Early stopping triggered
# Split 19 Accuracy: 0.6021
#
# FINAL AVERAGE ACCURACY: 0.6951847704367301
