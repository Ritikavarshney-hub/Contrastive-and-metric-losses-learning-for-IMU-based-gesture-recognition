# %%
# ...existing code...
import zipfile
import os
ZIP_PATH = r"C:\Users\Lenovo\Downloads\Data.zip"   # use raw string to avoid \U escape
EXTRACT_PATH = "Data"   

os.makedirs(EXTRACT_PATH, exist_ok=True)

print("Extracting Data.zip...")

with zipfile.ZipFile(ZIP_PATH, "r") as zip_ref:
    zip_ref.extractall(EXTRACT_PATH)

print("Extraction done.")
print("Top-level contents:", os.listdir(EXTRACT_PATH))
# ...existing code...
# Out:
# Extracting Data.zip...
# Extraction done.
# Top-level contents: ['Data', 'datapreprocessing.ipynb']
