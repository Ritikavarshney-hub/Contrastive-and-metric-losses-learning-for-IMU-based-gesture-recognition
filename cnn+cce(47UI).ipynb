# %%
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.optim import Adam

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

class EMGDataset(Dataset):
    def __init__(self, x_path, y_path):
        X = np.load(x_path)        
        y = np.load(y_path)       

        for i in range(X.shape[0]):
            for c in range(X.shape[2]):
                mu = X[i, :, c].mean()
                std = X[i, :, c].std() + 1e-8
                X[i, :, c] = (X[i, :, c] - mu) / std

        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(np.argmax(y, axis=1), dtype=torch.long)

        self.num_classes = y.shape[1]

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

class CNNEncoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv1d(6, 64, kernel_size=10),
            nn.ReLU(),

            nn.Conv1d(64, 64, kernel_size=10),
            nn.ReLU(),
            nn.MaxPool1d(3),

            nn.Conv1d(64, 256, kernel_size=10),
            nn.ReLU(),

            nn.Conv1d(256, 256, kernel_size=10),
            nn.ReLU(),

            nn.AdaptiveAvgPool1d(1)  
        )

    def forward(self, x):
        x = x.permute(0, 2, 1)      
        x = self.net(x)
        return x.squeeze(-1)        

class FullModel(nn.Module):
    def __init__(self, encoder, num_classes):
        super().__init__()
        self.encoder = encoder
        self.classifier = nn.Linear(256, num_classes)

    def forward(self, x):
        emb = self.encoder(x)
        logits = self.classifier(emb)
        return logits

class EarlyStopping:
    def __init__(self, patience=7):
        self.patience = patience
        self.best_acc = 0.0
        self.counter = 0
        self.best_state = None

    def step(self, acc, model):
        if acc > self.best_acc:
            self.best_acc = acc
            self.counter = 0
            self.best_state = {
                k: v.detach().cpu().clone()
                for k, v in model.state_dict().items()
            }
            return False
        else:
            self.counter += 1
            return self.counter >= self.patience

    def restore(self, model):
        model.load_state_dict(self.best_state)

def train_and_eval(model, train_loader, test_loader,
                   epochs=500, patience=7):

    criterion = nn.CrossEntropyLoss()
    optimizer = Adam(model.parameters(), lr=5e-4)
    early_stopper = EarlyStopping(patience)

    for epoch in range(epochs):
        model.train()
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)

            logits = model(x)
            loss = criterion(logits, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        model.eval()
        correct, total = 0, 0
        with torch.no_grad():
            for x, y in test_loader:
                x, y = x.to(device), y.to(device)
                preds = model(x).argmax(dim=1)
                correct += (preds == y).sum().item()
                total += y.size(0)

        val_acc = correct / total
        print(f"Epoch {epoch+1:02d} | Val Acc: {val_acc:.4f}")

        if early_stopper.step(val_acc, model):
            print("Early stopping")
            break

    early_stopper.restore(model)
    return early_stopper.best_acc

NUM_CLASSES = 47    
BASE = f"models/Data/Data/{NUM_CLASSES}_classes/UserInDependenet"

accs = []

for split in range(1,20):
    print(f"\n===== Split {split} =====")

    train_ds = EMGDataset(
        f"{BASE}/Train/X_train_{split}.npy",
        f"{BASE}/Train/y_train_{split}.npy"
    )
    test_ds = EMGDataset(
        f"{BASE}/Test/X_test_{split}.npy",
        f"{BASE}/Test/y_test_{split}.npy"
    )

    train_loader = DataLoader(train_ds, batch_size=128, shuffle=True)
    test_loader = DataLoader(test_ds, batch_size=128)

    model = FullModel(
        CNNEncoder(),
        num_classes=train_ds.num_classes   
    ).to(device)

    acc = train_and_eval(model, train_loader, test_loader)
    accs.append(acc)

    print(f"Best accuracy (split {split}): {acc:.4f}")

print("\nFINAL AVERAGE ACCURACY (CNN + CCE):", np.mean(accs))
# Out:
# Using device: cuda
#
# ===== Split 1 =====
# Epoch 01 | Val Acc: 0.1532
# Epoch 02 | Val Acc: 0.3298
# Epoch 03 | Val Acc: 0.4511
# Epoch 04 | Val Acc: 0.5489
# Epoch 05 | Val Acc: 0.5957
# Epoch 06 | Val Acc: 0.6149
# Epoch 07 | Val Acc: 0.6426
# Epoch 08 | Val Acc: 0.6638
# Epoch 09 | Val Acc: 0.6234
# Epoch 10 | Val Acc: 0.6872
# Epoch 11 | Val Acc: 0.6979
# Epoch 12 | Val Acc: 0.7213
# Epoch 13 | Val Acc: 0.6745
# Epoch 14 | Val Acc: 0.6638
# Epoch 15 | Val Acc: 0.6745
# Epoch 16 | Val Acc: 0.6851
# Epoch 17 | Val Acc: 0.6830
# Epoch 18 | Val Acc: 0.7064
# Epoch 19 | Val Acc: 0.7085
# Early stopping
# Best accuracy (split 1): 0.7213
#
# ===== Split 2 =====
# Epoch 01 | Val Acc: 0.1149
# Epoch 02 | Val Acc: 0.2234
# Epoch 03 | Val Acc: 0.3128
# Epoch 04 | Val Acc: 0.3830
# Epoch 05 | Val Acc: 0.4383
# Epoch 06 | Val Acc: 0.4426
# Epoch 07 | Val Acc: 0.3979
# Epoch 08 | Val Acc: 0.4596
# Epoch 09 | Val Acc: 0.4830
# Epoch 10 | Val Acc: 0.4936
# Epoch 11 | Val Acc: 0.4766
# Epoch 12 | Val Acc: 0.5043
# Epoch 13 | Val Acc: 0.5000
# Epoch 14 | Val Acc: 0.4894
# Epoch 15 | Val Acc: 0.5319
# Epoch 16 | Val Acc: 0.5149
# Epoch 17 | Val Acc: 0.5213
# Epoch 18 | Val Acc: 0.5404
# Epoch 19 | Val Acc: 0.5447
# Epoch 20 | Val Acc: 0.5319
# Epoch 21 | Val Acc: 0.5128
# Epoch 22 | Val Acc: 0.5383
# Epoch 23 | Val Acc: 0.5319
# Epoch 24 | Val Acc: 0.5511
# Epoch 25 | Val Acc: 0.5638
# Epoch 26 | Val Acc: 0.5553
# Epoch 27 | Val Acc: 0.5702
# Epoch 28 | Val Acc: 0.5745
# Epoch 29 | Val Acc: 0.5213
# Epoch 30 | Val Acc: 0.5447
# Epoch 31 | Val Acc: 0.5447
# Epoch 32 | Val Acc: 0.5787
# Epoch 33 | Val Acc: 0.5766
# Epoch 34 | Val Acc: 0.5319
# Epoch 35 | Val Acc: 0.5426
# Epoch 36 | Val Acc: 0.5468
# Epoch 37 | Val Acc: 0.5468
# Epoch 38 | Val Acc: 0.5553
# Epoch 39 | Val Acc: 0.5255
# Early stopping
# Best accuracy (split 2): 0.5787
#
# ===== Split 3 =====
# Epoch 01 | Val Acc: 0.2213
# Epoch 02 | Val Acc: 0.3830
# Epoch 03 | Val Acc: 0.4511
# Epoch 04 | Val Acc: 0.5660
# Epoch 05 | Val Acc: 0.5468
# Epoch 06 | Val Acc: 0.6085
# Epoch 07 | Val Acc: 0.6106
# Epoch 08 | Val Acc: 0.5787
# Epoch 09 | Val Acc: 0.6383
# Epoch 10 | Val Acc: 0.6447
# Epoch 11 | Val Acc: 0.6426
# Epoch 12 | Val Acc: 0.6596
# Epoch 13 | Val Acc: 0.6362
# Epoch 14 | Val Acc: 0.6468
# Epoch 15 | Val Acc: 0.6426
# Epoch 16 | Val Acc: 0.6596
# Epoch 17 | Val Acc: 0.6596
# Epoch 18 | Val Acc: 0.6596
# Epoch 19 | Val Acc: 0.6489
# Early stopping
# Best accuracy (split 3): 0.6596
#
# ===== Split 4 =====
# Epoch 01 | Val Acc: 0.2000
# Epoch 02 | Val Acc: 0.3149
# Epoch 03 | Val Acc: 0.4021
# Epoch 04 | Val Acc: 0.5660
# Epoch 05 | Val Acc: 0.5979
# Epoch 06 | Val Acc: 0.6255
# Epoch 07 | Val Acc: 0.6340
# Epoch 08 | Val Acc: 0.5957
# Epoch 09 | Val Acc: 0.6255
# Epoch 10 | Val Acc: 0.6468
# Epoch 11 | Val Acc: 0.6702
# Epoch 12 | Val Acc: 0.7106
# Epoch 13 | Val Acc: 0.6702
# Epoch 14 | Val Acc: 0.6745
# Epoch 15 | Val Acc: 0.7064
# Epoch 16 | Val Acc: 0.7128
# Epoch 17 | Val Acc: 0.7170
# Epoch 18 | Val Acc: 0.7170
# Epoch 19 | Val Acc: 0.6957
# Epoch 20 | Val Acc: 0.6979
# Epoch 21 | Val Acc: 0.7043
# Epoch 22 | Val Acc: 0.7085
# Epoch 23 | Val Acc: 0.7298
# Epoch 24 | Val Acc: 0.7149
# Epoch 25 | Val Acc: 0.7085
# Epoch 26 | Val Acc: 0.7000
# Epoch 27 | Val Acc: 0.7191
# Epoch 28 | Val Acc: 0.7149
# Epoch 29 | Val Acc: 0.7000
# Epoch 30 | Val Acc: 0.7149
# Early stopping
# Best accuracy (split 4): 0.7298
#
# ===== Split 5 =====
# Epoch 01 | Val Acc: 0.0830
# Epoch 02 | Val Acc: 0.1809
# Epoch 03 | Val Acc: 0.2617
# Epoch 04 | Val Acc: 0.3255
# Epoch 05 | Val Acc: 0.3511
# Epoch 06 | Val Acc: 0.3362
# Epoch 07 | Val Acc: 0.3596
# Epoch 08 | Val Acc: 0.3277
# Epoch 09 | Val Acc: 0.4277
# Epoch 10 | Val Acc: 0.4596
# Epoch 11 | Val Acc: 0.4255
# Epoch 12 | Val Acc: 0.4298
# Epoch 13 | Val Acc: 0.4447
# Epoch 14 | Val Acc: 0.4106
# Epoch 15 | Val Acc: 0.4596
# Epoch 16 | Val Acc: 0.4319
# Epoch 17 | Val Acc: 0.4447
# Early stopping
# Best accuracy (split 5): 0.4596
#
# ===== Split 6 =====
# Epoch 01 | Val Acc: 0.1319
# Epoch 02 | Val Acc: 0.3681
# Epoch 03 | Val Acc: 0.4596
# Epoch 04 | Val Acc: 0.5723
# Epoch 05 | Val Acc: 0.5957
# Epoch 06 | Val Acc: 0.5872
# Epoch 07 | Val Acc: 0.6064
# Epoch 08 | Val Acc: 0.6277
# Epoch 09 | Val Acc: 0.6191
# Epoch 10 | Val Acc: 0.6468
# Epoch 11 | Val Acc: 0.6277
# Epoch 12 | Val Acc: 0.6723
# Epoch 13 | Val Acc: 0.6617
# Epoch 14 | Val Acc: 0.6340
# Epoch 15 | Val Acc: 0.6362
# Epoch 16 | Val Acc: 0.6830
# Epoch 17 | Val Acc: 0.6553
# Epoch 18 | Val Acc: 0.7085
# Epoch 19 | Val Acc: 0.6319
# Epoch 20 | Val Acc: 0.6553
# Epoch 21 | Val Acc: 0.6404
# Epoch 22 | Val Acc: 0.6638
# Epoch 23 | Val Acc: 0.7191
# Epoch 24 | Val Acc: 0.6957
# Epoch 25 | Val Acc: 0.6809
# Epoch 26 | Val Acc: 0.6426
# Epoch 27 | Val Acc: 0.6915
# Epoch 28 | Val Acc: 0.7021
# Epoch 29 | Val Acc: 0.6532
# Epoch 30 | Val Acc: 0.6681
# Early stopping
# Best accuracy (split 6): 0.7191
#
# ===== Split 7 =====
# Epoch 01 | Val Acc: 0.1149
# Epoch 02 | Val Acc: 0.2213
# Epoch 03 | Val Acc: 0.3085
# Epoch 04 | Val Acc: 0.3106
# Epoch 05 | Val Acc: 0.4234
# Epoch 06 | Val Acc: 0.4085
# Epoch 07 | Val Acc: 0.4106
# Epoch 08 | Val Acc: 0.4298
# Epoch 09 | Val Acc: 0.4532
# Epoch 10 | Val Acc: 0.4489
# Epoch 11 | Val Acc: 0.4574
# Epoch 12 | Val Acc: 0.4085
# Epoch 13 | Val Acc: 0.4723
# Epoch 14 | Val Acc: 0.4362
# Epoch 15 | Val Acc: 0.4426
# Epoch 16 | Val Acc: 0.4617
# Epoch 17 | Val Acc: 0.4681
# Epoch 18 | Val Acc: 0.4170
# Epoch 19 | Val Acc: 0.4362
# Epoch 20 | Val Acc: 0.4681
# Early stopping
# Best accuracy (split 7): 0.4723
#
# ===== Split 8 =====
# Epoch 01 | Val Acc: 0.1681
# Epoch 02 | Val Acc: 0.3277
# Epoch 03 | Val Acc: 0.4362
# Epoch 04 | Val Acc: 0.4809
# Epoch 05 | Val Acc: 0.5000
# Epoch 06 | Val Acc: 0.4936
# Epoch 07 | Val Acc: 0.5574
# Epoch 08 | Val Acc: 0.6064
# Epoch 09 | Val Acc: 0.5872
# Epoch 10 | Val Acc: 0.5915
# Epoch 11 | Val Acc: 0.5915
# Epoch 12 | Val Acc: 0.6170
# Epoch 13 | Val Acc: 0.5872
# Epoch 14 | Val Acc: 0.5660
# Epoch 15 | Val Acc: 0.6383
# Epoch 16 | Val Acc: 0.5979
# Epoch 17 | Val Acc: 0.6000
# Epoch 18 | Val Acc: 0.5936
# Epoch 19 | Val Acc: 0.6021
# Epoch 20 | Val Acc: 0.5809
# Epoch 21 | Val Acc: 0.6191
# Epoch 22 | Val Acc: 0.6021
# Early stopping
# Best accuracy (split 8): 0.6383
#
# ===== Split 9 =====
# Epoch 01 | Val Acc: 0.1319
# Epoch 02 | Val Acc: 0.2426
# Epoch 03 | Val Acc: 0.3553
# Epoch 04 | Val Acc: 0.3979
# Epoch 05 | Val Acc: 0.3915
# Epoch 06 | Val Acc: 0.4745
# Epoch 07 | Val Acc: 0.4660
# Epoch 08 | Val Acc: 0.4617
# Epoch 09 | Val Acc: 0.4957
# Epoch 10 | Val Acc: 0.4596
# Epoch 11 | Val Acc: 0.4809
# Epoch 12 | Val Acc: 0.5234
# Epoch 13 | Val Acc: 0.4872
# Epoch 14 | Val Acc: 0.5404
# Epoch 15 | Val Acc: 0.5064
# Epoch 16 | Val Acc: 0.5298
# Epoch 17 | Val Acc: 0.5234
# Epoch 18 | Val Acc: 0.5085
# Epoch 19 | Val Acc: 0.5255
# Epoch 20 | Val Acc: 0.5106
# Epoch 21 | Val Acc: 0.5404
# Early stopping
# Best accuracy (split 9): 0.5404
#
# ===== Split 10 =====
# Epoch 01 | Val Acc: 0.1213
# Epoch 02 | Val Acc: 0.2362
# Epoch 03 | Val Acc: 0.3489
# Epoch 04 | Val Acc: 0.4787
# Epoch 05 | Val Acc: 0.5319
# Epoch 06 | Val Acc: 0.5723
# Epoch 07 | Val Acc: 0.5894
# Epoch 08 | Val Acc: 0.5660
# Epoch 09 | Val Acc: 0.5787
# Epoch 10 | Val Acc: 0.5660
# Epoch 11 | Val Acc: 0.6255
# Epoch 12 | Val Acc: 0.6000
# Epoch 13 | Val Acc: 0.5745
# Epoch 14 | Val Acc: 0.6298
# Epoch 15 | Val Acc: 0.6426
# Epoch 16 | Val Acc: 0.6128
# Epoch 17 | Val Acc: 0.6234
# Epoch 18 | Val Acc: 0.6532
# Epoch 19 | Val Acc: 0.6043
# Epoch 20 | Val Acc: 0.6319
# Epoch 21 | Val Acc: 0.6170
# Epoch 22 | Val Acc: 0.6596
# Epoch 23 | Val Acc: 0.6383
# Epoch 24 | Val Acc: 0.6553
# Epoch 25 | Val Acc: 0.6383
# Epoch 26 | Val Acc: 0.6319
# Epoch 27 | Val Acc: 0.6574
# Epoch 28 | Val Acc: 0.6426
# Epoch 29 | Val Acc: 0.6426
# Early stopping
# Best accuracy (split 10): 0.6596
#
# ===== Split 11 =====
# Epoch 01 | Val Acc: 0.2340
# Epoch 02 | Val Acc: 0.3574
# Epoch 03 | Val Acc: 0.4979
# Epoch 04 | Val Acc: 0.5128
# Epoch 05 | Val Acc: 0.6234
# Epoch 06 | Val Acc: 0.6766
# Epoch 07 | Val Acc: 0.6191
# Epoch 08 | Val Acc: 0.7000
# Epoch 09 | Val Acc: 0.7277
# Epoch 10 | Val Acc: 0.7149
# Epoch 11 | Val Acc: 0.7213
# Epoch 12 | Val Acc: 0.7213
# Epoch 13 | Val Acc: 0.7894
# Epoch 14 | Val Acc: 0.7702
# Epoch 15 | Val Acc: 0.7511
# Epoch 16 | Val Acc: 0.7085
# Epoch 17 | Val Acc: 0.7638
# Epoch 18 | Val Acc: 0.7426
# Epoch 19 | Val Acc: 0.7553
# Epoch 20 | Val Acc: 0.7723
# Early stopping
# Best accuracy (split 11): 0.7894
#
# ===== Split 12 =====
# Epoch 01 | Val Acc: 0.1936
# Epoch 02 | Val Acc: 0.4426
# Epoch 03 | Val Acc: 0.5532
# Epoch 04 | Val Acc: 0.6404
# Epoch 05 | Val Acc: 0.7021
# Epoch 06 | Val Acc: 0.6936
# Epoch 07 | Val Acc: 0.7404
# Epoch 08 | Val Acc: 0.7043
# Epoch 09 | Val Acc: 0.7766
# Epoch 10 | Val Acc: 0.8085
# Epoch 11 | Val Acc: 0.8000
# Epoch 12 | Val Acc: 0.7851
# Epoch 13 | Val Acc: 0.7851
# Epoch 14 | Val Acc: 0.7702
# Epoch 15 | Val Acc: 0.7872
# Epoch 16 | Val Acc: 0.8340
# Epoch 17 | Val Acc: 0.7830
# Epoch 18 | Val Acc: 0.8000
# Epoch 19 | Val Acc: 0.8234
# Epoch 20 | Val Acc: 0.7851
# Epoch 21 | Val Acc: 0.8298
# Epoch 22 | Val Acc: 0.8468
# Epoch 23 | Val Acc: 0.7638
# Epoch 24 | Val Acc: 0.8043
# Epoch 25 | Val Acc: 0.7936
# Epoch 26 | Val Acc: 0.8383
# Epoch 27 | Val Acc: 0.8191
# Epoch 28 | Val Acc: 0.8021
# Epoch 29 | Val Acc: 0.8255
# Early stopping
# Best accuracy (split 12): 0.8468
#
# ===== Split 13 =====
# Epoch 01 | Val Acc: 0.1596
# Epoch 02 | Val Acc: 0.3957
# Epoch 03 | Val Acc: 0.5319
# Epoch 04 | Val Acc: 0.6447
# Epoch 05 | Val Acc: 0.6936
# Epoch 06 | Val Acc: 0.7191
# Epoch 07 | Val Acc: 0.7064
# Epoch 08 | Val Acc: 0.7170
# Epoch 09 | Val Acc: 0.7511
# Epoch 10 | Val Acc: 0.7468
# Epoch 11 | Val Acc: 0.7340
# Epoch 12 | Val Acc: 0.7319
# Epoch 13 | Val Acc: 0.7404
# Epoch 14 | Val Acc: 0.7383
# Epoch 15 | Val Acc: 0.7574
# Epoch 16 | Val Acc: 0.7532
# Epoch 17 | Val Acc: 0.7340
# Epoch 18 | Val Acc: 0.7489
# Epoch 19 | Val Acc: 0.7426
# Epoch 20 | Val Acc: 0.7362
# Epoch 21 | Val Acc: 0.7809
# Epoch 22 | Val Acc: 0.7489
# Epoch 23 | Val Acc: 0.7702
# Epoch 24 | Val Acc: 0.7447
# Epoch 25 | Val Acc: 0.7404
# Epoch 26 | Val Acc: 0.7723
# Epoch 27 | Val Acc: 0.7447
# Epoch 28 | Val Acc: 0.7447
# Early stopping
# Best accuracy (split 13): 0.7809
#
# ===== Split 14 =====
# Epoch 01 | Val Acc: 0.0872
# Epoch 02 | Val Acc: 0.1128
# Epoch 03 | Val Acc: 0.1787
# Epoch 04 | Val Acc: 0.2149
# Epoch 05 | Val Acc: 0.2468
# Epoch 06 | Val Acc: 0.3128
# Epoch 07 | Val Acc: 0.3553
# Epoch 08 | Val Acc: 0.3553
# Epoch 09 | Val Acc: 0.3596
# Epoch 10 | Val Acc: 0.3894
# Epoch 11 | Val Acc: 0.3915
# Epoch 12 | Val Acc: 0.4000
# Epoch 13 | Val Acc: 0.4064
# Epoch 14 | Val Acc: 0.3915
# Epoch 15 | Val Acc: 0.4170
# Epoch 16 | Val Acc: 0.3681
# Epoch 17 | Val Acc: 0.3894
# Epoch 18 | Val Acc: 0.4191
# Epoch 19 | Val Acc: 0.4149
# Epoch 20 | Val Acc: 0.3617
# Epoch 21 | Val Acc: 0.4106
# Epoch 22 | Val Acc: 0.4383
# Epoch 23 | Val Acc: 0.4191
# Epoch 24 | Val Acc: 0.4085
# Epoch 25 | Val Acc: 0.4319
# Epoch 26 | Val Acc: 0.4043
# Epoch 27 | Val Acc: 0.4043
# Epoch 28 | Val Acc: 0.4085
# Epoch 29 | Val Acc: 0.4000
# Early stopping
# Best accuracy (split 14): 0.4383
#
# ===== Split 15 =====
# Epoch 01 | Val Acc: 0.1851
# Epoch 02 | Val Acc: 0.2936
# Epoch 03 | Val Acc: 0.4745
# Epoch 04 | Val Acc: 0.5064
# Epoch 05 | Val Acc: 0.5745
# Epoch 06 | Val Acc: 0.6468
# Epoch 07 | Val Acc: 0.6660
# Epoch 08 | Val Acc: 0.6553
# Epoch 09 | Val Acc: 0.6660
# Epoch 10 | Val Acc: 0.7191
# Epoch 11 | Val Acc: 0.6872
# Epoch 12 | Val Acc: 0.6723
# Epoch 13 | Val Acc: 0.7106
# Epoch 14 | Val Acc: 0.7213
# Epoch 15 | Val Acc: 0.7149
# Epoch 16 | Val Acc: 0.6979
# Epoch 17 | Val Acc: 0.7106
# Epoch 18 | Val Acc: 0.7106
# Epoch 19 | Val Acc: 0.7106
# Epoch 20 | Val Acc: 0.7149
# Epoch 21 | Val Acc: 0.6894
# Early stopping
# Best accuracy (split 15): 0.7213
#
# ===== Split 16 =====
# Epoch 01 | Val Acc: 0.1830
# Epoch 02 | Val Acc: 0.3447
# Epoch 03 | Val Acc: 0.5681
# Epoch 04 | Val Acc: 0.6426
# Epoch 05 | Val Acc: 0.6149
# Epoch 06 | Val Acc: 0.6681
# Epoch 07 | Val Acc: 0.6766
# Epoch 08 | Val Acc: 0.6872
# Epoch 09 | Val Acc: 0.7383
# Epoch 10 | Val Acc: 0.6723
# Epoch 11 | Val Acc: 0.7660
# Epoch 12 | Val Acc: 0.7255
# Epoch 13 | Val Acc: 0.7553
# Epoch 14 | Val Acc: 0.7404
# Epoch 15 | Val Acc: 0.7745
# Epoch 16 | Val Acc: 0.7404
# Epoch 17 | Val Acc: 0.7340
# Epoch 18 | Val Acc: 0.7596
# Epoch 19 | Val Acc: 0.7511
# Epoch 20 | Val Acc: 0.7213
# Epoch 21 | Val Acc: 0.7340
# Epoch 22 | Val Acc: 0.7723
# Early stopping
# Best accuracy (split 16): 0.7745
#
# ===== Split 17 =====
# Epoch 01 | Val Acc: 0.1426
# Epoch 02 | Val Acc: 0.2553
# Epoch 03 | Val Acc: 0.4362
# Epoch 04 | Val Acc: 0.5000
# Epoch 05 | Val Acc: 0.5787
# Epoch 06 | Val Acc: 0.5404
# Epoch 07 | Val Acc: 0.6043
# Epoch 08 | Val Acc: 0.5809
# Epoch 09 | Val Acc: 0.5915
# Epoch 10 | Val Acc: 0.6426
# Epoch 11 | Val Acc: 0.6723
# Epoch 12 | Val Acc: 0.7021
# Epoch 13 | Val Acc: 0.6766
# Epoch 14 | Val Acc: 0.6149
# Epoch 15 | Val Acc: 0.6574
# Epoch 16 | Val Acc: 0.7085
# Epoch 17 | Val Acc: 0.6915
# Epoch 18 | Val Acc: 0.6894
# Epoch 19 | Val Acc: 0.7213
# Epoch 20 | Val Acc: 0.6702
# Epoch 21 | Val Acc: 0.6766
# Epoch 22 | Val Acc: 0.6596
# Epoch 23 | Val Acc: 0.7234
# Epoch 24 | Val Acc: 0.6851
# Epoch 25 | Val Acc: 0.6638
# Epoch 26 | Val Acc: 0.7085
# Epoch 27 | Val Acc: 0.6426
# Epoch 28 | Val Acc: 0.6872
# Epoch 29 | Val Acc: 0.6511
# Epoch 30 | Val Acc: 0.7213
# Early stopping
# Best accuracy (split 17): 0.7234
#
# ===== Split 18 =====
# Epoch 01 | Val Acc: 0.1553
# Epoch 02 | Val Acc: 0.2851
# Epoch 03 | Val Acc: 0.4277
# Epoch 04 | Val Acc: 0.5149
# Epoch 05 | Val Acc: 0.5702
# Epoch 06 | Val Acc: 0.6043
# Epoch 07 | Val Acc: 0.6170
# Epoch 08 | Val Acc: 0.6532
# Epoch 09 | Val Acc: 0.6638
# Epoch 10 | Val Acc: 0.6723
# Epoch 11 | Val Acc: 0.6574
# Epoch 12 | Val Acc: 0.6702
# Epoch 13 | Val Acc: 0.7043
# Epoch 14 | Val Acc: 0.6681
# Epoch 15 | Val Acc: 0.6830
# Epoch 16 | Val Acc: 0.6553
# Epoch 17 | Val Acc: 0.7085
# Epoch 18 | Val Acc: 0.6915
# Epoch 19 | Val Acc: 0.6787
# Epoch 20 | Val Acc: 0.6468
# Epoch 21 | Val Acc: 0.6851
# Epoch 22 | Val Acc: 0.6830
# Epoch 23 | Val Acc: 0.6830
# Epoch 24 | Val Acc: 0.7000
# Early stopping
# Best accuracy (split 18): 0.7085
#
# ===== Split 19 =====
# Epoch 01 | Val Acc: 0.1426
# Epoch 02 | Val Acc: 0.2851
# Epoch 03 | Val Acc: 0.3532
# Epoch 04 | Val Acc: 0.4532
# Epoch 05 | Val Acc: 0.4787
# Epoch 06 | Val Acc: 0.5106
# Epoch 07 | Val Acc: 0.5085
# Epoch 08 | Val Acc: 0.5447
# Epoch 09 | Val Acc: 0.5787
# Epoch 10 | Val Acc: 0.5574
# Epoch 11 | Val Acc: 0.5660
# Epoch 12 | Val Acc: 0.5872
# Epoch 13 | Val Acc: 0.5830
# Epoch 14 | Val Acc: 0.5574
# Epoch 15 | Val Acc: 0.5915
# Epoch 16 | Val Acc: 0.6064
# Epoch 17 | Val Acc: 0.6085
# Epoch 18 | Val Acc: 0.6170
# Epoch 19 | Val Acc: 0.6085
# Epoch 20 | Val Acc: 0.5809
# Epoch 21 | Val Acc: 0.5872
# Epoch 22 | Val Acc: 0.5915
# Epoch 23 | Val Acc: 0.5957
# Epoch 24 | Val Acc: 0.6191
# Epoch 25 | Val Acc: 0.5915
# Epoch 26 | Val Acc: 0.6213
# Epoch 27 | Val Acc: 0.5979
# Epoch 28 | Val Acc: 0.5766
# Epoch 29 | Val Acc: 0.5894
# Epoch 30 | Val Acc: 0.6128
# Epoch 31 | Val Acc: 0.5894
# Epoch 32 | Val Acc: 0.6170
# Epoch 33 | Val Acc: 0.6043
# Early stopping
# Best accuracy (split 19): 0.6213
#
# FINAL AVERAGE ACCURACY (CNN + CCE): 0.6622620380739082
