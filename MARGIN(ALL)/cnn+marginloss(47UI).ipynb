# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.optim import Adam

torch.manual_seed(42)
np.random.seed(42)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# ---------------- Dataset ----------------
class EMGDataset(Dataset):
    def __init__(self, x_path, y_path):
        self.X = np.load(x_path)                     # (N, T, C)
        y_onehot = np.load(y_path)                   # (N, num_classes)

        self.y = np.argmax(y_onehot, axis=1)
        self.num_classes = y_onehot.shape[1]         # 🔥 auto-detect

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        x = torch.tensor(self.X[idx], dtype=torch.float32)
        y = torch.tensor(self.y[idx], dtype=torch.long)
        return x, y

# ---------------- CNN Encoder ----------------
class CNNEncoder(nn.Module):
    def __init__(self, emb_dim=128):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv1d(6, 64, kernel_size=10),
            nn.ReLU(),

            nn.Conv1d(64, 64, kernel_size=10),
            nn.ReLU(),
            nn.MaxPool1d(3),

            nn.Conv1d(64, 256, kernel_size=10),
            nn.ReLU(),

            nn.Conv1d(256, 256, kernel_size=10),
            nn.ReLU(),

            nn.AdaptiveAvgPool1d(1)
        )
        self.fc = nn.Linear(256, emb_dim)

    def forward(self, x):
        x = x.permute(0, 2, 1)              # (B, C, T)
        x = self.net(x).squeeze(-1)         # (B, 256)
        z = F.normalize(self.fc(x), dim=1)  # normalized embeddings
        return z
    
class FullModel(nn.Module):
    def __init__(self, emb_dim, num_classes):
        super().__init__()
        self.encoder = CNNEncoder(emb_dim)
        self.classifier = nn.Linear(emb_dim, num_classes)

    def forward(self, x):
        z = self.encoder(x)
        logits = self.classifier(z)
        return z, logits

class MarginEmbeddingLoss(nn.Module):
    def __init__(self, margin=1.0):
        super().__init__()
        self.margin = margin

    def forward(self, z, y):
        dist = torch.cdist(z, z, p=2)
        y = y.unsqueeze(1)

        pos_mask = (y == y.T).float()
        neg_mask = (y != y.T).float()

        eye = torch.eye(len(z), device=z.device)
        pos_mask = pos_mask - eye

        pos_loss = pos_mask * dist.pow(2)
        neg_loss = neg_mask * F.relu(self.margin - dist).pow(2)

        loss = (pos_loss.sum() + neg_loss.sum()) / (
            pos_mask.sum() + neg_mask.sum() + 1e-8
        )
        return loss

class EarlyStopping:
    def __init__(self, patience=10):
        self.patience = patience
        self.best_acc = -1
        self.counter = 0
        self.best_state = None

    def step(self, acc, model):
        if acc > self.best_acc:
            self.best_acc = acc
            self.best_state = {k: v.cpu() for k, v in model.state_dict().items()}
            self.counter = 0
            return False
        else:
            self.counter += 1
            return self.counter >= self.patience

    def restore(self, model):
        model.load_state_dict(self.best_state)

def train_and_eval(model, train_loader, test_loader,
                   margin_loss, alpha=1.0,
                   epochs=500, patience=10):

    ce_loss = nn.CrossEntropyLoss()
    optimizer = Adam(model.parameters(), lr=5e-4)
    stopper = EarlyStopping(patience)

    for epoch in range(epochs):
        model.train()
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)

            z, logits = model(x)
            loss = ce_loss(logits, y) + alpha * margin_loss(z, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        model.eval()
        correct, total = 0, 0
        with torch.no_grad():
            for x, y in test_loader:
                x, y = x.to(device), y.to(device)
                _, logits = model(x)
                preds = logits.argmax(dim=1)
                correct += (preds == y).sum().item()
                total += y.size(0)

        acc = correct / total
        print(f"Epoch {epoch+1:02d} | Test Acc: {acc:.4f}")

        if stopper.step(acc, model):
            print("Early stopping triggered")
            break

    stopper.restore(model)
    return stopper.best_acc

NUM_CLASSES = 47
BASE = f"models/Data/Data/{NUM_CLASSES}_classes/UserInDependenet"

margin_loss = MarginEmbeddingLoss(margin=1.0)
all_accs = []

for split in range(1, 20):
    print(f"\n========== SPLIT {split} ==========")

    train_ds = EMGDataset(
        f"{BASE}/Train/X_train_{split}.npy",
        f"{BASE}/Train/y_train_{split}.npy"
    )
    test_ds = EMGDataset(
        f"{BASE}/Test/X_test_{split}.npy",
        f"{BASE}/Test/y_test_{split}.npy"
    )

    train_loader = DataLoader(train_ds, batch_size=128, shuffle=True)
    test_loader = DataLoader(test_ds, batch_size=128, shuffle=False)

    model = FullModel(
        emb_dim=128,
        num_classes=train_ds.num_classes   
    ).to(device)

    acc = train_and_eval(
        model,
        train_loader,
        test_loader,
        margin_loss,
        alpha=1.0,
        epochs=500,
        patience=10
    )

    print(f"Best Split Accuracy: {acc:.4f}")
    all_accs.append(acc)

    del model
    torch.cuda.empty_cache()

print("\nFINAL RESULT")
print("Average Accuracy (Margin + CE):", np.mean(all_accs))
# Out:
# Using device: cuda
#
# ========== SPLIT 1 ==========
# Epoch 01 | Test Acc: 0.0766
# Epoch 02 | Test Acc: 0.1489
# Epoch 03 | Test Acc: 0.3468
# Epoch 04 | Test Acc: 0.4234
# Epoch 05 | Test Acc: 0.5426
# Epoch 06 | Test Acc: 0.5894
# Epoch 07 | Test Acc: 0.6681
# Epoch 08 | Test Acc: 0.6851
# Epoch 09 | Test Acc: 0.7617
# Epoch 10 | Test Acc: 0.6447
# Epoch 11 | Test Acc: 0.7426
# Epoch 12 | Test Acc: 0.7170
# Epoch 13 | Test Acc: 0.7085
# Epoch 14 | Test Acc: 0.7043
# Epoch 15 | Test Acc: 0.7489
# Epoch 16 | Test Acc: 0.6702
# Epoch 17 | Test Acc: 0.7064
# Epoch 18 | Test Acc: 0.7340
# Epoch 19 | Test Acc: 0.7000
# Early stopping triggered
# Best Split Accuracy: 0.7617
#
# ========== SPLIT 2 ==========
# Epoch 01 | Test Acc: 0.0532
# Epoch 02 | Test Acc: 0.1426
# Epoch 03 | Test Acc: 0.2383
# Epoch 04 | Test Acc: 0.3745
# Epoch 05 | Test Acc: 0.4128
# Epoch 06 | Test Acc: 0.4723
# Epoch 07 | Test Acc: 0.5128
# Epoch 08 | Test Acc: 0.4766
# Epoch 09 | Test Acc: 0.5383
# Epoch 10 | Test Acc: 0.5468
# Epoch 11 | Test Acc: 0.5255
# Epoch 12 | Test Acc: 0.5064
# Epoch 13 | Test Acc: 0.4936
# Epoch 14 | Test Acc: 0.5128
# Epoch 15 | Test Acc: 0.5574
# Epoch 16 | Test Acc: 0.5340
# Epoch 17 | Test Acc: 0.5511
# Epoch 18 | Test Acc: 0.5596
# Epoch 19 | Test Acc: 0.5021
# Epoch 20 | Test Acc: 0.5000
# Epoch 21 | Test Acc: 0.5213
# Epoch 22 | Test Acc: 0.5213
# Epoch 23 | Test Acc: 0.4851
# Epoch 24 | Test Acc: 0.4894
# Epoch 25 | Test Acc: 0.5064
# Epoch 26 | Test Acc: 0.4957
# Epoch 27 | Test Acc: 0.5000
# Epoch 28 | Test Acc: 0.5043
# Early stopping triggered
# Best Split Accuracy: 0.5596
#
# ========== SPLIT 3 ==========
# Epoch 01 | Test Acc: 0.0809
# Epoch 02 | Test Acc: 0.1660
# Epoch 03 | Test Acc: 0.2660
# Epoch 04 | Test Acc: 0.3936
# Epoch 05 | Test Acc: 0.4596
# Epoch 06 | Test Acc: 0.5085
# Epoch 07 | Test Acc: 0.5702
# Epoch 08 | Test Acc: 0.6277
# Epoch 09 | Test Acc: 0.6213
# Epoch 10 | Test Acc: 0.6745
# Epoch 11 | Test Acc: 0.6362
# Epoch 12 | Test Acc: 0.6809
# Epoch 13 | Test Acc: 0.6255
# Epoch 14 | Test Acc: 0.6426
# Epoch 15 | Test Acc: 0.6532
# Epoch 16 | Test Acc: 0.6532
# Epoch 17 | Test Acc: 0.6894
# Epoch 18 | Test Acc: 0.6191
# Epoch 19 | Test Acc: 0.6511
# Epoch 20 | Test Acc: 0.6298
# Epoch 21 | Test Acc: 0.6511
# Epoch 22 | Test Acc: 0.6383
# Epoch 23 | Test Acc: 0.6489
# Epoch 24 | Test Acc: 0.6404
# Epoch 25 | Test Acc: 0.6106
# Epoch 26 | Test Acc: 0.6574
# Epoch 27 | Test Acc: 0.6681
# Early stopping triggered
# Best Split Accuracy: 0.6894
#
# ========== SPLIT 4 ==========
# Epoch 01 | Test Acc: 0.0596
# Epoch 02 | Test Acc: 0.0979
# Epoch 03 | Test Acc: 0.2064
# Epoch 04 | Test Acc: 0.3426
# Epoch 05 | Test Acc: 0.5426
# Epoch 06 | Test Acc: 0.6298
# Epoch 07 | Test Acc: 0.6617
# Epoch 08 | Test Acc: 0.6957
# Epoch 09 | Test Acc: 0.6894
# Epoch 10 | Test Acc: 0.7447
# Epoch 11 | Test Acc: 0.7340
# Epoch 12 | Test Acc: 0.7340
# Epoch 13 | Test Acc: 0.7170
# Epoch 14 | Test Acc: 0.6915
# Epoch 15 | Test Acc: 0.7532
# Epoch 16 | Test Acc: 0.7043
# Epoch 17 | Test Acc: 0.7085
# Epoch 18 | Test Acc: 0.6894
# Epoch 19 | Test Acc: 0.7319
# Epoch 20 | Test Acc: 0.7511
# Epoch 21 | Test Acc: 0.7149
# Epoch 22 | Test Acc: 0.7128
# Epoch 23 | Test Acc: 0.6766
# Epoch 24 | Test Acc: 0.7021
# Epoch 25 | Test Acc: 0.6936
# Early stopping triggered
# Best Split Accuracy: 0.7532
#
# ========== SPLIT 5 ==========
# Epoch 01 | Test Acc: 0.0426
# Epoch 02 | Test Acc: 0.0851
# Epoch 03 | Test Acc: 0.1511
# Epoch 04 | Test Acc: 0.2213
# Epoch 05 | Test Acc: 0.3298
# Epoch 06 | Test Acc: 0.4638
# Epoch 07 | Test Acc: 0.4532
# Epoch 08 | Test Acc: 0.4574
# Epoch 09 | Test Acc: 0.5064
# Epoch 10 | Test Acc: 0.5234
# Epoch 11 | Test Acc: 0.5255
# Epoch 12 | Test Acc: 0.5277
# Epoch 13 | Test Acc: 0.5489
# Epoch 14 | Test Acc: 0.4660
# Epoch 15 | Test Acc: 0.4957
# Epoch 16 | Test Acc: 0.5000
# Epoch 17 | Test Acc: 0.5085
# Epoch 18 | Test Acc: 0.4957
# Epoch 19 | Test Acc: 0.5553
# Epoch 20 | Test Acc: 0.4957
# Epoch 21 | Test Acc: 0.5298
# Epoch 22 | Test Acc: 0.4511
# Epoch 23 | Test Acc: 0.5085
# Epoch 24 | Test Acc: 0.4830
# Epoch 25 | Test Acc: 0.4532
# Epoch 26 | Test Acc: 0.5064
# Epoch 27 | Test Acc: 0.4745
# Epoch 28 | Test Acc: 0.5085
# Epoch 29 | Test Acc: 0.4404
# Early stopping triggered
# Best Split Accuracy: 0.5553
#
# ========== SPLIT 6 ==========
# Epoch 01 | Test Acc: 0.0255
# Epoch 02 | Test Acc: 0.1489
# Epoch 03 | Test Acc: 0.2830
# Epoch 04 | Test Acc: 0.4404
# Epoch 05 | Test Acc: 0.5234
# Epoch 06 | Test Acc: 0.5915
# Epoch 07 | Test Acc: 0.7021
# Epoch 08 | Test Acc: 0.6830
# Epoch 09 | Test Acc: 0.7191
# Epoch 10 | Test Acc: 0.7128
# Epoch 11 | Test Acc: 0.6915
# Epoch 12 | Test Acc: 0.6915
# Epoch 13 | Test Acc: 0.6915
# Epoch 14 | Test Acc: 0.6809
# Epoch 15 | Test Acc: 0.6404
# Epoch 16 | Test Acc: 0.7021
# Epoch 17 | Test Acc: 0.6830
# Epoch 18 | Test Acc: 0.6787
# Epoch 19 | Test Acc: 0.7043
# Early stopping triggered
# Best Split Accuracy: 0.7191
#
# ========== SPLIT 7 ==========
# Epoch 01 | Test Acc: 0.0255
# Epoch 02 | Test Acc: 0.1277
# Epoch 03 | Test Acc: 0.3000
# Epoch 04 | Test Acc: 0.3957
# Epoch 05 | Test Acc: 0.4340
# Epoch 06 | Test Acc: 0.5043
# Epoch 07 | Test Acc: 0.5319
# Epoch 08 | Test Acc: 0.4745
# Epoch 09 | Test Acc: 0.5447
# Epoch 10 | Test Acc: 0.5064
# Epoch 11 | Test Acc: 0.4915
# Epoch 12 | Test Acc: 0.4128
# Epoch 13 | Test Acc: 0.5149
# Epoch 14 | Test Acc: 0.5191
# Epoch 15 | Test Acc: 0.4872
# Epoch 16 | Test Acc: 0.5149
# Epoch 17 | Test Acc: 0.4660
# Epoch 18 | Test Acc: 0.4830
# Epoch 19 | Test Acc: 0.4830
# Early stopping triggered
# Best Split Accuracy: 0.5447
#
# ========== SPLIT 8 ==========
# Epoch 01 | Test Acc: 0.0319
# Epoch 02 | Test Acc: 0.0426
# Epoch 03 | Test Acc: 0.1617
# Epoch 04 | Test Acc: 0.3043
# Epoch 05 | Test Acc: 0.3957
# Epoch 06 | Test Acc: 0.4809
# Epoch 07 | Test Acc: 0.4957
# Epoch 08 | Test Acc: 0.4596
# Epoch 09 | Test Acc: 0.4979
# Epoch 10 | Test Acc: 0.4426
# Epoch 11 | Test Acc: 0.5426
# Epoch 12 | Test Acc: 0.5128
# Epoch 13 | Test Acc: 0.4787
# Epoch 14 | Test Acc: 0.5191
# Epoch 15 | Test Acc: 0.5234
# Epoch 16 | Test Acc: 0.4660
# Epoch 17 | Test Acc: 0.5106
# Epoch 18 | Test Acc: 0.5043
# Epoch 19 | Test Acc: 0.4234
# Epoch 20 | Test Acc: 0.5277
# Epoch 21 | Test Acc: 0.4426
# Early stopping triggered
# Best Split Accuracy: 0.5426
#
# ========== SPLIT 9 ==========
# Epoch 01 | Test Acc: 0.0319
# Epoch 02 | Test Acc: 0.0809
# Epoch 03 | Test Acc: 0.2149
# Epoch 04 | Test Acc: 0.3191
# Epoch 05 | Test Acc: 0.3489
# Epoch 06 | Test Acc: 0.4894
# Epoch 07 | Test Acc: 0.5277
# Epoch 08 | Test Acc: 0.5723
# Epoch 09 | Test Acc: 0.5447
# Epoch 10 | Test Acc: 0.5638
# Epoch 11 | Test Acc: 0.5404
# Epoch 12 | Test Acc: 0.5149
# Epoch 13 | Test Acc: 0.5447
# Epoch 14 | Test Acc: 0.5723
# Epoch 15 | Test Acc: 0.5766
# Epoch 16 | Test Acc: 0.5319
# Epoch 17 | Test Acc: 0.6106
# Epoch 18 | Test Acc: 0.6043
# Epoch 19 | Test Acc: 0.5340
# Epoch 20 | Test Acc: 0.4894
# Epoch 21 | Test Acc: 0.6021
# Epoch 22 | Test Acc: 0.5638
# Epoch 23 | Test Acc: 0.5340
# Epoch 24 | Test Acc: 0.5234
# Epoch 25 | Test Acc: 0.5830
# Epoch 26 | Test Acc: 0.6128
# Epoch 27 | Test Acc: 0.6000
# Epoch 28 | Test Acc: 0.5468
# Epoch 29 | Test Acc: 0.5170
# Epoch 30 | Test Acc: 0.5426
# Epoch 31 | Test Acc: 0.5170
# Epoch 32 | Test Acc: 0.5128
# Epoch 33 | Test Acc: 0.5000
# Epoch 34 | Test Acc: 0.5681
# Epoch 35 | Test Acc: 0.5596
# Epoch 36 | Test Acc: 0.5809
# Early stopping triggered
# Best Split Accuracy: 0.6128
#
# ========== SPLIT 10 ==========
# Epoch 01 | Test Acc: 0.0319
# Epoch 02 | Test Acc: 0.1234
# Epoch 03 | Test Acc: 0.2404
# Epoch 04 | Test Acc: 0.2979
# Epoch 05 | Test Acc: 0.4638
# Epoch 06 | Test Acc: 0.5191
# Epoch 07 | Test Acc: 0.5723
# Epoch 08 | Test Acc: 0.5638
# Epoch 09 | Test Acc: 0.6447
# Epoch 10 | Test Acc: 0.5936
# Epoch 11 | Test Acc: 0.6383
# Epoch 12 | Test Acc: 0.6149
# Epoch 13 | Test Acc: 0.5894
# Epoch 14 | Test Acc: 0.5766
# Epoch 15 | Test Acc: 0.6128
# Epoch 16 | Test Acc: 0.6021
# Epoch 17 | Test Acc: 0.6000
# Epoch 18 | Test Acc: 0.5723
# Epoch 19 | Test Acc: 0.5894
# Early stopping triggered
# Best Split Accuracy: 0.6447
#
# ========== SPLIT 11 ==========
# Epoch 01 | Test Acc: 0.0298
# Epoch 02 | Test Acc: 0.1340
# Epoch 03 | Test Acc: 0.3617
# Epoch 04 | Test Acc: 0.4574
# Epoch 05 | Test Acc: 0.5766
# Epoch 06 | Test Acc: 0.5745
# Epoch 07 | Test Acc: 0.6574
# Epoch 08 | Test Acc: 0.6702
# Epoch 09 | Test Acc: 0.6128
# Epoch 10 | Test Acc: 0.7213
# Epoch 11 | Test Acc: 0.6660
# Epoch 12 | Test Acc: 0.6532
# Epoch 13 | Test Acc: 0.7106
# Epoch 14 | Test Acc: 0.6915
# Epoch 15 | Test Acc: 0.6255
# Epoch 16 | Test Acc: 0.6404
# Epoch 17 | Test Acc: 0.6489
# Epoch 18 | Test Acc: 0.6957
# Epoch 19 | Test Acc: 0.6043
# Epoch 20 | Test Acc: 0.7319
# Epoch 21 | Test Acc: 0.7255
# Epoch 22 | Test Acc: 0.6936
# Epoch 23 | Test Acc: 0.7191
# Epoch 24 | Test Acc: 0.6979
# Epoch 25 | Test Acc: 0.6936
# Epoch 26 | Test Acc: 0.6766
# Epoch 27 | Test Acc: 0.7298
# Epoch 28 | Test Acc: 0.7191
# Epoch 29 | Test Acc: 0.7191
# Epoch 30 | Test Acc: 0.6957
# Early stopping triggered
# Best Split Accuracy: 0.7319
#
# ========== SPLIT 12 ==========
# Epoch 01 | Test Acc: 0.0702
# Epoch 02 | Test Acc: 0.1957
# Epoch 03 | Test Acc: 0.3298
# Epoch 04 | Test Acc: 0.5000
# Epoch 05 | Test Acc: 0.6064
# Epoch 06 | Test Acc: 0.6426
# Epoch 07 | Test Acc: 0.6830
# Epoch 08 | Test Acc: 0.7596
# Epoch 09 | Test Acc: 0.7787
# Epoch 10 | Test Acc: 0.7809
# Epoch 11 | Test Acc: 0.8128
# Epoch 12 | Test Acc: 0.8128
# Epoch 13 | Test Acc: 0.8170
# Epoch 14 | Test Acc: 0.8255
# Epoch 15 | Test Acc: 0.8234
# Epoch 16 | Test Acc: 0.8106
# Epoch 17 | Test Acc: 0.8170
# Epoch 18 | Test Acc: 0.8489
# Epoch 19 | Test Acc: 0.8085
# Epoch 20 | Test Acc: 0.8191
# Epoch 21 | Test Acc: 0.8106
# Epoch 22 | Test Acc: 0.7957
# Epoch 23 | Test Acc: 0.8319
# Epoch 24 | Test Acc: 0.8149
# Epoch 25 | Test Acc: 0.8128
# Epoch 26 | Test Acc: 0.8149
# Epoch 27 | Test Acc: 0.8000
# Epoch 28 | Test Acc: 0.7872
# Early stopping triggered
# Best Split Accuracy: 0.8489
#
# ========== SPLIT 13 ==========
# Epoch 01 | Test Acc: 0.0447
# Epoch 02 | Test Acc: 0.1723
# Epoch 03 | Test Acc: 0.4106
# Epoch 04 | Test Acc: 0.5383
# Epoch 05 | Test Acc: 0.6085
# Epoch 06 | Test Acc: 0.6787
# Epoch 07 | Test Acc: 0.6872
# Epoch 08 | Test Acc: 0.6872
# Epoch 09 | Test Acc: 0.7043
# Epoch 10 | Test Acc: 0.7319
# Epoch 11 | Test Acc: 0.7234
# Epoch 12 | Test Acc: 0.7660
# Epoch 13 | Test Acc: 0.7298
# Epoch 14 | Test Acc: 0.6596
# Epoch 15 | Test Acc: 0.7340
# Epoch 16 | Test Acc: 0.6957
# Epoch 17 | Test Acc: 0.7170
# Epoch 18 | Test Acc: 0.6830
# Epoch 19 | Test Acc: 0.7362
# Epoch 20 | Test Acc: 0.7064
# Epoch 21 | Test Acc: 0.7319
# Epoch 22 | Test Acc: 0.6638
# Early stopping triggered
# Best Split Accuracy: 0.7660
#
# ========== SPLIT 14 ==========
# Epoch 01 | Test Acc: 0.0511
# Epoch 02 | Test Acc: 0.1106
# Epoch 03 | Test Acc: 0.2319
# Epoch 04 | Test Acc: 0.3255
# Epoch 05 | Test Acc: 0.3532
# Epoch 06 | Test Acc: 0.2915
# Epoch 07 | Test Acc: 0.3277
# Epoch 08 | Test Acc: 0.3511
# Epoch 09 | Test Acc: 0.3106
# Epoch 10 | Test Acc: 0.2617
# Epoch 11 | Test Acc: 0.2447
# Epoch 12 | Test Acc: 0.2617
# Epoch 13 | Test Acc: 0.2170
# Epoch 14 | Test Acc: 0.2043
# Epoch 15 | Test Acc: 0.2489
# Early stopping triggered
# Best Split Accuracy: 0.3532
#
# ========== SPLIT 15 ==========
# Epoch 01 | Test Acc: 0.0638
# Epoch 02 | Test Acc: 0.1106
# Epoch 03 | Test Acc: 0.1957
# Epoch 04 | Test Acc: 0.4021
# Epoch 05 | Test Acc: 0.5000
# Epoch 06 | Test Acc: 0.5872
# Epoch 07 | Test Acc: 0.6234
# Epoch 08 | Test Acc: 0.6702
# Epoch 09 | Test Acc: 0.7085
# Epoch 10 | Test Acc: 0.7553
# Epoch 11 | Test Acc: 0.7234
# Epoch 12 | Test Acc: 0.7106
# Epoch 13 | Test Acc: 0.6809
# Epoch 14 | Test Acc: 0.7128
# Epoch 15 | Test Acc: 0.7447
# Epoch 16 | Test Acc: 0.6979
# Epoch 17 | Test Acc: 0.6681
# Epoch 18 | Test Acc: 0.7021
# Epoch 19 | Test Acc: 0.6957
# Epoch 20 | Test Acc: 0.7106
# Early stopping triggered
# Best Split Accuracy: 0.7553
#
# ========== SPLIT 16 ==========
# Epoch 01 | Test Acc: 0.0638
# Epoch 02 | Test Acc: 0.2723
# Epoch 03 | Test Acc: 0.3723
# Epoch 04 | Test Acc: 0.6021
# Epoch 05 | Test Acc: 0.6915
# Epoch 06 | Test Acc: 0.7128
# Epoch 07 | Test Acc: 0.7404
# Epoch 08 | Test Acc: 0.7553
# Epoch 09 | Test Acc: 0.7617
# Epoch 10 | Test Acc: 0.8085
# Epoch 11 | Test Acc: 0.7979
# Epoch 12 | Test Acc: 0.7979
# Epoch 13 | Test Acc: 0.8298
# Epoch 14 | Test Acc: 0.7979
# Epoch 15 | Test Acc: 0.7553
# Epoch 16 | Test Acc: 0.7957
# Epoch 17 | Test Acc: 0.7830
# Epoch 18 | Test Acc: 0.7830
# Epoch 19 | Test Acc: 0.7894
# Epoch 20 | Test Acc: 0.8064
# Epoch 21 | Test Acc: 0.8043
# Epoch 22 | Test Acc: 0.7957
# Epoch 23 | Test Acc: 0.7617
# Early stopping triggered
# Best Split Accuracy: 0.8298
#
# ========== SPLIT 17 ==========
# Epoch 01 | Test Acc: 0.0574
# Epoch 02 | Test Acc: 0.1340
# Epoch 03 | Test Acc: 0.2553
# Epoch 04 | Test Acc: 0.4277
# Epoch 05 | Test Acc: 0.5468
# Epoch 06 | Test Acc: 0.5766
# Epoch 07 | Test Acc: 0.6809
# Epoch 08 | Test Acc: 0.7234
# Epoch 09 | Test Acc: 0.6681
# Epoch 10 | Test Acc: 0.7191
# Epoch 11 | Test Acc: 0.7340
# Epoch 12 | Test Acc: 0.7553
# Epoch 13 | Test Acc: 0.6915
# Epoch 14 | Test Acc: 0.7319
# Epoch 15 | Test Acc: 0.7638
# Epoch 16 | Test Acc: 0.7128
# Epoch 17 | Test Acc: 0.7489
# Epoch 18 | Test Acc: 0.7553
# Epoch 19 | Test Acc: 0.7553
# Epoch 20 | Test Acc: 0.6298
# Epoch 21 | Test Acc: 0.6085
# Epoch 22 | Test Acc: 0.7362
# Epoch 23 | Test Acc: 0.6809
# Epoch 24 | Test Acc: 0.7149
# Epoch 25 | Test Acc: 0.7255
# Early stopping triggered
# Best Split Accuracy: 0.7638
#
# ========== SPLIT 18 ==========
# Epoch 01 | Test Acc: 0.0340
# Epoch 02 | Test Acc: 0.1660
# Epoch 03 | Test Acc: 0.2894
# Epoch 04 | Test Acc: 0.3638
# Epoch 05 | Test Acc: 0.5149
# Epoch 06 | Test Acc: 0.6021
# Epoch 07 | Test Acc: 0.6809
# Epoch 08 | Test Acc: 0.6319
# Epoch 09 | Test Acc: 0.6532
# Epoch 10 | Test Acc: 0.6872
# Epoch 11 | Test Acc: 0.6915
# Epoch 12 | Test Acc: 0.6957
# Epoch 13 | Test Acc: 0.6362
# Epoch 14 | Test Acc: 0.6404
# Epoch 15 | Test Acc: 0.7064
# Epoch 16 | Test Acc: 0.6894
# Epoch 17 | Test Acc: 0.6574
# Epoch 18 | Test Acc: 0.6617
# Epoch 19 | Test Acc: 0.6872
# Epoch 20 | Test Acc: 0.6638
# Epoch 21 | Test Acc: 0.6872
# Epoch 22 | Test Acc: 0.6936
# Epoch 23 | Test Acc: 0.6553
# Epoch 24 | Test Acc: 0.6894
# Epoch 25 | Test Acc: 0.6489
# Early stopping triggered
# Best Split Accuracy: 0.7064
#
# ========== SPLIT 19 ==========
# Epoch 01 | Test Acc: 0.0532
# Epoch 02 | Test Acc: 0.1128
# Epoch 03 | Test Acc: 0.2511
# Epoch 04 | Test Acc: 0.2936
# Epoch 05 | Test Acc: 0.3596
# Epoch 06 | Test Acc: 0.4298
# Epoch 07 | Test Acc: 0.4851
# Epoch 08 | Test Acc: 0.5277
# Epoch 09 | Test Acc: 0.5255
# Epoch 10 | Test Acc: 0.5638
# Epoch 11 | Test Acc: 0.5319
# Epoch 12 | Test Acc: 0.4979
# Epoch 13 | Test Acc: 0.5745
# Epoch 14 | Test Acc: 0.5128
# Epoch 15 | Test Acc: 0.5404
# Epoch 16 | Test Acc: 0.5255
# Epoch 17 | Test Acc: 0.5106
# Epoch 18 | Test Acc: 0.4979
# Epoch 19 | Test Acc: 0.5191
# Epoch 20 | Test Acc: 0.5064
# Epoch 21 | Test Acc: 0.4809
# Epoch 22 | Test Acc: 0.4362
# Epoch 23 | Test Acc: 0.5319
# Early stopping triggered
# Best Split Accuracy: 0.5745
#
# FINAL RESULT
# Average Accuracy (Margin + CE): 0.6690929451287794
