# %%
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.optim import Adam

# ---------------- DEVICE ----------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# ---------------- DATASET ----------------
class EMGDataset(Dataset):
    def __init__(self, x_path, y_path):
        X = np.load(x_path)        # (N, T, C)
        y = np.load(y_path)        # (N, num_classes)

        # Per-sample, per-channel normalization
        for i in range(X.shape[0]):
            for c in range(X.shape[2]):
                mu = X[i, :, c].mean()
                std = X[i, :, c].std() + 1e-8
                X[i, :, c] = (X[i, :, c] - mu) / std

        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(np.argmax(y, axis=1), dtype=torch.long)

        # 🔥 infer number of classes automatically
        self.num_classes = y.shape[1]

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# ---------------- CNN ENCODER ----------------
class CNNEncoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv1d(6, 64, kernel_size=10),
            nn.ReLU(),

            nn.Conv1d(64, 64, kernel_size=10),
            nn.ReLU(),
            nn.MaxPool1d(3),

            nn.Conv1d(64, 256, kernel_size=10),
            nn.ReLU(),

            nn.Conv1d(256, 256, kernel_size=10),
            nn.ReLU(),

            nn.AdaptiveAvgPool1d(1)   # (B, 256, 1)
        )

    def forward(self, x):
        x = x.permute(0, 2, 1)      # (B, C, T)
        x = self.net(x)
        return x.squeeze(-1)        # (B, 256)

# ---------------- FULL MODEL ----------------
class FullModel(nn.Module):
    def __init__(self, encoder, num_classes):
        super().__init__()
        self.encoder = encoder
        self.classifier = nn.Linear(256, num_classes)

    def forward(self, x):
        emb = self.encoder(x)
        logits = self.classifier(emb)
        return logits

# ---------------- EARLY STOPPING ----------------
class EarlyStopping:
    def __init__(self, patience=7):
        self.patience = patience
        self.best_acc = 0.0
        self.counter = 0
        self.best_state = None

    def step(self, acc, model):
        if acc > self.best_acc:
            self.best_acc = acc
            self.counter = 0
            self.best_state = {
                k: v.detach().cpu().clone()
                for k, v in model.state_dict().items()
            }
            return False
        else:
            self.counter += 1
            return self.counter >= self.patience

    def restore(self, model):
        model.load_state_dict(self.best_state)

# ---------------- TRAIN & EVAL ----------------
def train_and_eval(model, train_loader, test_loader,
                   epochs=500, patience=7):

    criterion = nn.CrossEntropyLoss()
    optimizer = Adam(model.parameters(), lr=5e-4)
    early_stopper = EarlyStopping(patience)

    for epoch in range(epochs):
        model.train()
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)

            logits = model(x)
            loss = criterion(logits, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        # ----- validation -----
        model.eval()
        correct, total = 0, 0
        with torch.no_grad():
            for x, y in test_loader:
                x, y = x.to(device), y.to(device)
                preds = model(x).argmax(dim=1)
                correct += (preds == y).sum().item()
                total += y.size(0)

        val_acc = correct / total
        print(f"Epoch {epoch+1:02d} | Val Acc: {val_acc:.4f}")

        if early_stopper.step(val_acc, model):
            print("Early stopping")
            break

    early_stopper.restore(model)
    return early_stopper.best_acc

# ---------------- MAIN LOOP ----------------
NUM_CLASSES = 47    # 🔁 change to 62 if needed
BASE = f"models/Data/Data/{NUM_CLASSES}_classes/UserDependenet"

accs = []

for split in range(1, 11):
    print(f"\n===== Split {split} =====")

    train_ds = EMGDataset(
        f"{BASE}/Train/X_train_{split}.npy",
        f"{BASE}/Train/y_train_{split}.npy"
    )
    test_ds = EMGDataset(
        f"{BASE}/Test/X_test_{split}.npy",
        f"{BASE}/Test/y_test_{split}.npy"
    )

    train_loader = DataLoader(train_ds, batch_size=128, shuffle=True)
    test_loader = DataLoader(test_ds, batch_size=128)

    model = FullModel(
        CNNEncoder(),
        num_classes=train_ds.num_classes   # 🔥 auto
    ).to(device)

    acc = train_and_eval(model, train_loader, test_loader)
    accs.append(acc)

    print(f"Best accuracy (split {split}): {acc:.4f}")

print("\nFINAL AVERAGE ACCURACY (CNN + CCE):", np.mean(accs))
# Out:
# Using device: cuda
#
# ===== Split 1 =====
# Epoch 01 | Val Acc: 0.1723
# Epoch 02 | Val Acc: 0.3702
# Epoch 03 | Val Acc: 0.5043
# Epoch 04 | Val Acc: 0.5713
# Epoch 05 | Val Acc: 0.6032
# Epoch 06 | Val Acc: 0.6479
# Epoch 07 | Val Acc: 0.6670
# Epoch 08 | Val Acc: 0.7000
# Epoch 09 | Val Acc: 0.7181
# Epoch 10 | Val Acc: 0.7340
# Epoch 11 | Val Acc: 0.7489
# Epoch 12 | Val Acc: 0.7447
# Epoch 13 | Val Acc: 0.7553
# Epoch 14 | Val Acc: 0.7394
# Epoch 15 | Val Acc: 0.7766
# Epoch 16 | Val Acc: 0.7798
# Epoch 17 | Val Acc: 0.7883
# Epoch 18 | Val Acc: 0.7883
# Epoch 19 | Val Acc: 0.7936
# Epoch 20 | Val Acc: 0.7766
# Epoch 21 | Val Acc: 0.8000
# Epoch 22 | Val Acc: 0.7936
# Epoch 23 | Val Acc: 0.8011
# Epoch 24 | Val Acc: 0.8043
# Epoch 25 | Val Acc: 0.7872
# Epoch 26 | Val Acc: 0.8011
# Epoch 27 | Val Acc: 0.8106
# Epoch 28 | Val Acc: 0.7904
# Epoch 29 | Val Acc: 0.7926
# Epoch 30 | Val Acc: 0.8074
# Epoch 31 | Val Acc: 0.7926
# Epoch 32 | Val Acc: 0.8085
# Epoch 33 | Val Acc: 0.8021
# Epoch 34 | Val Acc: 0.8191
# Epoch 35 | Val Acc: 0.8053
# Epoch 36 | Val Acc: 0.8106
# Epoch 37 | Val Acc: 0.8011
# Epoch 38 | Val Acc: 0.7979
# Epoch 39 | Val Acc: 0.7989
# Epoch 40 | Val Acc: 0.8053
# Epoch 41 | Val Acc: 0.8074
# Early stopping
# Best accuracy (split 1): 0.8191
#
# ===== Split 2 =====
# Epoch 01 | Val Acc: 0.1585
# Epoch 02 | Val Acc: 0.3351
# Epoch 03 | Val Acc: 0.4638
# Epoch 04 | Val Acc: 0.5404
# Epoch 05 | Val Acc: 0.6128
# Epoch 06 | Val Acc: 0.6553
# Epoch 07 | Val Acc: 0.7096
# Epoch 08 | Val Acc: 0.7181
# Epoch 09 | Val Acc: 0.7585
# Epoch 10 | Val Acc: 0.7681
# Epoch 11 | Val Acc: 0.7596
# Epoch 12 | Val Acc: 0.7894
# Epoch 13 | Val Acc: 0.8128
# Epoch 14 | Val Acc: 0.8202
# Epoch 15 | Val Acc: 0.8277
# Epoch 16 | Val Acc: 0.8160
# Epoch 17 | Val Acc: 0.8415
# Epoch 18 | Val Acc: 0.8298
# Epoch 19 | Val Acc: 0.8383
# Epoch 20 | Val Acc: 0.8564
# Epoch 21 | Val Acc: 0.8457
# Epoch 22 | Val Acc: 0.8553
# Epoch 23 | Val Acc: 0.8574
# Epoch 24 | Val Acc: 0.8426
# Epoch 25 | Val Acc: 0.8691
# Epoch 26 | Val Acc: 0.8734
# Epoch 27 | Val Acc: 0.8553
# Epoch 28 | Val Acc: 0.8638
# Epoch 29 | Val Acc: 0.8670
# Epoch 30 | Val Acc: 0.8596
# Epoch 31 | Val Acc: 0.8638
# Epoch 32 | Val Acc: 0.8766
# Epoch 33 | Val Acc: 0.8766
# Epoch 34 | Val Acc: 0.8340
# Epoch 35 | Val Acc: 0.8681
# Epoch 36 | Val Acc: 0.8670
# Epoch 37 | Val Acc: 0.8809
# Epoch 38 | Val Acc: 0.8734
# Epoch 39 | Val Acc: 0.8691
# Epoch 40 | Val Acc: 0.8755
# Epoch 41 | Val Acc: 0.8862
# Epoch 42 | Val Acc: 0.8755
# Epoch 43 | Val Acc: 0.8798
# Epoch 44 | Val Acc: 0.8777
# Epoch 45 | Val Acc: 0.8681
# Epoch 46 | Val Acc: 0.8723
# Epoch 47 | Val Acc: 0.8649
# Epoch 48 | Val Acc: 0.8947
# Epoch 49 | Val Acc: 0.8915
# Epoch 50 | Val Acc: 0.8894
# Epoch 51 | Val Acc: 0.8787
# Epoch 52 | Val Acc: 0.8681
# Epoch 53 | Val Acc: 0.8809
# Epoch 54 | Val Acc: 0.8670
# Epoch 55 | Val Acc: 0.8904
# Early stopping
# Best accuracy (split 2): 0.8947
#
# ===== Split 3 =====
# Epoch 01 | Val Acc: 0.1298
# Epoch 02 | Val Acc: 0.3128
# Epoch 03 | Val Acc: 0.4340
# Epoch 04 | Val Acc: 0.5340
# Epoch 05 | Val Acc: 0.6245
# Epoch 06 | Val Acc: 0.6585
# Epoch 07 | Val Acc: 0.6915
# Epoch 08 | Val Acc: 0.7202
# Epoch 09 | Val Acc: 0.7553
# Epoch 10 | Val Acc: 0.7468
# Epoch 11 | Val Acc: 0.7904
# Epoch 12 | Val Acc: 0.7394
# Epoch 13 | Val Acc: 0.8043
# Epoch 14 | Val Acc: 0.8021
# Epoch 15 | Val Acc: 0.8064
# Epoch 16 | Val Acc: 0.8266
# Epoch 17 | Val Acc: 0.8170
# Epoch 18 | Val Acc: 0.8511
# Epoch 19 | Val Acc: 0.8436
# Epoch 20 | Val Acc: 0.8223
# Epoch 21 | Val Acc: 0.8447
# Epoch 22 | Val Acc: 0.8511
# Epoch 23 | Val Acc: 0.8372
# Epoch 24 | Val Acc: 0.8500
# Epoch 25 | Val Acc: 0.8404
# Early stopping
# Best accuracy (split 3): 0.8511
#
# ===== Split 4 =====
# Epoch 01 | Val Acc: 0.2000
# Epoch 02 | Val Acc: 0.3617
# Epoch 03 | Val Acc: 0.5085
# Epoch 04 | Val Acc: 0.5851
# Epoch 05 | Val Acc: 0.6181
# Epoch 06 | Val Acc: 0.6691
# Epoch 07 | Val Acc: 0.7309
# Epoch 08 | Val Acc: 0.7234
# Epoch 09 | Val Acc: 0.7734
# Epoch 10 | Val Acc: 0.7787
# Epoch 11 | Val Acc: 0.7936
# Epoch 12 | Val Acc: 0.8330
# Epoch 13 | Val Acc: 0.8319
# Epoch 14 | Val Acc: 0.8383
# Epoch 15 | Val Acc: 0.8447
# Epoch 16 | Val Acc: 0.8426
# Epoch 17 | Val Acc: 0.8585
# Epoch 18 | Val Acc: 0.8543
# Epoch 19 | Val Acc: 0.8596
# Epoch 20 | Val Acc: 0.8809
# Epoch 21 | Val Acc: 0.8670
# Epoch 22 | Val Acc: 0.8713
# Epoch 23 | Val Acc: 0.8723
# Epoch 24 | Val Acc: 0.8564
# Epoch 25 | Val Acc: 0.8830
# Epoch 26 | Val Acc: 0.8691
# Epoch 27 | Val Acc: 0.8798
# Epoch 28 | Val Acc: 0.8840
# Epoch 29 | Val Acc: 0.8819
# Epoch 30 | Val Acc: 0.8947
# Epoch 31 | Val Acc: 0.8957
# Epoch 32 | Val Acc: 0.8904
# Epoch 33 | Val Acc: 0.8809
# Epoch 34 | Val Acc: 0.8883
# Epoch 35 | Val Acc: 0.8713
# Epoch 36 | Val Acc: 0.8904
# Epoch 37 | Val Acc: 0.8628
# Epoch 38 | Val Acc: 0.8649
# Early stopping
# Best accuracy (split 4): 0.8957
#
# ===== Split 5 =====
# Epoch 01 | Val Acc: 0.1979
# Epoch 02 | Val Acc: 0.3574
# Epoch 03 | Val Acc: 0.4777
# Epoch 04 | Val Acc: 0.5340
# Epoch 05 | Val Acc: 0.6245
# Epoch 06 | Val Acc: 0.6532
# Epoch 07 | Val Acc: 0.6862
# Epoch 08 | Val Acc: 0.7309
# Epoch 09 | Val Acc: 0.7596
# Epoch 10 | Val Acc: 0.7819
# Epoch 11 | Val Acc: 0.7606
# Epoch 12 | Val Acc: 0.8053
# Epoch 13 | Val Acc: 0.7915
# Epoch 14 | Val Acc: 0.8170
# Epoch 15 | Val Acc: 0.8255
# Epoch 16 | Val Acc: 0.8330
# Epoch 17 | Val Acc: 0.8309
# Epoch 18 | Val Acc: 0.8266
# Epoch 19 | Val Acc: 0.8404
# Epoch 20 | Val Acc: 0.8468
# Epoch 21 | Val Acc: 0.8372
# Epoch 22 | Val Acc: 0.8596
# Epoch 23 | Val Acc: 0.8723
# Epoch 24 | Val Acc: 0.8564
# Epoch 25 | Val Acc: 0.8521
# Epoch 26 | Val Acc: 0.8713
# Epoch 27 | Val Acc: 0.8500
# Epoch 28 | Val Acc: 0.8766
# Epoch 29 | Val Acc: 0.8574
# Epoch 30 | Val Acc: 0.8734
# Epoch 31 | Val Acc: 0.8755
# Epoch 32 | Val Acc: 0.8691
# Epoch 33 | Val Acc: 0.8617
# Epoch 34 | Val Acc: 0.8809
# Epoch 35 | Val Acc: 0.8691
# Epoch 36 | Val Acc: 0.8691
# Epoch 37 | Val Acc: 0.8574
# Epoch 38 | Val Acc: 0.8670
# Epoch 39 | Val Acc: 0.8723
# Epoch 40 | Val Acc: 0.8819
# Epoch 41 | Val Acc: 0.8798
# Epoch 42 | Val Acc: 0.8713
# Epoch 43 | Val Acc: 0.8755
# Epoch 44 | Val Acc: 0.8777
# Epoch 45 | Val Acc: 0.8809
# Epoch 46 | Val Acc: 0.8936
# Epoch 47 | Val Acc: 0.8915
# Epoch 48 | Val Acc: 0.8862
# Epoch 49 | Val Acc: 0.8649
# Epoch 50 | Val Acc: 0.8830
# Epoch 51 | Val Acc: 0.8755
# Epoch 52 | Val Acc: 0.8957
# Epoch 53 | Val Acc: 0.8649
# Epoch 54 | Val Acc: 0.8968
# Epoch 55 | Val Acc: 0.9011
# Epoch 56 | Val Acc: 0.8957
# Epoch 57 | Val Acc: 0.9000
# Epoch 58 | Val Acc: 0.8894
# Epoch 59 | Val Acc: 0.8798
# Epoch 60 | Val Acc: 0.8766
# Epoch 61 | Val Acc: 0.8766
# Epoch 62 | Val Acc: 0.8755
# Early stopping
# Best accuracy (split 5): 0.9011
#
# ===== Split 6 =====
# Epoch 01 | Val Acc: 0.1713
# Epoch 02 | Val Acc: 0.3415
# Epoch 03 | Val Acc: 0.4798
# Epoch 04 | Val Acc: 0.5394
# Epoch 05 | Val Acc: 0.6085
# Epoch 06 | Val Acc: 0.6426
# Epoch 07 | Val Acc: 0.6872
# Epoch 08 | Val Acc: 0.7202
# Epoch 09 | Val Acc: 0.7574
# Epoch 10 | Val Acc: 0.7457
# Epoch 11 | Val Acc: 0.7809
# Epoch 12 | Val Acc: 0.7638
# Epoch 13 | Val Acc: 0.7755
# Epoch 14 | Val Acc: 0.7787
# Epoch 15 | Val Acc: 0.7862
# Epoch 16 | Val Acc: 0.8213
# Epoch 17 | Val Acc: 0.8128
# Epoch 18 | Val Acc: 0.8213
# Epoch 19 | Val Acc: 0.8287
# Epoch 20 | Val Acc: 0.8117
# Epoch 21 | Val Acc: 0.8489
# Epoch 22 | Val Acc: 0.8340
# Epoch 23 | Val Acc: 0.8479
# Epoch 24 | Val Acc: 0.8468
# Epoch 25 | Val Acc: 0.8383
# Epoch 26 | Val Acc: 0.8489
# Epoch 27 | Val Acc: 0.8298
# Epoch 28 | Val Acc: 0.8426
# Early stopping
# Best accuracy (split 6): 0.8489
#
# ===== Split 7 =====
# Epoch 01 | Val Acc: 0.1500
# Epoch 02 | Val Acc: 0.2957
# Epoch 03 | Val Acc: 0.4245
# Epoch 04 | Val Acc: 0.5362
# Epoch 05 | Val Acc: 0.5766
# Epoch 06 | Val Acc: 0.6404
# Epoch 07 | Val Acc: 0.6532
# Epoch 08 | Val Acc: 0.6947
# Epoch 09 | Val Acc: 0.7064
# Epoch 10 | Val Acc: 0.7383
# Epoch 11 | Val Acc: 0.7532
# Epoch 12 | Val Acc: 0.7511
# Epoch 13 | Val Acc: 0.7777
# Epoch 14 | Val Acc: 0.7745
# Epoch 15 | Val Acc: 0.7734
# Epoch 16 | Val Acc: 0.8160
# Epoch 17 | Val Acc: 0.7968
# Epoch 18 | Val Acc: 0.8138
# Epoch 19 | Val Acc: 0.8117
# Epoch 20 | Val Acc: 0.8223
# Epoch 21 | Val Acc: 0.8287
# Epoch 22 | Val Acc: 0.8404
# Epoch 23 | Val Acc: 0.8351
# Epoch 24 | Val Acc: 0.8340
# Epoch 25 | Val Acc: 0.8436
# Epoch 26 | Val Acc: 0.8585
# Epoch 27 | Val Acc: 0.8404
# Epoch 28 | Val Acc: 0.8585
# Epoch 29 | Val Acc: 0.8511
# Epoch 30 | Val Acc: 0.8340
# Epoch 31 | Val Acc: 0.8128
# Epoch 32 | Val Acc: 0.8617
# Epoch 33 | Val Acc: 0.8511
# Epoch 34 | Val Acc: 0.8649
# Epoch 35 | Val Acc: 0.8585
# Epoch 36 | Val Acc: 0.8543
# Epoch 37 | Val Acc: 0.8596
# Epoch 38 | Val Acc: 0.8702
# Epoch 39 | Val Acc: 0.8596
# Epoch 40 | Val Acc: 0.8553
# Epoch 41 | Val Acc: 0.8426
# Epoch 42 | Val Acc: 0.8617
# Epoch 43 | Val Acc: 0.8638
# Epoch 44 | Val Acc: 0.8649
# Epoch 45 | Val Acc: 0.8691
# Early stopping
# Best accuracy (split 7): 0.8702
#
# ===== Split 8 =====
# Epoch 01 | Val Acc: 0.1447
# Epoch 02 | Val Acc: 0.3394
# Epoch 03 | Val Acc: 0.4404
# Epoch 04 | Val Acc: 0.5191
# Epoch 05 | Val Acc: 0.6021
# Epoch 06 | Val Acc: 0.6128
# Epoch 07 | Val Acc: 0.6521
# Epoch 08 | Val Acc: 0.6936
# Epoch 09 | Val Acc: 0.7074
# Epoch 10 | Val Acc: 0.7287
# Epoch 11 | Val Acc: 0.7489
# Epoch 12 | Val Acc: 0.7564
# Epoch 13 | Val Acc: 0.7479
# Epoch 14 | Val Acc: 0.7840
# Epoch 15 | Val Acc: 0.7851
# Epoch 16 | Val Acc: 0.8128
# Epoch 17 | Val Acc: 0.7660
# Epoch 18 | Val Acc: 0.8191
# Epoch 19 | Val Acc: 0.8298
# Epoch 20 | Val Acc: 0.8351
# Epoch 21 | Val Acc: 0.8277
# Epoch 22 | Val Acc: 0.8500
# Epoch 23 | Val Acc: 0.8277
# Epoch 24 | Val Acc: 0.8138
# Epoch 25 | Val Acc: 0.8436
# Epoch 26 | Val Acc: 0.8383
# Epoch 27 | Val Acc: 0.8372
# Epoch 28 | Val Acc: 0.8415
# Epoch 29 | Val Acc: 0.8298
# Early stopping
# Best accuracy (split 8): 0.8500
#
# ===== Split 9 =====
# Epoch 01 | Val Acc: 0.1702
# Epoch 02 | Val Acc: 0.2883
# Epoch 03 | Val Acc: 0.4489
# Epoch 04 | Val Acc: 0.5074
# Epoch 05 | Val Acc: 0.5436
# Epoch 06 | Val Acc: 0.5968
# Epoch 07 | Val Acc: 0.6404
# Epoch 08 | Val Acc: 0.6649
# Epoch 09 | Val Acc: 0.6904
# Epoch 10 | Val Acc: 0.6968
# Epoch 11 | Val Acc: 0.6957
# Epoch 12 | Val Acc: 0.7511
# Epoch 13 | Val Acc: 0.7468
# Epoch 14 | Val Acc: 0.7564
# Epoch 15 | Val Acc: 0.7553
# Epoch 16 | Val Acc: 0.7713
# Epoch 17 | Val Acc: 0.7851
# Epoch 18 | Val Acc: 0.7638
# Epoch 19 | Val Acc: 0.7957
# Epoch 20 | Val Acc: 0.7904
# Epoch 21 | Val Acc: 0.7989
# Epoch 22 | Val Acc: 0.8138
# Epoch 23 | Val Acc: 0.8043
# Epoch 24 | Val Acc: 0.8191
# Epoch 25 | Val Acc: 0.8266
# Epoch 26 | Val Acc: 0.8340
# Epoch 27 | Val Acc: 0.8277
# Epoch 28 | Val Acc: 0.8223
# Epoch 29 | Val Acc: 0.8223
# Epoch 30 | Val Acc: 0.8309
# Epoch 31 | Val Acc: 0.8181
# Epoch 32 | Val Acc: 0.8415
# Epoch 33 | Val Acc: 0.8266
# Epoch 34 | Val Acc: 0.8266
# Epoch 35 | Val Acc: 0.8426
# Epoch 36 | Val Acc: 0.8309
# Epoch 37 | Val Acc: 0.8266
# Epoch 38 | Val Acc: 0.8543
# Epoch 39 | Val Acc: 0.8415
# Epoch 40 | Val Acc: 0.8574
# Epoch 41 | Val Acc: 0.8447
# Epoch 42 | Val Acc: 0.8532
# Epoch 43 | Val Acc: 0.8553
# Epoch 44 | Val Acc: 0.8436
# Epoch 45 | Val Acc: 0.8532
# Epoch 46 | Val Acc: 0.8617
# Epoch 47 | Val Acc: 0.8447
# Epoch 48 | Val Acc: 0.8457
# Epoch 49 | Val Acc: 0.8447
# Epoch 50 | Val Acc: 0.8691
# Epoch 51 | Val Acc: 0.8649
# Epoch 52 | Val Acc: 0.8681
# Epoch 53 | Val Acc: 0.8596
# Epoch 54 | Val Acc: 0.8660
# Epoch 55 | Val Acc: 0.8426
# Epoch 56 | Val Acc: 0.8298
# Epoch 57 | Val Acc: 0.8468
# Early stopping
# Best accuracy (split 9): 0.8691
#
# ===== Split 10 =====
# Epoch 01 | Val Acc: 0.1489
# Epoch 02 | Val Acc: 0.2479
# Epoch 03 | Val Acc: 0.4404
# Epoch 04 | Val Acc: 0.5074
# Epoch 05 | Val Acc: 0.5500
# Epoch 06 | Val Acc: 0.6106
# Epoch 07 | Val Acc: 0.6245
# Epoch 08 | Val Acc: 0.6670
# Epoch 09 | Val Acc: 0.6989
# Epoch 10 | Val Acc: 0.7266
# Epoch 11 | Val Acc: 0.7181
# Epoch 12 | Val Acc: 0.7319
# Epoch 13 | Val Acc: 0.7500
# Epoch 14 | Val Acc: 0.7606
# Epoch 15 | Val Acc: 0.7755
# Epoch 16 | Val Acc: 0.7755
# Epoch 17 | Val Acc: 0.7521
# Epoch 18 | Val Acc: 0.7617
# Epoch 19 | Val Acc: 0.7830
# Epoch 20 | Val Acc: 0.7979
# Epoch 21 | Val Acc: 0.7989
# Epoch 22 | Val Acc: 0.7787
# Epoch 23 | Val Acc: 0.7894
# Epoch 24 | Val Acc: 0.8138
# Epoch 25 | Val Acc: 0.8149
# Epoch 26 | Val Acc: 0.8266
# Epoch 27 | Val Acc: 0.8149
# Epoch 28 | Val Acc: 0.8128
# Epoch 29 | Val Acc: 0.8457
# Epoch 30 | Val Acc: 0.8436
# Epoch 31 | Val Acc: 0.8202
# Epoch 32 | Val Acc: 0.8223
# Epoch 33 | Val Acc: 0.8330
# Epoch 34 | Val Acc: 0.8479
# Epoch 35 | Val Acc: 0.8245
# Epoch 36 | Val Acc: 0.8372
# Epoch 37 | Val Acc: 0.8277
# Epoch 38 | Val Acc: 0.8309
# Epoch 39 | Val Acc: 0.8277
# Epoch 40 | Val Acc: 0.8383
# Epoch 41 | Val Acc: 0.8457
# Early stopping
# Best accuracy (split 10): 0.8479
#
# FINAL AVERAGE ACCURACY (CNN + CCE): 0.8647872340425533
