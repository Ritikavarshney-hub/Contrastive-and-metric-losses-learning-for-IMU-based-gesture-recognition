# %%
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.optim import Adam

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

class EMGDataset(Dataset):
    def __init__(self, x_path, y_path):
        X = np.load(x_path)          
        y = np.load(y_path)           
        for i in range(X.shape[0]):
            for c in range(6):
                X[i, :, c] = (X[i, :, c] - X[i, :, c].mean()) / (X[i, :, c].std() + 1e-8)

        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(np.argmax(y, axis=1), dtype=torch.long)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

class CNNEncoder(nn.Module):
    def __init__(self):
        super().__init__()

        self.net = nn.Sequential(
            nn.Conv1d(6, 64, kernel_size=10),
            nn.ReLU(),
            nn.Conv1d(64, 64, kernel_size=10),
            nn.ReLU(),
            nn.MaxPool1d(3),

            nn.Conv1d(64, 256, kernel_size=10),
            nn.ReLU(),
            nn.Conv1d(256, 256, kernel_size=10),
            nn.ReLU(),

            nn.AdaptiveAvgPool1d(1)  
        )

    def forward(self, x):
        x = x.permute(0, 2, 1)  
        x = self.net(x)
        return x.squeeze(-1)   

class FullModel(nn.Module):
    def __init__(self, encoder, num_classes=62):
        super().__init__()
        self.encoder = encoder
        self.classifier = nn.Linear(256, num_classes)

    def forward(self, x):
        emb = self.encoder(x)
        logits = self.classifier(emb)
        return logits

class EarlyStopping:
    def __init__(self, patience=7):
        self.patience = patience
        self.best_acc = 0.0
        self.counter = 0
        self.best_state = None

    def step(self, acc, model):
        if acc > self.best_acc:
            self.best_acc = acc
            self.counter = 0
            self.best_state = {
                k: v.detach().cpu().clone()
                for k, v in model.state_dict().items()
            }
            return False
        else:
            self.counter += 1
            return self.counter >= self.patience

    def restore(self, model):
        model.load_state_dict(self.best_state)

def train_and_eval(model, train_loader, test_loader,
                   epochs=500, patience=10):

    criterion = nn.CrossEntropyLoss()
    optimizer = Adam(model.parameters(), lr=0.0005)
    early_stopper = EarlyStopping(patience)

    for epoch in range(epochs):
        model.train()
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)

            logits = model(x)
            loss = criterion(logits, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        model.eval()
        correct, total = 0, 0
        with torch.no_grad():
            for x, y in test_loader:
                x, y = x.to(device), y.to(device)
                preds = model(x).argmax(1)
                correct += (preds == y).sum().item()
                total += y.size(0)

        val_acc = correct / total
        print(f"Epoch {epoch+1:02d} | Val Acc: {val_acc:.4f}")

        if early_stopper.step(val_acc, model):
            print("Early stopping")
            break

    early_stopper.restore(model)
    return early_stopper.best_acc

BASE = "models/Data/Data/62_classes/UserDependenet"

accs = []

for split in range(1, 11):
    print(f"\n===== Split {split} =====")

    train_ds = EMGDataset(
        f"{BASE}/Train/X_train_{split}.npy",
        f"{BASE}/Train/y_train_{split}.npy"
    )
    test_ds = EMGDataset(
        f"{BASE}/Test/X_test_{split}.npy",
        f"{BASE}/Test/y_test_{split}.npy"
    )

    train_loader = DataLoader(train_ds, batch_size=128, shuffle=True)
    test_loader = DataLoader(test_ds, batch_size=128)

    model = FullModel(CNNEncoder(), num_classes=62).to(device)

    acc = train_and_eval(model, train_loader, test_loader)
    accs.append(acc)

    print(f"Best accuracy (split {split}): {acc:.4f}")

print("\nFINAL AVERAGE ACCURACY (CNN + CCE):", np.mean(accs))
# Out:
# Using device: cuda
#
# ===== Split 1 =====
# Epoch 01 | Val Acc: 0.1548
# Epoch 02 | Val Acc: 0.3508
# Epoch 03 | Val Acc: 0.4766
# Epoch 04 | Val Acc: 0.5113
# Epoch 05 | Val Acc: 0.5653
# Epoch 06 | Val Acc: 0.6129
# Epoch 07 | Val Acc: 0.6097
# Epoch 08 | Val Acc: 0.6266
# Epoch 09 | Val Acc: 0.6145
# Epoch 10 | Val Acc: 0.6613
# Epoch 11 | Val Acc: 0.6653
# Epoch 12 | Val Acc: 0.6653
# Epoch 13 | Val Acc: 0.6871
# Epoch 14 | Val Acc: 0.6984
# Epoch 15 | Val Acc: 0.6952
# Epoch 16 | Val Acc: 0.7016
# Epoch 17 | Val Acc: 0.6960
# Epoch 18 | Val Acc: 0.6911
# Epoch 19 | Val Acc: 0.7097
# Epoch 20 | Val Acc: 0.7008
# Epoch 21 | Val Acc: 0.7226
# Epoch 22 | Val Acc: 0.7210
# Epoch 23 | Val Acc: 0.7113
# Epoch 24 | Val Acc: 0.7242
# Epoch 25 | Val Acc: 0.7161
# Epoch 26 | Val Acc: 0.7266
# Epoch 27 | Val Acc: 0.7153
# Epoch 28 | Val Acc: 0.7363
# Epoch 29 | Val Acc: 0.7226
# Epoch 30 | Val Acc: 0.7194
# Epoch 31 | Val Acc: 0.7355
# Epoch 32 | Val Acc: 0.7419
# Epoch 33 | Val Acc: 0.7331
# Epoch 34 | Val Acc: 0.7210
# Epoch 35 | Val Acc: 0.7363
# Epoch 36 | Val Acc: 0.7234
# Epoch 37 | Val Acc: 0.7274
# Epoch 38 | Val Acc: 0.7435
# Epoch 39 | Val Acc: 0.7298
# Epoch 40 | Val Acc: 0.7323
# Epoch 41 | Val Acc: 0.7290
# Epoch 42 | Val Acc: 0.7419
# Epoch 43 | Val Acc: 0.7274
# Epoch 44 | Val Acc: 0.7403
# Epoch 45 | Val Acc: 0.7298
# Epoch 46 | Val Acc: 0.7363
# Epoch 47 | Val Acc: 0.7282
# Epoch 48 | Val Acc: 0.7395
# Early stopping
# Best accuracy (split 1): 0.7435
#
# ===== Split 2 =====
# Epoch 01 | Val Acc: 0.1911
# Epoch 02 | Val Acc: 0.3895
# Epoch 03 | Val Acc: 0.4976
# Epoch 04 | Val Acc: 0.5524
# Epoch 05 | Val Acc: 0.6000
# Epoch 06 | Val Acc: 0.6669
# Epoch 07 | Val Acc: 0.6710
# Epoch 08 | Val Acc: 0.6758
# Epoch 09 | Val Acc: 0.6879
# Epoch 10 | Val Acc: 0.6944
# Epoch 11 | Val Acc: 0.7234
# Epoch 12 | Val Acc: 0.7306
# Epoch 13 | Val Acc: 0.7621
# Epoch 14 | Val Acc: 0.7419
# Epoch 15 | Val Acc: 0.7605
# Epoch 16 | Val Acc: 0.7718
# Epoch 17 | Val Acc: 0.7774
# Epoch 18 | Val Acc: 0.7645
# Epoch 19 | Val Acc: 0.7847
# Epoch 20 | Val Acc: 0.7726
# Epoch 21 | Val Acc: 0.7831
# Epoch 22 | Val Acc: 0.7960
# Epoch 23 | Val Acc: 0.7927
# Epoch 24 | Val Acc: 0.7992
# Epoch 25 | Val Acc: 0.7944
# Epoch 26 | Val Acc: 0.8065
# Epoch 27 | Val Acc: 0.8065
# Epoch 28 | Val Acc: 0.7984
# Epoch 29 | Val Acc: 0.8073
# Epoch 30 | Val Acc: 0.8040
# Epoch 31 | Val Acc: 0.7911
# Epoch 32 | Val Acc: 0.8032
# Epoch 33 | Val Acc: 0.8065
# Epoch 34 | Val Acc: 0.8032
# Epoch 35 | Val Acc: 0.7960
# Epoch 36 | Val Acc: 0.8161
# Epoch 37 | Val Acc: 0.8073
# Epoch 38 | Val Acc: 0.7992
# Epoch 39 | Val Acc: 0.7976
# Epoch 40 | Val Acc: 0.8234
# Epoch 41 | Val Acc: 0.8161
# Epoch 42 | Val Acc: 0.7944
# Epoch 43 | Val Acc: 0.8113
# Epoch 44 | Val Acc: 0.8032
# Epoch 45 | Val Acc: 0.8024
# Epoch 46 | Val Acc: 0.8323
# Epoch 47 | Val Acc: 0.8323
# Epoch 48 | Val Acc: 0.8161
# Epoch 49 | Val Acc: 0.8161
# Epoch 50 | Val Acc: 0.8016
# Epoch 51 | Val Acc: 0.8226
# Epoch 52 | Val Acc: 0.8145
# Epoch 53 | Val Acc: 0.8194
# Epoch 54 | Val Acc: 0.8347
# Epoch 55 | Val Acc: 0.8194
# Epoch 56 | Val Acc: 0.8266
# Epoch 57 | Val Acc: 0.8194
# Epoch 58 | Val Acc: 0.8177
# Epoch 59 | Val Acc: 0.8218
# Epoch 60 | Val Acc: 0.8169
# Epoch 61 | Val Acc: 0.8169
# Epoch 62 | Val Acc: 0.8065
# Epoch 63 | Val Acc: 0.8073
# Epoch 64 | Val Acc: 0.8105
# Early stopping
# Best accuracy (split 2): 0.8347
#
# ===== Split 3 =====
# Epoch 01 | Val Acc: 0.1790
# Epoch 02 | Val Acc: 0.3290
# Epoch 03 | Val Acc: 0.4815
# Epoch 04 | Val Acc: 0.5363
# Epoch 05 | Val Acc: 0.5742
# Epoch 06 | Val Acc: 0.6040
# Epoch 07 | Val Acc: 0.6194
# Epoch 08 | Val Acc: 0.6371
# Epoch 09 | Val Acc: 0.6718
# Epoch 10 | Val Acc: 0.6685
# Epoch 11 | Val Acc: 0.6798
# Epoch 12 | Val Acc: 0.6726
# Epoch 13 | Val Acc: 0.7089
# Epoch 14 | Val Acc: 0.7040
# Epoch 15 | Val Acc: 0.7185
# Epoch 16 | Val Acc: 0.7476
# Epoch 17 | Val Acc: 0.7323
# Epoch 18 | Val Acc: 0.7484
# Epoch 19 | Val Acc: 0.7597
# Epoch 20 | Val Acc: 0.7540
# Epoch 21 | Val Acc: 0.7597
# Epoch 22 | Val Acc: 0.7823
# Epoch 23 | Val Acc: 0.7847
# Epoch 24 | Val Acc: 0.7653
# Epoch 25 | Val Acc: 0.7742
# Epoch 26 | Val Acc: 0.7798
# Epoch 27 | Val Acc: 0.7847
# Epoch 28 | Val Acc: 0.7847
# Epoch 29 | Val Acc: 0.7847
# Epoch 30 | Val Acc: 0.7935
# Epoch 31 | Val Acc: 0.7919
# Epoch 32 | Val Acc: 0.7863
# Epoch 33 | Val Acc: 0.7863
# Epoch 34 | Val Acc: 0.7935
# Epoch 35 | Val Acc: 0.7968
# Epoch 36 | Val Acc: 0.7927
# Epoch 37 | Val Acc: 0.7927
# Epoch 38 | Val Acc: 0.8105
# Epoch 39 | Val Acc: 0.8089
# Epoch 40 | Val Acc: 0.8089
# Epoch 41 | Val Acc: 0.7944
# Epoch 42 | Val Acc: 0.8024
# Epoch 43 | Val Acc: 0.8129
# Epoch 44 | Val Acc: 0.8234
# Epoch 45 | Val Acc: 0.8113
# Epoch 46 | Val Acc: 0.8040
# Epoch 47 | Val Acc: 0.8169
# Epoch 48 | Val Acc: 0.7952
# Epoch 49 | Val Acc: 0.8137
# Epoch 50 | Val Acc: 0.8226
# Epoch 51 | Val Acc: 0.8315
# Epoch 52 | Val Acc: 0.8274
# Epoch 53 | Val Acc: 0.8161
# Epoch 54 | Val Acc: 0.7992
# Epoch 55 | Val Acc: 0.8306
# Epoch 56 | Val Acc: 0.8339
# Epoch 57 | Val Acc: 0.8331
# Epoch 58 | Val Acc: 0.8185
# Epoch 59 | Val Acc: 0.8202
# Epoch 60 | Val Acc: 0.8210
# Epoch 61 | Val Acc: 0.8210
# Epoch 62 | Val Acc: 0.8323
# Epoch 63 | Val Acc: 0.8185
# Epoch 64 | Val Acc: 0.8331
# Epoch 65 | Val Acc: 0.8298
# Epoch 66 | Val Acc: 0.8210
# Early stopping
# Best accuracy (split 3): 0.8339
#
# ===== Split 4 =====
# Epoch 01 | Val Acc: 0.1960
# Epoch 02 | Val Acc: 0.4024
# Epoch 03 | Val Acc: 0.4984
# Epoch 04 | Val Acc: 0.5903
# Epoch 05 | Val Acc: 0.6081
# Epoch 06 | Val Acc: 0.6484
# Epoch 07 | Val Acc: 0.6702
# Epoch 08 | Val Acc: 0.6984
# Epoch 09 | Val Acc: 0.6952
# Epoch 10 | Val Acc: 0.7427
# Epoch 11 | Val Acc: 0.7444
# Epoch 12 | Val Acc: 0.7565
# Epoch 13 | Val Acc: 0.7694
# Epoch 14 | Val Acc: 0.7653
# Epoch 15 | Val Acc: 0.7750
# Epoch 16 | Val Acc: 0.7871
# Epoch 17 | Val Acc: 0.7806
# Epoch 18 | Val Acc: 0.7847
# Epoch 19 | Val Acc: 0.7903
# Epoch 20 | Val Acc: 0.8000
# Epoch 21 | Val Acc: 0.7968
# Epoch 22 | Val Acc: 0.7927
# Epoch 23 | Val Acc: 0.7944
# Epoch 24 | Val Acc: 0.8113
# Epoch 25 | Val Acc: 0.8073
# Epoch 26 | Val Acc: 0.8056
# Epoch 27 | Val Acc: 0.8081
# Epoch 28 | Val Acc: 0.8097
# Epoch 29 | Val Acc: 0.8137
# Epoch 30 | Val Acc: 0.8121
# Epoch 31 | Val Acc: 0.8105
# Epoch 32 | Val Acc: 0.8137
# Epoch 33 | Val Acc: 0.8210
# Epoch 34 | Val Acc: 0.8282
# Epoch 35 | Val Acc: 0.8274
# Epoch 36 | Val Acc: 0.8290
# Epoch 37 | Val Acc: 0.8145
# Epoch 38 | Val Acc: 0.8339
# Epoch 39 | Val Acc: 0.8250
# Epoch 40 | Val Acc: 0.8371
# Epoch 41 | Val Acc: 0.8258
# Epoch 42 | Val Acc: 0.8250
# Epoch 43 | Val Acc: 0.8210
# Epoch 44 | Val Acc: 0.8444
# Epoch 45 | Val Acc: 0.8226
# Epoch 46 | Val Acc: 0.8403
# Epoch 47 | Val Acc: 0.8331
# Epoch 48 | Val Acc: 0.8339
# Epoch 49 | Val Acc: 0.8387
# Epoch 50 | Val Acc: 0.8444
# Epoch 51 | Val Acc: 0.8315
# Epoch 52 | Val Acc: 0.8500
# Epoch 53 | Val Acc: 0.8210
# Epoch 54 | Val Acc: 0.8194
# Epoch 55 | Val Acc: 0.8452
# Epoch 56 | Val Acc: 0.8306
# Epoch 57 | Val Acc: 0.8250
# Epoch 58 | Val Acc: 0.8306
# Epoch 59 | Val Acc: 0.8347
# Epoch 60 | Val Acc: 0.8250
# Epoch 61 | Val Acc: 0.8435
# Epoch 62 | Val Acc: 0.8347
# Early stopping
# Best accuracy (split 4): 0.8500
#
# ===== Split 5 =====
# Epoch 01 | Val Acc: 0.1677
# Epoch 02 | Val Acc: 0.3629
# Epoch 03 | Val Acc: 0.4782
# Epoch 04 | Val Acc: 0.5556
# Epoch 05 | Val Acc: 0.6056
# Epoch 06 | Val Acc: 0.6710
# Epoch 07 | Val Acc: 0.6629
# Epoch 08 | Val Acc: 0.6944
# Epoch 09 | Val Acc: 0.7089
# Epoch 10 | Val Acc: 0.7371
# Epoch 11 | Val Acc: 0.7468
# Epoch 12 | Val Acc: 0.7435
# Epoch 13 | Val Acc: 0.7419
# Epoch 14 | Val Acc: 0.7742
# Epoch 15 | Val Acc: 0.7685
# Epoch 16 | Val Acc: 0.7879
# Epoch 17 | Val Acc: 0.7774
# Epoch 18 | Val Acc: 0.8024
# Epoch 19 | Val Acc: 0.8089
# Epoch 20 | Val Acc: 0.8040
# Epoch 21 | Val Acc: 0.8073
# Epoch 22 | Val Acc: 0.8089
# Epoch 23 | Val Acc: 0.8226
# Epoch 24 | Val Acc: 0.8258
# Epoch 25 | Val Acc: 0.8177
# Epoch 26 | Val Acc: 0.8242
# Epoch 27 | Val Acc: 0.8218
# Epoch 28 | Val Acc: 0.8315
# Epoch 29 | Val Acc: 0.8274
# Epoch 30 | Val Acc: 0.8290
# Epoch 31 | Val Acc: 0.8468
# Epoch 32 | Val Acc: 0.8323
# Epoch 33 | Val Acc: 0.8355
# Epoch 34 | Val Acc: 0.8339
# Epoch 35 | Val Acc: 0.8403
# Epoch 36 | Val Acc: 0.8387
# Epoch 37 | Val Acc: 0.8315
# Epoch 38 | Val Acc: 0.8403
# Epoch 39 | Val Acc: 0.8306
# Epoch 40 | Val Acc: 0.8427
# Epoch 41 | Val Acc: 0.8452
# Early stopping
# Best accuracy (split 5): 0.8468
#
# ===== Split 6 =====
# Epoch 01 | Val Acc: 0.1847
# Epoch 02 | Val Acc: 0.3452
# Epoch 03 | Val Acc: 0.4629
# Epoch 04 | Val Acc: 0.5556
# Epoch 05 | Val Acc: 0.6081
# Epoch 06 | Val Acc: 0.6153
# Epoch 07 | Val Acc: 0.6395
# Epoch 08 | Val Acc: 0.6879
# Epoch 09 | Val Acc: 0.6839
# Epoch 10 | Val Acc: 0.7121
# Epoch 11 | Val Acc: 0.7129
# Epoch 12 | Val Acc: 0.7355
# Epoch 13 | Val Acc: 0.7379
# Epoch 14 | Val Acc: 0.7427
# Epoch 15 | Val Acc: 0.7452
# Epoch 16 | Val Acc: 0.7605
# Epoch 17 | Val Acc: 0.7790
# Epoch 18 | Val Acc: 0.7815
# Epoch 19 | Val Acc: 0.7903
# Epoch 20 | Val Acc: 0.7815
# Epoch 21 | Val Acc: 0.7879
# Epoch 22 | Val Acc: 0.7782
# Epoch 23 | Val Acc: 0.7984
# Epoch 24 | Val Acc: 0.8024
# Epoch 25 | Val Acc: 0.7887
# Epoch 26 | Val Acc: 0.7952
# Epoch 27 | Val Acc: 0.7903
# Epoch 28 | Val Acc: 0.7968
# Epoch 29 | Val Acc: 0.8121
# Epoch 30 | Val Acc: 0.7952
# Epoch 31 | Val Acc: 0.7960
# Epoch 32 | Val Acc: 0.8000
# Epoch 33 | Val Acc: 0.8121
# Epoch 34 | Val Acc: 0.7911
# Epoch 35 | Val Acc: 0.8194
# Epoch 36 | Val Acc: 0.8081
# Epoch 37 | Val Acc: 0.8097
# Epoch 38 | Val Acc: 0.8194
# Epoch 39 | Val Acc: 0.8081
# Epoch 40 | Val Acc: 0.8194
# Epoch 41 | Val Acc: 0.8234
# Epoch 42 | Val Acc: 0.8177
# Epoch 43 | Val Acc: 0.8315
# Epoch 44 | Val Acc: 0.8040
# Epoch 45 | Val Acc: 0.8347
# Epoch 46 | Val Acc: 0.8089
# Epoch 47 | Val Acc: 0.8169
# Epoch 48 | Val Acc: 0.8202
# Epoch 49 | Val Acc: 0.8411
# Epoch 50 | Val Acc: 0.8355
# Epoch 51 | Val Acc: 0.8290
# Epoch 52 | Val Acc: 0.8161
# Epoch 53 | Val Acc: 0.8355
# Epoch 54 | Val Acc: 0.8258
# Epoch 55 | Val Acc: 0.8169
# Epoch 56 | Val Acc: 0.8323
# Epoch 57 | Val Acc: 0.8153
# Epoch 58 | Val Acc: 0.8379
# Epoch 59 | Val Acc: 0.8210
# Early stopping
# Best accuracy (split 6): 0.8411
#
# ===== Split 7 =====
# Epoch 01 | Val Acc: 0.1790
# Epoch 02 | Val Acc: 0.3750
# Epoch 03 | Val Acc: 0.4927
# Epoch 04 | Val Acc: 0.5331
# Epoch 05 | Val Acc: 0.6008
# Epoch 06 | Val Acc: 0.6282
# Epoch 07 | Val Acc: 0.6750
# Epoch 08 | Val Acc: 0.6895
# Epoch 09 | Val Acc: 0.7169
# Epoch 10 | Val Acc: 0.7153
# Epoch 11 | Val Acc: 0.7194
# Epoch 12 | Val Acc: 0.7315
# Epoch 13 | Val Acc: 0.7371
# Epoch 14 | Val Acc: 0.7597
# Epoch 15 | Val Acc: 0.7379
# Epoch 16 | Val Acc: 0.7702
# Epoch 17 | Val Acc: 0.7702
# Epoch 18 | Val Acc: 0.7895
# Epoch 19 | Val Acc: 0.7960
# Epoch 20 | Val Acc: 0.8000
# Epoch 21 | Val Acc: 0.7871
# Epoch 22 | Val Acc: 0.8113
# Epoch 23 | Val Acc: 0.7927
# Epoch 24 | Val Acc: 0.8008
# Epoch 25 | Val Acc: 0.8032
# Epoch 26 | Val Acc: 0.8161
# Epoch 27 | Val Acc: 0.8097
# Epoch 28 | Val Acc: 0.8137
# Epoch 29 | Val Acc: 0.7976
# Epoch 30 | Val Acc: 0.8177
# Epoch 31 | Val Acc: 0.8274
# Epoch 32 | Val Acc: 0.8258
# Epoch 33 | Val Acc: 0.8121
# Epoch 34 | Val Acc: 0.8274
# Epoch 35 | Val Acc: 0.8250
# Epoch 36 | Val Acc: 0.8282
# Epoch 37 | Val Acc: 0.8331
# Epoch 38 | Val Acc: 0.8290
# Epoch 39 | Val Acc: 0.8185
# Epoch 40 | Val Acc: 0.8113
# Epoch 41 | Val Acc: 0.8258
# Epoch 42 | Val Acc: 0.8040
# Epoch 43 | Val Acc: 0.8331
# Epoch 44 | Val Acc: 0.8371
# Epoch 45 | Val Acc: 0.8379
# Epoch 46 | Val Acc: 0.8274
# Epoch 47 | Val Acc: 0.8323
# Epoch 48 | Val Acc: 0.8427
# Epoch 49 | Val Acc: 0.8218
# Epoch 50 | Val Acc: 0.8427
# Epoch 51 | Val Acc: 0.8331
# Epoch 52 | Val Acc: 0.8444
# Epoch 53 | Val Acc: 0.8403
# Epoch 54 | Val Acc: 0.8581
# Epoch 55 | Val Acc: 0.8476
# Epoch 56 | Val Acc: 0.8427
# Epoch 57 | Val Acc: 0.8210
# Epoch 58 | Val Acc: 0.8468
# Epoch 59 | Val Acc: 0.8363
# Epoch 60 | Val Acc: 0.8411
# Epoch 61 | Val Acc: 0.8306
# Epoch 62 | Val Acc: 0.8379
# Epoch 63 | Val Acc: 0.8403
# Epoch 64 | Val Acc: 0.8484
# Early stopping
# Best accuracy (split 7): 0.8581
#
# ===== Split 8 =====
# Epoch 01 | Val Acc: 0.1790
# Epoch 02 | Val Acc: 0.3468
# Epoch 03 | Val Acc: 0.4573
# Epoch 04 | Val Acc: 0.5113
# Epoch 05 | Val Acc: 0.5742
# Epoch 06 | Val Acc: 0.5887
# Epoch 07 | Val Acc: 0.6347
# Epoch 08 | Val Acc: 0.6532
# Epoch 09 | Val Acc: 0.6823
# Epoch 10 | Val Acc: 0.6944
# Epoch 11 | Val Acc: 0.6927
# Epoch 12 | Val Acc: 0.7169
# Epoch 13 | Val Acc: 0.7210
# Epoch 14 | Val Acc: 0.7145
# Epoch 15 | Val Acc: 0.7532
# Epoch 16 | Val Acc: 0.7532
# Epoch 17 | Val Acc: 0.7379
# Epoch 18 | Val Acc: 0.7476
# Epoch 19 | Val Acc: 0.7613
# Epoch 20 | Val Acc: 0.7508
# Epoch 21 | Val Acc: 0.7871
# Epoch 22 | Val Acc: 0.7742
# Epoch 23 | Val Acc: 0.7548
# Epoch 24 | Val Acc: 0.7702
# Epoch 25 | Val Acc: 0.7806
# Epoch 26 | Val Acc: 0.7871
# Epoch 27 | Val Acc: 0.7903
# Epoch 28 | Val Acc: 0.7952
# Epoch 29 | Val Acc: 0.7919
# Epoch 30 | Val Acc: 0.7887
# Epoch 31 | Val Acc: 0.8008
# Epoch 32 | Val Acc: 0.8089
# Epoch 33 | Val Acc: 0.7879
# Epoch 34 | Val Acc: 0.8040
# Epoch 35 | Val Acc: 0.7919
# Epoch 36 | Val Acc: 0.8032
# Epoch 37 | Val Acc: 0.8089
# Epoch 38 | Val Acc: 0.8016
# Epoch 39 | Val Acc: 0.8000
# Epoch 40 | Val Acc: 0.7927
# Epoch 41 | Val Acc: 0.8056
# Epoch 42 | Val Acc: 0.7935
# Early stopping
# Best accuracy (split 8): 0.8089
#
# ===== Split 9 =====
# Epoch 01 | Val Acc: 0.1548
# Epoch 02 | Val Acc: 0.3298
# Epoch 03 | Val Acc: 0.4798
# Epoch 04 | Val Acc: 0.5298
# Epoch 05 | Val Acc: 0.5774
# Epoch 06 | Val Acc: 0.6323
# Epoch 07 | Val Acc: 0.6476
# Epoch 08 | Val Acc: 0.6847
# Epoch 09 | Val Acc: 0.6944
# Epoch 10 | Val Acc: 0.7089
# Epoch 11 | Val Acc: 0.7113
# Epoch 12 | Val Acc: 0.7242
# Epoch 13 | Val Acc: 0.7460
# Epoch 14 | Val Acc: 0.7524
# Epoch 15 | Val Acc: 0.7306
# Epoch 16 | Val Acc: 0.7484
# Epoch 17 | Val Acc: 0.7597
# Epoch 18 | Val Acc: 0.7605
# Epoch 19 | Val Acc: 0.7815
# Epoch 20 | Val Acc: 0.7621
# Epoch 21 | Val Acc: 0.7774
# Epoch 22 | Val Acc: 0.7847
# Epoch 23 | Val Acc: 0.7782
# Epoch 24 | Val Acc: 0.8048
# Epoch 25 | Val Acc: 0.8089
# Epoch 26 | Val Acc: 0.7935
# Epoch 27 | Val Acc: 0.7887
# Epoch 28 | Val Acc: 0.7968
# Epoch 29 | Val Acc: 0.8065
# Epoch 30 | Val Acc: 0.7952
# Epoch 31 | Val Acc: 0.7984
# Epoch 32 | Val Acc: 0.8056
# Epoch 33 | Val Acc: 0.8202
# Epoch 34 | Val Acc: 0.8113
# Epoch 35 | Val Acc: 0.8024
# Epoch 36 | Val Acc: 0.8169
# Epoch 37 | Val Acc: 0.8129
# Epoch 38 | Val Acc: 0.8202
# Epoch 39 | Val Acc: 0.8121
# Epoch 40 | Val Acc: 0.8242
# Epoch 41 | Val Acc: 0.8000
# Epoch 42 | Val Acc: 0.8210
# Epoch 43 | Val Acc: 0.8306
# Epoch 44 | Val Acc: 0.8250
# Epoch 45 | Val Acc: 0.8113
# Epoch 46 | Val Acc: 0.8177
# Epoch 47 | Val Acc: 0.8121
# Epoch 48 | Val Acc: 0.8137
# Epoch 49 | Val Acc: 0.8065
# Epoch 50 | Val Acc: 0.8210
# Epoch 51 | Val Acc: 0.8218
# Epoch 52 | Val Acc: 0.8363
# Epoch 53 | Val Acc: 0.8339
# Epoch 54 | Val Acc: 0.8266
# Epoch 55 | Val Acc: 0.8153
# Epoch 56 | Val Acc: 0.8113
# Epoch 57 | Val Acc: 0.8032
# Epoch 58 | Val Acc: 0.8169
# Epoch 59 | Val Acc: 0.8218
# Epoch 60 | Val Acc: 0.8137
# Epoch 61 | Val Acc: 0.8202
# Epoch 62 | Val Acc: 0.8266
# Early stopping
# Best accuracy (split 9): 0.8363
#
# ===== Split 10 =====
# Epoch 01 | Val Acc: 0.1976
# Epoch 02 | Val Acc: 0.3387
# Epoch 03 | Val Acc: 0.4516
# Epoch 04 | Val Acc: 0.5169
# Epoch 05 | Val Acc: 0.5460
# Epoch 06 | Val Acc: 0.6105
# Epoch 07 | Val Acc: 0.6347
# Epoch 08 | Val Acc: 0.6363
# Epoch 09 | Val Acc: 0.6702
# Epoch 10 | Val Acc: 0.6790
# Epoch 11 | Val Acc: 0.6927
# Epoch 12 | Val Acc: 0.7105
# Epoch 13 | Val Acc: 0.6944
# Epoch 14 | Val Acc: 0.7016
# Epoch 15 | Val Acc: 0.7065
# Epoch 16 | Val Acc: 0.7306
# Epoch 17 | Val Acc: 0.7274
# Epoch 18 | Val Acc: 0.7379
# Epoch 19 | Val Acc: 0.7685
# Epoch 20 | Val Acc: 0.7419
# Epoch 21 | Val Acc: 0.7565
# Epoch 22 | Val Acc: 0.7403
# Epoch 23 | Val Acc: 0.7710
# Epoch 24 | Val Acc: 0.7718
# Epoch 25 | Val Acc: 0.7726
# Epoch 26 | Val Acc: 0.7645
# Epoch 27 | Val Acc: 0.7734
# Epoch 28 | Val Acc: 0.7516
# Epoch 29 | Val Acc: 0.7839
# Epoch 30 | Val Acc: 0.7718
# Epoch 31 | Val Acc: 0.7887
# Epoch 32 | Val Acc: 0.7855
# Epoch 33 | Val Acc: 0.7871
# Epoch 34 | Val Acc: 0.7871
# Epoch 35 | Val Acc: 0.8016
# Epoch 36 | Val Acc: 0.7952
# Epoch 37 | Val Acc: 0.7855
# Epoch 38 | Val Acc: 0.7798
# Epoch 39 | Val Acc: 0.7806
# Epoch 40 | Val Acc: 0.7855
# Epoch 41 | Val Acc: 0.7944
# Epoch 42 | Val Acc: 0.7968
# Epoch 43 | Val Acc: 0.7806
# Epoch 44 | Val Acc: 0.7976
# Epoch 45 | Val Acc: 0.7968
# Early stopping
# Best accuracy (split 10): 0.8016
#
# FINAL AVERAGE ACCURACY (CNN + CCE): 0.8254838709677419

# %%
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.optim import Adam

torch.manual_seed(42)
np.random.seed(42)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

class EMGDataset(Dataset):
    def __init__(self, x_path, y_path):
        X = np.load(x_path)
        y = np.load(y_path)

        # channel-wise normalization (same as Keras)
        for i in range(X.shape[0]):
            for c in range(6):
                X[i, :, c] = (X[i, :, c] - X[i, :, c].mean()) / (X[i, :, c].std() + 1e-8)

        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(np.argmax(y, axis=1), dtype=torch.long)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# ---------------- CNN + BiLSTM Model ----------------
class CNN_BiLSTM(nn.Module):
    def __init__(self, num_classes=62):
        super().__init__()

        # CNN part (same filters as Keras)
        self.cnn = nn.Sequential(
            nn.Conv1d(6, 64, kernel_size=10),
            nn.ReLU(),
            nn.Conv1d(64, 64, kernel_size=10),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=3, stride=3),

            nn.Conv1d(64, 256, kernel_size=10),
            nn.ReLU(),
            nn.Conv1d(256, 256, kernel_size=10),
            nn.ReLU()
        )

        # BiLSTM (same idea as Keras)
        self.bilstm = nn.LSTM(
            input_size=256,
            hidden_size=256,
            batch_first=True,
            bidirectional=True
        )

        self.dropout = nn.Dropout(0.5)
        self.classifier = nn.Linear(512, num_classes)  # 256*2

    def forward(self, x):
        # x: (B, T, C)
        x = x.permute(0, 2, 1)       # (B, C, T)
        x = self.cnn(x)              # (B, 256, T')

        x = x.permute(0, 2, 1)       # (B, T', 256)
        out, _ = self.bilstm(x)      # (B, T', 512)

        feat = out[:, -1, :]         # last timestep
        feat = self.dropout(feat)
        logits = self.classifier(feat)

        return logits

# ---------------- Early Stopping ----------------
class EarlyStopping:
    def __init__(self, patience=10):
        self.patience = patience
        self.best_acc = 0.0
        self.counter = 0
        self.best_state = None

    def step(self, acc, model):
        if acc > self.best_acc:
            self.best_acc = acc
            self.counter = 0
            self.best_state = {
                k: v.detach().cpu().clone()
                for k, v in model.state_dict().items()
            }
            return False
        else:
            self.counter += 1
            return self.counter >= self.patience

    def restore(self, model):
        model.load_state_dict(self.best_state)

# ---------------- Train & Evaluate ----------------
def train_and_eval(model, train_loader, test_loader,
                   epochs=500, patience=10):

    criterion = nn.CrossEntropyLoss()
    optimizer = Adam(model.parameters(), lr=5e-4)
    stopper = EarlyStopping(patience)

    for epoch in range(epochs):
        model.train()
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)

            logits = model(x)
            loss = criterion(logits, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        # evaluation
        model.eval()
        correct, total = 0, 0
        with torch.no_grad():
            for x, y in test_loader:
                x, y = x.to(device), y.to(device)
                preds = model(x).argmax(dim=1)
                correct += (preds == y).sum().item()
                total += y.size(0)

        acc = correct / total
        print(f"Epoch {epoch+1:03d} | Val Acc: {acc:.4f}")

        if stopper.step(acc, model):
            print("Early stopping triggered")
            break

    stopper.restore(model)
    return stopper.best_acc

BASE = "models/Data/Data/62_classes/UserDependenet"
accs = []

for split in range(1,11):
    print(f"\n===== SPLIT {split} =====")

    train_ds = EMGDataset(
        f"{BASE}/Train/X_train_{split}.npy",
        f"{BASE}/Train/y_train_{split}.npy"
    )
    test_ds = EMGDataset(
        f"{BASE}/Test/X_test_{split}.npy",
        f"{BASE}/Test/y_test_{split}.npy"
    )

    train_loader = DataLoader(train_ds, batch_size=128, shuffle=True)
    test_loader = DataLoader(test_ds, batch_size=128)

    model = CNN_BiLSTM(num_classes=62).to(device)

    acc = train_and_eval(model, train_loader, test_loader)
    accs.append(acc)

    print(f"Best accuracy (split {split}): {acc:.4f}")

    del model
    torch.cuda.empty_cache()

print("\nFINAL AVERAGE ACCURACY (CNN + BiLSTM + CCE):", np.mean(accs))
# Out:
# Using device: cuda
#
# ===== SPLIT 1 =====
# Epoch 001 | Val Acc: 0.0258
# Epoch 002 | Val Acc: 0.0460
# Epoch 003 | Val Acc: 0.1073
# Epoch 004 | Val Acc: 0.1540
# Epoch 005 | Val Acc: 0.2226
# Epoch 006 | Val Acc: 0.2677
# Epoch 007 | Val Acc: 0.3468
# Epoch 008 | Val Acc: 0.4113
# Epoch 009 | Val Acc: 0.4516
# Epoch 010 | Val Acc: 0.5032
# Epoch 011 | Val Acc: 0.5274
# Epoch 012 | Val Acc: 0.5468
# Epoch 013 | Val Acc: 0.5685
# Epoch 014 | Val Acc: 0.5645
# Epoch 015 | Val Acc: 0.5790
# Epoch 016 | Val Acc: 0.6097
# Epoch 017 | Val Acc: 0.6218
# Epoch 018 | Val Acc: 0.6427
# Epoch 019 | Val Acc: 0.6484
# Epoch 020 | Val Acc: 0.6403
# Epoch 021 | Val Acc: 0.6645
# Epoch 022 | Val Acc: 0.6444
# Epoch 023 | Val Acc: 0.6653
# Epoch 024 | Val Acc: 0.6581
# Epoch 025 | Val Acc: 0.6863
# Epoch 026 | Val Acc: 0.6758
# Epoch 027 | Val Acc: 0.6839
# Epoch 028 | Val Acc: 0.6774
# Epoch 029 | Val Acc: 0.6952
# Epoch 030 | Val Acc: 0.7008
# Epoch 031 | Val Acc: 0.7000
# Epoch 032 | Val Acc: 0.7008
# Epoch 033 | Val Acc: 0.7097
# Epoch 034 | Val Acc: 0.7129
# Epoch 035 | Val Acc: 0.7097
# Epoch 036 | Val Acc: 0.7202
# Epoch 037 | Val Acc: 0.7073
# Epoch 038 | Val Acc: 0.7097
# Epoch 039 | Val Acc: 0.7266
# Epoch 040 | Val Acc: 0.7218
# Epoch 041 | Val Acc: 0.7266
# Epoch 042 | Val Acc: 0.7048
# Epoch 043 | Val Acc: 0.7298
# Epoch 044 | Val Acc: 0.7161
# Epoch 045 | Val Acc: 0.7161
# Epoch 046 | Val Acc: 0.6984
# Epoch 047 | Val Acc: 0.7056
# Epoch 048 | Val Acc: 0.7065
# Epoch 049 | Val Acc: 0.7185
# Epoch 050 | Val Acc: 0.7113
# Epoch 051 | Val Acc: 0.7129
# Epoch 052 | Val Acc: 0.7403
# Epoch 053 | Val Acc: 0.7258
# Epoch 054 | Val Acc: 0.7363
# Epoch 055 | Val Acc: 0.7194
# Epoch 056 | Val Acc: 0.7169
# Epoch 057 | Val Acc: 0.7089
# Epoch 058 | Val Acc: 0.7234
# Epoch 059 | Val Acc: 0.7121
# Epoch 060 | Val Acc: 0.7492
# Epoch 061 | Val Acc: 0.7290
# Epoch 062 | Val Acc: 0.7105
# Epoch 063 | Val Acc: 0.7258
# Epoch 064 | Val Acc: 0.7363
# Epoch 065 | Val Acc: 0.7177
# Epoch 066 | Val Acc: 0.7258
# Epoch 067 | Val Acc: 0.7218
# Epoch 068 | Val Acc: 0.7290
# Epoch 069 | Val Acc: 0.7153
# Epoch 070 | Val Acc: 0.7258
# Early stopping triggered
# Best accuracy (split 1): 0.7492
#
# ===== SPLIT 2 =====
# Epoch 001 | Val Acc: 0.0452
# Epoch 002 | Val Acc: 0.1048
# Epoch 003 | Val Acc: 0.1532
# Epoch 004 | Val Acc: 0.2073
# Epoch 005 | Val Acc: 0.2798
# Epoch 006 | Val Acc: 0.3581
# Epoch 007 | Val Acc: 0.4226
# Epoch 008 | Val Acc: 0.4653
# Epoch 009 | Val Acc: 0.5113
# Epoch 010 | Val Acc: 0.5734
# Epoch 011 | Val Acc: 0.6089
# Epoch 012 | Val Acc: 0.6444
# Epoch 013 | Val Acc: 0.6347
# Epoch 014 | Val Acc: 0.6734
# Epoch 015 | Val Acc: 0.6750
# Epoch 016 | Val Acc: 0.6815
# Epoch 017 | Val Acc: 0.7185
# Epoch 018 | Val Acc: 0.7169
# Epoch 019 | Val Acc: 0.7145
# Epoch 020 | Val Acc: 0.7202
# Epoch 021 | Val Acc: 0.7242
# Epoch 022 | Val Acc: 0.7363
# Epoch 023 | Val Acc: 0.7323
# Epoch 024 | Val Acc: 0.7500
# Epoch 025 | Val Acc: 0.7645
# Epoch 026 | Val Acc: 0.7597
# Epoch 027 | Val Acc: 0.7460
# Epoch 028 | Val Acc: 0.7750
# Epoch 029 | Val Acc: 0.7637
# Epoch 030 | Val Acc: 0.7565
# Epoch 031 | Val Acc: 0.7806
# Epoch 032 | Val Acc: 0.7782
# Epoch 033 | Val Acc: 0.7815
# Epoch 034 | Val Acc: 0.7548
# Epoch 035 | Val Acc: 0.7726
# Epoch 036 | Val Acc: 0.7734
# Epoch 037 | Val Acc: 0.7839
# Epoch 038 | Val Acc: 0.7863
# Epoch 039 | Val Acc: 0.7726
# Epoch 040 | Val Acc: 0.7952
# Epoch 041 | Val Acc: 0.7976
# Epoch 042 | Val Acc: 0.7782
# Epoch 043 | Val Acc: 0.7944
# Epoch 044 | Val Acc: 0.7766
# Epoch 045 | Val Acc: 0.7911
# Epoch 046 | Val Acc: 0.7871
# Epoch 047 | Val Acc: 0.7903
# Epoch 048 | Val Acc: 0.8048
# Epoch 049 | Val Acc: 0.8000
# Epoch 050 | Val Acc: 0.7927
# Epoch 051 | Val Acc: 0.7944
# Epoch 052 | Val Acc: 0.8097
# Epoch 053 | Val Acc: 0.8073
# Epoch 054 | Val Acc: 0.8105
# Epoch 055 | Val Acc: 0.8105
# Epoch 056 | Val Acc: 0.8008
# Epoch 057 | Val Acc: 0.8177
# Epoch 058 | Val Acc: 0.8145
# Epoch 059 | Val Acc: 0.8274
# Epoch 060 | Val Acc: 0.8000
# Epoch 061 | Val Acc: 0.8113
# Epoch 062 | Val Acc: 0.7903
# Epoch 063 | Val Acc: 0.7976
# Epoch 064 | Val Acc: 0.8056
# Epoch 065 | Val Acc: 0.8081
# Epoch 066 | Val Acc: 0.8081
# Epoch 067 | Val Acc: 0.8081
# Epoch 068 | Val Acc: 0.8016
# Epoch 069 | Val Acc: 0.8016
# Early stopping triggered
# Best accuracy (split 2): 0.8274
#
# ===== SPLIT 3 =====
# Epoch 001 | Val Acc: 0.0323
# Epoch 002 | Val Acc: 0.0944
# Epoch 003 | Val Acc: 0.1242
# Epoch 004 | Val Acc: 0.2008
# Epoch 005 | Val Acc: 0.2960
# Epoch 006 | Val Acc: 0.3395
# Epoch 007 | Val Acc: 0.3976
# Epoch 008 | Val Acc: 0.4806
# Epoch 009 | Val Acc: 0.5395
# Epoch 010 | Val Acc: 0.5855
# Epoch 011 | Val Acc: 0.6218
# Epoch 012 | Val Acc: 0.6258
# Epoch 013 | Val Acc: 0.6339
# Epoch 014 | Val Acc: 0.6645
# Epoch 015 | Val Acc: 0.6677
# Epoch 016 | Val Acc: 0.7008
# Epoch 017 | Val Acc: 0.7121
# Epoch 018 | Val Acc: 0.7024
# Epoch 019 | Val Acc: 0.7347
# Epoch 020 | Val Acc: 0.7065
# Epoch 021 | Val Acc: 0.7395
# Epoch 022 | Val Acc: 0.7565
# Epoch 023 | Val Acc: 0.7669
# Epoch 024 | Val Acc: 0.7556
# Epoch 025 | Val Acc: 0.7573
# Epoch 026 | Val Acc: 0.7734
# Epoch 027 | Val Acc: 0.7621
# Epoch 028 | Val Acc: 0.7565
# Epoch 029 | Val Acc: 0.7782
# Epoch 030 | Val Acc: 0.7895
# Epoch 031 | Val Acc: 0.7613
# Epoch 032 | Val Acc: 0.7750
# Epoch 033 | Val Acc: 0.7919
# Epoch 034 | Val Acc: 0.7806
# Epoch 035 | Val Acc: 0.7863
# Epoch 036 | Val Acc: 0.7839
# Epoch 037 | Val Acc: 0.8048
# Epoch 038 | Val Acc: 0.8032
# Epoch 039 | Val Acc: 0.8065
# Epoch 040 | Val Acc: 0.8065
# Epoch 041 | Val Acc: 0.8121
# Epoch 042 | Val Acc: 0.8032
# Epoch 043 | Val Acc: 0.8258
# Epoch 044 | Val Acc: 0.7984
# Epoch 045 | Val Acc: 0.8121
# Epoch 046 | Val Acc: 0.8073
# Epoch 047 | Val Acc: 0.8056
# Epoch 048 | Val Acc: 0.8081
# Epoch 049 | Val Acc: 0.8073
# Epoch 050 | Val Acc: 0.8048
# Epoch 051 | Val Acc: 0.8081
# Epoch 052 | Val Acc: 0.8194
# Epoch 053 | Val Acc: 0.8194
# Early stopping triggered
# Best accuracy (split 3): 0.8258
#
# ===== SPLIT 4 =====
# Epoch 001 | Val Acc: 0.0315
# Epoch 002 | Val Acc: 0.0887
# Epoch 003 | Val Acc: 0.1532
# Epoch 004 | Val Acc: 0.2266
# Epoch 005 | Val Acc: 0.2589
# Epoch 006 | Val Acc: 0.3427
# Epoch 007 | Val Acc: 0.4113
# Epoch 008 | Val Acc: 0.4677
# Epoch 009 | Val Acc: 0.5363
# Epoch 010 | Val Acc: 0.5565
# Epoch 011 | Val Acc: 0.6129
# Epoch 012 | Val Acc: 0.6484
# Epoch 013 | Val Acc: 0.6540
# Epoch 014 | Val Acc: 0.6855
# Epoch 015 | Val Acc: 0.6871
# Epoch 016 | Val Acc: 0.6984
# Epoch 017 | Val Acc: 0.7016
# Epoch 018 | Val Acc: 0.7387
# Epoch 019 | Val Acc: 0.7105
# Epoch 020 | Val Acc: 0.7274
# Epoch 021 | Val Acc: 0.7589
# Epoch 022 | Val Acc: 0.7565
# Epoch 023 | Val Acc: 0.7532
# Epoch 024 | Val Acc: 0.7605
# Epoch 025 | Val Acc: 0.7637
# Epoch 026 | Val Acc: 0.7855
# Epoch 027 | Val Acc: 0.7766
# Epoch 028 | Val Acc: 0.7742
# Epoch 029 | Val Acc: 0.7911
# Epoch 030 | Val Acc: 0.7145
# Epoch 031 | Val Acc: 0.7903
# Epoch 032 | Val Acc: 0.7895
# Epoch 033 | Val Acc: 0.7944
# Epoch 034 | Val Acc: 0.7960
# Epoch 035 | Val Acc: 0.7976
# Epoch 036 | Val Acc: 0.7750
# Epoch 037 | Val Acc: 0.7952
# Epoch 038 | Val Acc: 0.7935
# Epoch 039 | Val Acc: 0.7895
# Epoch 040 | Val Acc: 0.7944
# Epoch 041 | Val Acc: 0.8056
# Epoch 042 | Val Acc: 0.8298
# Epoch 043 | Val Acc: 0.8194
# Epoch 044 | Val Acc: 0.8081
# Epoch 045 | Val Acc: 0.8153
# Epoch 046 | Val Acc: 0.8105
# Epoch 047 | Val Acc: 0.7976
# Epoch 048 | Val Acc: 0.8129
# Epoch 049 | Val Acc: 0.8032
# Epoch 050 | Val Acc: 0.8258
# Epoch 051 | Val Acc: 0.8226
# Epoch 052 | Val Acc: 0.8177
# Early stopping triggered
# Best accuracy (split 4): 0.8298
#
# ===== SPLIT 5 =====
# Epoch 001 | Val Acc: 0.0323
# Epoch 002 | Val Acc: 0.0605
# Epoch 003 | Val Acc: 0.1363
# Epoch 004 | Val Acc: 0.2218
# Epoch 005 | Val Acc: 0.2984
# Epoch 006 | Val Acc: 0.3629
# Epoch 007 | Val Acc: 0.3532
# Epoch 008 | Val Acc: 0.4685
# Epoch 009 | Val Acc: 0.4871
# Epoch 010 | Val Acc: 0.4992
# Epoch 011 | Val Acc: 0.5419
# Epoch 012 | Val Acc: 0.5847
# Epoch 013 | Val Acc: 0.6331
# Epoch 014 | Val Acc: 0.6645
# Epoch 015 | Val Acc: 0.6710
# Epoch 016 | Val Acc: 0.6831
# Epoch 017 | Val Acc: 0.7016
# Epoch 018 | Val Acc: 0.7024
# Epoch 019 | Val Acc: 0.7298
# Epoch 020 | Val Acc: 0.7387
# Epoch 021 | Val Acc: 0.7605
# Epoch 022 | Val Acc: 0.7548
# Epoch 023 | Val Acc: 0.7452
# Epoch 024 | Val Acc: 0.7613
# Epoch 025 | Val Acc: 0.7661
# Epoch 026 | Val Acc: 0.7718
# Epoch 027 | Val Acc: 0.7702
# Epoch 028 | Val Acc: 0.7645
# Epoch 029 | Val Acc: 0.7734
# Epoch 030 | Val Acc: 0.7911
# Epoch 031 | Val Acc: 0.7895
# Epoch 032 | Val Acc: 0.7815
# Epoch 033 | Val Acc: 0.8016
# Epoch 034 | Val Acc: 0.7887
# Epoch 035 | Val Acc: 0.7879
# Epoch 036 | Val Acc: 0.8218
# Epoch 037 | Val Acc: 0.7944
# Epoch 038 | Val Acc: 0.8129
# Epoch 039 | Val Acc: 0.8097
# Epoch 040 | Val Acc: 0.7863
# Epoch 041 | Val Acc: 0.8073
# Epoch 042 | Val Acc: 0.8000
# Epoch 043 | Val Acc: 0.8234
# Epoch 044 | Val Acc: 0.8105
# Epoch 045 | Val Acc: 0.8105
# Epoch 046 | Val Acc: 0.8306
# Epoch 047 | Val Acc: 0.8073
# Epoch 048 | Val Acc: 0.8065
# Epoch 049 | Val Acc: 0.8210
# Epoch 050 | Val Acc: 0.8258
# Epoch 051 | Val Acc: 0.8194
# Epoch 052 | Val Acc: 0.8000
# Epoch 053 | Val Acc: 0.8121
# Epoch 054 | Val Acc: 0.8234
# Epoch 055 | Val Acc: 0.8282
# Epoch 056 | Val Acc: 0.8306
# Early stopping triggered
# Best accuracy (split 5): 0.8306
#
# ===== SPLIT 6 =====
# Epoch 001 | Val Acc: 0.0274
# Epoch 002 | Val Acc: 0.0605
# Epoch 003 | Val Acc: 0.0532
# Epoch 004 | Val Acc: 0.1718
# Epoch 005 | Val Acc: 0.2597
# Epoch 006 | Val Acc: 0.3194
# Epoch 007 | Val Acc: 0.3581
# Epoch 008 | Val Acc: 0.3839
# Epoch 009 | Val Acc: 0.4984
# Epoch 010 | Val Acc: 0.5306
# Epoch 011 | Val Acc: 0.5581
# Epoch 012 | Val Acc: 0.5718
# Epoch 013 | Val Acc: 0.6242
# Epoch 014 | Val Acc: 0.6411
# Epoch 015 | Val Acc: 0.6927
# Epoch 016 | Val Acc: 0.6444
# Epoch 017 | Val Acc: 0.6758
# Epoch 018 | Val Acc: 0.7016
# Epoch 019 | Val Acc: 0.7500
# Epoch 020 | Val Acc: 0.7347
# Epoch 021 | Val Acc: 0.7548
# Epoch 022 | Val Acc: 0.7508
# Epoch 023 | Val Acc: 0.7621
# Epoch 024 | Val Acc: 0.7387
# Epoch 025 | Val Acc: 0.7798
# Epoch 026 | Val Acc: 0.7685
# Epoch 027 | Val Acc: 0.7621
# Epoch 028 | Val Acc: 0.7823
# Epoch 029 | Val Acc: 0.7927
# Epoch 030 | Val Acc: 0.7790
# Epoch 031 | Val Acc: 0.7871
# Epoch 032 | Val Acc: 0.8008
# Epoch 033 | Val Acc: 0.8056
# Epoch 034 | Val Acc: 0.7847
# Epoch 035 | Val Acc: 0.7806
# Epoch 036 | Val Acc: 0.8097
# Epoch 037 | Val Acc: 0.8056
# Epoch 038 | Val Acc: 0.8089
# Epoch 039 | Val Acc: 0.7976
# Epoch 040 | Val Acc: 0.8097
# Epoch 041 | Val Acc: 0.8242
# Epoch 042 | Val Acc: 0.8081
# Epoch 043 | Val Acc: 0.8016
# Epoch 044 | Val Acc: 0.8129
# Epoch 045 | Val Acc: 0.7911
# Epoch 046 | Val Acc: 0.8113
# Epoch 047 | Val Acc: 0.8097
# Epoch 048 | Val Acc: 0.8097
# Epoch 049 | Val Acc: 0.8258
# Epoch 050 | Val Acc: 0.8129
# Epoch 051 | Val Acc: 0.8282
# Epoch 052 | Val Acc: 0.8194
# Epoch 053 | Val Acc: 0.8137
# Epoch 054 | Val Acc: 0.8153
# Epoch 055 | Val Acc: 0.8226
# Epoch 056 | Val Acc: 0.8258
# Epoch 057 | Val Acc: 0.8121
# Epoch 058 | Val Acc: 0.8210
# Epoch 059 | Val Acc: 0.7919
# Epoch 060 | Val Acc: 0.8185
# Epoch 061 | Val Acc: 0.8298
# Epoch 062 | Val Acc: 0.8040
# Epoch 063 | Val Acc: 0.8258
# Epoch 064 | Val Acc: 0.8266
# Epoch 065 | Val Acc: 0.8153
# Epoch 066 | Val Acc: 0.8121
# Epoch 067 | Val Acc: 0.8169
# Epoch 068 | Val Acc: 0.8081
# Epoch 069 | Val Acc: 0.8097
# Epoch 070 | Val Acc: 0.8097
# Epoch 071 | Val Acc: 0.8194
# Early stopping triggered
# Best accuracy (split 6): 0.8298
#
# ===== SPLIT 7 =====
# Epoch 001 | Val Acc: 0.0492
# Epoch 002 | Val Acc: 0.1040
# Epoch 003 | Val Acc: 0.1597
# Epoch 004 | Val Acc: 0.2274
# Epoch 005 | Val Acc: 0.2726
# Epoch 006 | Val Acc: 0.3508
# Epoch 007 | Val Acc: 0.4379
# Epoch 008 | Val Acc: 0.5048
# Epoch 009 | Val Acc: 0.5315
# Epoch 010 | Val Acc: 0.4685
# Epoch 011 | Val Acc: 0.5782
# Epoch 012 | Val Acc: 0.6468
# Epoch 013 | Val Acc: 0.6516
# Epoch 014 | Val Acc: 0.6742
# Epoch 015 | Val Acc: 0.6831
# Epoch 016 | Val Acc: 0.6726
# Epoch 017 | Val Acc: 0.6444
# Epoch 018 | Val Acc: 0.7298
# Epoch 019 | Val Acc: 0.7363
# Epoch 020 | Val Acc: 0.7363
# Epoch 021 | Val Acc: 0.7468
# Epoch 022 | Val Acc: 0.7540
# Epoch 023 | Val Acc: 0.7790
# Epoch 024 | Val Acc: 0.7758
# Epoch 025 | Val Acc: 0.7645
# Epoch 026 | Val Acc: 0.7726
# Epoch 027 | Val Acc: 0.7782
# Epoch 028 | Val Acc: 0.7718
# Epoch 029 | Val Acc: 0.7806
# Epoch 030 | Val Acc: 0.7645
# Epoch 031 | Val Acc: 0.7540
# Epoch 032 | Val Acc: 0.7984
# Epoch 033 | Val Acc: 0.7831
# Epoch 034 | Val Acc: 0.7839
# Epoch 035 | Val Acc: 0.7726
# Epoch 036 | Val Acc: 0.7976
# Epoch 037 | Val Acc: 0.7798
# Epoch 038 | Val Acc: 0.8024
# Epoch 039 | Val Acc: 0.7968
# Epoch 040 | Val Acc: 0.7952
# Epoch 041 | Val Acc: 0.8008
# Epoch 042 | Val Acc: 0.7976
# Epoch 043 | Val Acc: 0.8008
# Epoch 044 | Val Acc: 0.8210
# Epoch 045 | Val Acc: 0.8048
# Epoch 046 | Val Acc: 0.7976
# Epoch 047 | Val Acc: 0.8032
# Epoch 048 | Val Acc: 0.8056
# Epoch 049 | Val Acc: 0.8016
# Epoch 050 | Val Acc: 0.8137
# Epoch 051 | Val Acc: 0.8040
# Epoch 052 | Val Acc: 0.8113
# Epoch 053 | Val Acc: 0.8290
# Epoch 054 | Val Acc: 0.8194
# Epoch 055 | Val Acc: 0.8282
# Epoch 056 | Val Acc: 0.8089
# Epoch 057 | Val Acc: 0.8105
# Epoch 058 | Val Acc: 0.8153
# Epoch 059 | Val Acc: 0.8065
# Epoch 060 | Val Acc: 0.8048
# Epoch 061 | Val Acc: 0.8073
# Epoch 062 | Val Acc: 0.8202
# Epoch 063 | Val Acc: 0.8234
# Early stopping triggered
# Best accuracy (split 7): 0.8290
#
# ===== SPLIT 8 =====
# Epoch 001 | Val Acc: 0.0339
# Epoch 002 | Val Acc: 0.1024
# Epoch 003 | Val Acc: 0.1605
# Epoch 004 | Val Acc: 0.2161
# Epoch 005 | Val Acc: 0.2306
# Epoch 006 | Val Acc: 0.3306
# Epoch 007 | Val Acc: 0.4097
# Epoch 008 | Val Acc: 0.4758
# Epoch 009 | Val Acc: 0.4944
# Epoch 010 | Val Acc: 0.5355
# Epoch 011 | Val Acc: 0.5992
# Epoch 012 | Val Acc: 0.6121
# Epoch 013 | Val Acc: 0.6347
# Epoch 014 | Val Acc: 0.6258
# Epoch 015 | Val Acc: 0.5976
# Epoch 016 | Val Acc: 0.6960
# Epoch 017 | Val Acc: 0.7024
# Epoch 018 | Val Acc: 0.7056
# Epoch 019 | Val Acc: 0.7121
# Epoch 020 | Val Acc: 0.7282
# Epoch 021 | Val Acc: 0.7073
# Epoch 022 | Val Acc: 0.7250
# Epoch 023 | Val Acc: 0.7331
# Epoch 024 | Val Acc: 0.7387
# Epoch 025 | Val Acc: 0.7500
# Epoch 026 | Val Acc: 0.7250
# Epoch 027 | Val Acc: 0.7597
# Epoch 028 | Val Acc: 0.7637
# Epoch 029 | Val Acc: 0.7548
# Epoch 030 | Val Acc: 0.7589
# Epoch 031 | Val Acc: 0.7677
# Epoch 032 | Val Acc: 0.7645
# Epoch 033 | Val Acc: 0.7734
# Epoch 034 | Val Acc: 0.7645
# Epoch 035 | Val Acc: 0.7637
# Epoch 036 | Val Acc: 0.7565
# Epoch 037 | Val Acc: 0.7726
# Epoch 038 | Val Acc: 0.7790
# Epoch 039 | Val Acc: 0.7879
# Epoch 040 | Val Acc: 0.7766
# Epoch 041 | Val Acc: 0.7831
# Epoch 042 | Val Acc: 0.7710
# Epoch 043 | Val Acc: 0.8032
# Epoch 044 | Val Acc: 0.7782
# Epoch 045 | Val Acc: 0.8048
# Epoch 046 | Val Acc: 0.8008
# Epoch 047 | Val Acc: 0.7750
# Epoch 048 | Val Acc: 0.7887
# Epoch 049 | Val Acc: 0.7879
# Epoch 050 | Val Acc: 0.7903
# Epoch 051 | Val Acc: 0.7911
# Epoch 052 | Val Acc: 0.7919
# Epoch 053 | Val Acc: 0.8097
# Epoch 054 | Val Acc: 0.8153
# Epoch 055 | Val Acc: 0.8073
# Epoch 056 | Val Acc: 0.7992
# Epoch 057 | Val Acc: 0.8089
# Epoch 058 | Val Acc: 0.8145
# Epoch 059 | Val Acc: 0.8056
# Epoch 060 | Val Acc: 0.7790
# Epoch 061 | Val Acc: 0.8145
# Epoch 062 | Val Acc: 0.8089
# Epoch 063 | Val Acc: 0.7895
# Epoch 064 | Val Acc: 0.7968
# Early stopping triggered
# Best accuracy (split 8): 0.8153
#
# ===== SPLIT 9 =====
# Epoch 001 | Val Acc: 0.0427
# Epoch 002 | Val Acc: 0.0847
# Epoch 003 | Val Acc: 0.1710
# Epoch 004 | Val Acc: 0.2282
# Epoch 005 | Val Acc: 0.2823
# Epoch 006 | Val Acc: 0.3879
# Epoch 007 | Val Acc: 0.4290
# Epoch 008 | Val Acc: 0.5194
# Epoch 009 | Val Acc: 0.5629
# Epoch 010 | Val Acc: 0.5887
# Epoch 011 | Val Acc: 0.6065
# Epoch 012 | Val Acc: 0.6298
# Epoch 013 | Val Acc: 0.6387
# Epoch 014 | Val Acc: 0.6661
# Epoch 015 | Val Acc: 0.6815
# Epoch 016 | Val Acc: 0.6887
# Epoch 017 | Val Acc: 0.7137
# Epoch 018 | Val Acc: 0.6935
# Epoch 019 | Val Acc: 0.7347
# Epoch 020 | Val Acc: 0.7339
# Epoch 021 | Val Acc: 0.7306
# Epoch 022 | Val Acc: 0.7411
# Epoch 023 | Val Acc: 0.7597
# Epoch 024 | Val Acc: 0.7718
# Epoch 025 | Val Acc: 0.7605
# Epoch 026 | Val Acc: 0.7694
# Epoch 027 | Val Acc: 0.7750
# Epoch 028 | Val Acc: 0.7734
# Epoch 029 | Val Acc: 0.7806
# Epoch 030 | Val Acc: 0.7710
# Epoch 031 | Val Acc: 0.7911
# Epoch 032 | Val Acc: 0.7831
# Epoch 033 | Val Acc: 0.7968
# Epoch 034 | Val Acc: 0.7927
# Epoch 035 | Val Acc: 0.7952
# Epoch 036 | Val Acc: 0.7960
# Epoch 037 | Val Acc: 0.7605
# Epoch 038 | Val Acc: 0.7984
# Epoch 039 | Val Acc: 0.7847
# Epoch 040 | Val Acc: 0.7887
# Epoch 041 | Val Acc: 0.8016
# Epoch 042 | Val Acc: 0.8073
# Epoch 043 | Val Acc: 0.7984
# Epoch 044 | Val Acc: 0.8040
# Epoch 045 | Val Acc: 0.8105
# Epoch 046 | Val Acc: 0.8145
# Epoch 047 | Val Acc: 0.8056
# Epoch 048 | Val Acc: 0.8016
# Epoch 049 | Val Acc: 0.8065
# Epoch 050 | Val Acc: 0.8137
# Epoch 051 | Val Acc: 0.7919
# Epoch 052 | Val Acc: 0.7734
# Epoch 053 | Val Acc: 0.8137
# Epoch 054 | Val Acc: 0.8202
# Epoch 055 | Val Acc: 0.7718
# Epoch 056 | Val Acc: 0.7984
# Epoch 057 | Val Acc: 0.8202
# Epoch 058 | Val Acc: 0.8226
# Epoch 059 | Val Acc: 0.8347
# Epoch 060 | Val Acc: 0.8274
# Epoch 061 | Val Acc: 0.8315
# Epoch 062 | Val Acc: 0.8298
# Epoch 063 | Val Acc: 0.7960
# Epoch 064 | Val Acc: 0.8024
# Epoch 065 | Val Acc: 0.8210
# Epoch 066 | Val Acc: 0.8242
# Epoch 067 | Val Acc: 0.8331
# Epoch 068 | Val Acc: 0.8298
# Epoch 069 | Val Acc: 0.8234
# Early stopping triggered
# Best accuracy (split 9): 0.8347
#
# ===== SPLIT 10 =====
# Epoch 001 | Val Acc: 0.0290
# Epoch 002 | Val Acc: 0.0976
# Epoch 003 | Val Acc: 0.1452
# Epoch 004 | Val Acc: 0.1702
# Epoch 005 | Val Acc: 0.2653
# Epoch 006 | Val Acc: 0.3661
# Epoch 007 | Val Acc: 0.4040
# Epoch 008 | Val Acc: 0.4637
# Epoch 009 | Val Acc: 0.5089
# Epoch 010 | Val Acc: 0.5871
# Epoch 011 | Val Acc: 0.6024
# Epoch 012 | Val Acc: 0.6185
# Epoch 013 | Val Acc: 0.6379
# Epoch 014 | Val Acc: 0.6435
# Epoch 015 | Val Acc: 0.6790
# Epoch 016 | Val Acc: 0.6895
# Epoch 017 | Val Acc: 0.6790
# Epoch 018 | Val Acc: 0.7210
# Epoch 019 | Val Acc: 0.7137
# Epoch 020 | Val Acc: 0.7266
# Epoch 021 | Val Acc: 0.7339
# Epoch 022 | Val Acc: 0.7234
# Epoch 023 | Val Acc: 0.7323
# Epoch 024 | Val Acc: 0.7161
# Epoch 025 | Val Acc: 0.7532
# Epoch 026 | Val Acc: 0.7605
# Epoch 027 | Val Acc: 0.7581
# Epoch 028 | Val Acc: 0.7548
# Epoch 029 | Val Acc: 0.7613
# Epoch 030 | Val Acc: 0.7613
# Epoch 031 | Val Acc: 0.7669
# Epoch 032 | Val Acc: 0.7702
# Epoch 033 | Val Acc: 0.7621
# Epoch 034 | Val Acc: 0.7726
# Epoch 035 | Val Acc: 0.7581
# Epoch 036 | Val Acc: 0.7863
# Epoch 037 | Val Acc: 0.7815
# Epoch 038 | Val Acc: 0.7847
# Epoch 039 | Val Acc: 0.7871
# Epoch 040 | Val Acc: 0.7855
# Epoch 041 | Val Acc: 0.7815
# Epoch 042 | Val Acc: 0.7944
# Epoch 043 | Val Acc: 0.7871
# Epoch 044 | Val Acc: 0.7613
# Epoch 045 | Val Acc: 0.7935
# Epoch 046 | Val Acc: 0.8000
# Epoch 047 | Val Acc: 0.7911
# Epoch 048 | Val Acc: 0.7944
# Epoch 049 | Val Acc: 0.7944
# Epoch 050 | Val Acc: 0.7992
# Epoch 051 | Val Acc: 0.7806
# Epoch 052 | Val Acc: 0.7758
# Epoch 053 | Val Acc: 0.7968
# Epoch 054 | Val Acc: 0.7944
# Epoch 055 | Val Acc: 0.7831
# Epoch 056 | Val Acc: 0.7927
# Early stopping triggered
# Best accuracy (split 10): 0.8000
#
# FINAL AVERAGE ACCURACY (CNN + BiLSTM + CCE): 0.8171774193548387
